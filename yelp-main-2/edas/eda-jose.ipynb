# %%
import pandas as pd

test_sample = pd.read_csv('under-sample.csv')

# %%
test_sample.head()
# Out:
#    Unnamed: 0             business_id                 user_id  \
# 0           0  ZeJjnl4o5sffMxPTt7h6ug  CNPZ2ZjDu-lNPKi6f5wEIA
# 1           1  Ccs-77XZCWf1aOozv6U-Ww  nJVAtTBB-25RiomzBB8bHw
# 2           2  FHdgpBT2Br7BL-V3gglIkA  zZOjl_mlBoqJN22dD5nbpQ
# 3           3  FHdgpBT2Br7BL-V3gglIkA  DWO5d7GJWB2Mmuv67yY_fQ
# 4           4  FHdgpBT2Br7BL-V3gglIkA  fJrZ-1B0ngdgM_2qQY_6BA
#
#                                                 text  cool  stars  \
# 0  I tried to give this company the benefit of th...     0    1.0
# 1  We ended up here through serendipity... White ...     0    5.0
# 2  Bouncers were actively enforcing CDC/ social d...     0    5.0
# 3  Its a place that I comfortable but I hate when...     0    2.0
# 4  Great food and great staff! There racks Mack b...     0    5.0
#
#                         date  funny               review_id  useful  ...  \
# 0  2015-09-09 15:02:48+00:00      0  Zs2sKoUKASUe_WsGpQuE8A       5  ...
# 1  2017-11-18 19:59:59+00:00      0  Eju6FaSp93TC_g06mwwFzA       0  ...
# 2  2020-06-27 04:51:22+00:00      0  ulSlOe8dnv8mjLvLtly8hQ       0  ...
# 3  2016-01-08 22:35:17+00:00      0  dISAAuF9njJb6pT2J1ILuQ       0  ...
# 4  2019-04-12 20:31:51+00:00      0  MlSZu7iI4pbCl7MY0eFXgA       0  ...
#
#                 address  city  state   latitude  longitude  \
# 0      241 Boro Line Rd   kop     PA  40.102683 -75.355972
# 1       209 Vineyard Rd  Atco     NJ  39.738343 -74.886403
# 2  286 White Horse Pike  Atco     NJ  39.772589 -74.900347
# 3  286 White Horse Pike  Atco     NJ  39.772589 -74.900347
# 4  286 White Horse Pike  Atco     NJ  39.772589 -74.900347
#
#   average_business_stars recieved_reviews  \
# 0                    2.0               70
# 1                    4.5               53
# 2                    3.0               58
# 3                    3.0               58
# 4                    3.0               58
#
#                                           categories  \
# 0                    Automotive, Auto Repair, Towing
# 1               Food, Arts & Entertainment, Wineries
# 2  American (Traditional), Nightlife, Bars, Sport...
# 3  American (Traditional), Nightlife, Bars, Sport...
# 4  American (Traditional), Nightlife, Bars, Sport...
#
#                                           attributes  tip_review
# 0            {'BusinessAcceptsCreditCards': 'False'}         NaN
# 1  {'GoodForKids': 'False', 'RestaurantsPriceRang...         NaN
# 2  {'Alcohol': "u'full_bar'", 'BusinessAcceptsCre...         NaN
# 3  {'Alcohol': "u'full_bar'", 'BusinessAcceptsCre...         NaN
# 4  {'Alcohol': "u'full_bar'", 'BusinessAcceptsCre...         NaN
#
# [5 rows x 24 columns]

# %%
test_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 327662 entries, 0 to 327661
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Unnamed: 0              327662 non-null  int64
#  1   business_id             327662 non-null  object
#  2   user_id                 327662 non-null  object
#  3   text                    327662 non-null  object
#  4   cool                    327662 non-null  int64
#  5   stars                   327662 non-null  float64
#  6   date                    327662 non-null  object
#  7   funny                   327662 non-null  int64
#  8   review_id               327662 non-null  object
#  9   useful                  327662 non-null  int64
#  10  average_user_stars      327661 non-null  float64
#  11  yelping_since           327661 non-null  object
#  12  submitted_reviews       327661 non-null  float64
#  13  name                    327662 non-null  object
#  14  address                 323650 non-null  object
#  15  city                    327662 non-null  object
#  16  state                   327662 non-null  object
#  17  latitude                327662 non-null  float64
#  18  longitude               327662 non-null  float64
#  19  average_business_stars  327662 non-null  float64
#  20  recieved_reviews        327662 non-null  int64
#  21  categories              327633 non-null  object
#  22  attributes              319061 non-null  object
#  23  tip_review              20229 non-null   object
# dtypes: float64(6), int64(5), object(13)
# memory usage: 60.0+ MB

# %% [markdown]
# #### Understanding the Dataset

# %%
## Number of unique business ID
test_sample['business_id'].nunique()
# Out:
# 85697

# %%
test_sample['user_id'].nunique()
# Out:
# 231044

# %%
test_sample['cool'].unique()
# Out:
# array([  0,   1,   2,   3,  49,   5,   4,   6,   8,   9,  10,  16,   7,
#         18,  11,  12,  14,  24,  22,  17,  21,  19,  25,  27,  13,  20,
#        121,  40,  73,  39,  23,  15,  79,  43,  96,  45,  58,  46,  30,
#         35,  31,  37,  64,  51,  33,  55, 141,  26,  29,  81,  32,  50,
#        145, 169,  63,  47,  42,  28,  48, 110,  87,  44, 164,  98,  36,
#         34, 105,  41,  82,  67,  52, 205, 400, 143,  91,  72, 124, 120,
#         59,  38, 376, 355, 101, 128,  53,  68,  89, 111,  61,  94,  54,
#         74,  69, 116,  86,  60, 107, 136,  70, 113,  57])

# %%
test_sample['average_business_stars'].unique()
# Out:
# array([2. , 4.5, 3. , 2.5, 3.5, 4. , 1.5, 5. , 1. ])

# %%
test_sample['tip_review'].isna().sum()
# Out:
# 307433

# %%
test_sample['categories'].isna().sum()
# Out:
# 29

# %%
test_sample['attributes'].unique()
# Out:
# array(["{'BusinessAcceptsCreditCards': 'False'}",
#        '{\'GoodForKids\': \'False\', \'RestaurantsPriceRange2\': \'2\', \'BusinessAcceptsCreditCards\': \'True\', \'BusinessParking\': "{\'garage\': False, \'street\': False, \'validated\': False, \'lot\': True, \'valet\': False}", \'ByAppointmentOnly\': \'False\', \'RestaurantsTakeOut\': \'False\', \'Caters\': \'False\', \'BikeParking\': \'True\'}',
#        '{\'Alcohol\': "u\'full_bar\'", \'BusinessAcceptsCreditCards\': \'True\', \'NoiseLevel\': "u\'average\'", \'BusinessParking\': "{\'garage\': False, \'street\': False, \'validated\': False, \'lot\': True, \'valet\': False}", \'OutdoorSeating\': \'True\', \'RestaurantsGoodForGroups\': \'True\', \'RestaurantsTakeOut\': \'True\', \'WiFi\': "\'free\'", \'GoodForKids\': \'True\', \'RestaurantsPriceRange2\': \'2\', \'HasTV\': \'True\', \'Ambience\': "{\'romantic\': False, \'intimate\': False, \'classy\': False, \'hipster\': False, \'divey\': False, \'touristy\': False, \'trendy\': False, \'upscale\': False, \'casual\': True}", \'RestaurantsAttire\': "u\'casual\'", \'Caters\': \'False\', \'BikeParking\': \'True\', \'Smoking\': "u\'outdoor\'", \'HappyHour\': \'True\', \'BusinessAcceptsBitcoin\': \'False\', \'WheelchairAccessible\': \'True\', \'Music\': "{\'dj\': False, \'background_music\': False, \'no_music\': False, \'jukebox\': False, \'live\': True, \'video\': False, \'karaoke\': False}", \'RestaurantsReservations\': \'True\', \'RestaurantsDelivery\': \'True\', \'RestaurantsTableService\': \'True\', \'CoatCheck\': \'False\', \'BYOB\': \'False\', \'GoodForMeal\': "{\'dessert\': False, \'latenight\': False, \'lunch\': False, \'dinner\': False, \'brunch\': False, \'breakfast\': False}", \'DogsAllowed\': \'False\', \'BestNights\': "{\'monday\': False, \'tuesday\': False, \'friday\': True, \'wednesday\': False, \'thursday\': False, \'sunday\': True, \'saturday\': True}"}',
#        ...,
#        '{\'BusinessAcceptsCreditCards\': \'True\', \'BusinessParking\': "{\'garage\': False, \'street\': True, \'validated\': False, \'lot\': True, \'valet\': False}", \'ByAppointmentOnly\': \'False\', \'GoodForKids\': \'False\', \'RestaurantsPriceRange2\': \'2\'}',
#        '{\'Ambience\': "{\'romantic\': False, \'intimate\': False, \'classy\': False, \'hipster\': False, \'divey\': False, \'touristy\': False, \'trendy\': False, \'upscale\': False, \'casual\': False}", \'RestaurantsTakeOut\': \'True\', \'BusinessParking\': "{\'garage\': False, \'street\': False, \'validated\': False, \'lot\': False, \'valet\': False}", \'RestaurantsReservations\': \'False\', \'GoodForKids\': \'True\', \'OutdoorSeating\': \'False\', \'BusinessAcceptsCreditCards\': \'True\', \'Caters\': \'False\', \'RestaurantsPriceRange2\': \'1\', \'NoiseLevel\': "\'quiet\'", \'Alcohol\': "\'none\'", \'RestaurantsGoodForGroups\': \'True\', \'WiFi\': "\'free\'", \'RestaurantsDelivery\': \'True\', \'RestaurantsAttire\': "\'casual\'", \'GoodForMeal\': "{\'dessert\': False, \'latenight\': False, \'lunch\': False, \'dinner\': False, \'brunch\': False, \'breakfast\': False}", \'HasTV\': \'True\', \'BikeParking\': \'False\'}',
#        '{\'RestaurantsTakeOut\': \'True\', \'BusinessAcceptsCreditCards\': \'True\', \'HappyHour\': \'True\', \'Caters\': \'False\', \'BusinessParking\': "{\'garage\': False, \'street\': False, \'validated\': False, \'lot\': True, \'valet\': False}", \'DogsAllowed\': \'True\', \'WheelchairAccessible\': \'True\', \'RestaurantsPriceRange2\': \'2\'}'],
#       dtype=object)

# %% [markdown]
# #### Cleaning and transforming

# %%
test_sample.drop(columns = ['address', 'tip_review'], axis = 1, inplace = True)

# %%
test_sample.set_index('Unnamed: 0', inplace=True)

# %%
nans = test_sample.isna().sum()
nans
# Out:
# business_id                  0
# user_id                      0
# text                         0
# cool                         0
# stars                        0
# date                         0
# funny                        0
# review_id                    0
# useful                       0
# average_user_stars           1
# yelping_since                1
# submitted_reviews            1
# name                         0
# city                         0
# state                        0
# latitude                     0
# longitude                    0
# average_business_stars       0
# recieved_reviews             0
# categories                  29
# attributes                8601
# dtype: int64

# %%
test_sample_dropped_na = test_sample.dropna()

# %%
test_sample_dropped_na
# Out:
#                        business_id                 user_id  \
# Unnamed: 0
# 0           ZeJjnl4o5sffMxPTt7h6ug  CNPZ2ZjDu-lNPKi6f5wEIA
# 1           Ccs-77XZCWf1aOozv6U-Ww  nJVAtTBB-25RiomzBB8bHw
# 2           FHdgpBT2Br7BL-V3gglIkA  zZOjl_mlBoqJN22dD5nbpQ
# 3           FHdgpBT2Br7BL-V3gglIkA  DWO5d7GJWB2Mmuv67yY_fQ
# 4           FHdgpBT2Br7BL-V3gglIkA  fJrZ-1B0ngdgM_2qQY_6BA
# ...                            ...                     ...
# 327657      HuoKX6R9VC5yn9xj-xUT8w  7ThsVyQniXAH0THHqQpLJw
# 327658      HuoKX6R9VC5yn9xj-xUT8w  YbgXTYO_87L1GzIrmHHoiQ
# 327659      r_kRUzLVOws0qdSXINGuQA  qvPylVHr8-0_hmjDl2iX4g
# 327660      XZGOTAmHF1fdOfXMES3kaA  yR6bO_X610KIJZm2i8uOiw
# 327661      5-dALZnUy43LJM5d8SAeyw  gR6zPKYEI1OaEZH7Q0FFVg
#
#                                                          text  cool  stars  \
# Unnamed: 0
# 0           I tried to give this company the benefit of th...     0    1.0
# 1           We ended up here through serendipity... White ...     0    5.0
# 2           Bouncers were actively enforcing CDC/ social d...     0    5.0
# 3           Its a place that I comfortable but I hate when...     0    2.0
# 4           Great food and great staff! There racks Mack b...     0    5.0
# ...                                                       ...   ...    ...
# 327657      Was there last night, great food all around.  ...     0    5.0
# 327658      Amazing food! A very cozy atmosphere. As good ...     0    5.0
# 327659      Came in for the Eagles game and had a wonderfu...     0    5.0
# 327660      I always shop here. The salespeople are honest...     0    5.0
# 327661      Super convenient, good price, great job - I'm ...     0    5.0
#
#                                  date  funny               review_id  useful  \
# Unnamed: 0
# 0           2015-09-09 15:02:48+00:00      0  Zs2sKoUKASUe_WsGpQuE8A       5
# 1           2017-11-18 19:59:59+00:00      0  Eju6FaSp93TC_g06mwwFzA       0
# 2           2020-06-27 04:51:22+00:00      0  ulSlOe8dnv8mjLvLtly8hQ       0
# 3           2016-01-08 22:35:17+00:00      0  dISAAuF9njJb6pT2J1ILuQ       0
# 4           2019-04-12 20:31:51+00:00      0  MlSZu7iI4pbCl7MY0eFXgA       0
# ...                               ...    ...                     ...     ...
# 327657      2013-08-23 00:28:20+00:00      0  9DWpXzU0wI0sJXmaqQWe9g       1
# 327658      2015-04-08 22:53:47+00:00      0  0ys_6YRgC5xrsU8bzQ2RdQ       0
# 327659      2018-10-28 17:12:19+00:00      0  EIhs_ZGmYcANgXvuTHC9Rw       0
# 327660      2019-08-05 20:01:46+00:00      0  e6_Ji3VFnxr6Jau-zG5vAA       0
# 327661      2017-08-20 19:16:35+00:00      0  JeAqXFCO0P9wvcn53m1DMA       0
#
#             average_user_stars  ... submitted_reviews  \
# Unnamed: 0                      ...
# 0                         2.20  ...               5.0
# 1                         2.82  ...              11.0
# 2                         3.67  ...              12.0
# 3                         3.85  ...              39.0
# 4                         3.67  ...               3.0
# ...                        ...  ...               ...
# 327657                    5.00  ...               1.0
# 327658                    4.00  ...               2.0
# 327659                    5.00  ...               1.0
# 327660                    4.07  ...              52.0
# 327661                    4.20  ...               9.0
#
#                                     name                              city  \
# Unnamed: 0
# 0           Samantha's Towing & Recovery                               kop
# 1           Amalthea Cellars Farm Winery                              Atco
# 2                      Racks Pub & Grill                              Atco
# 3                      Racks Pub & Grill                              Atco
# 4                      Racks Pub & Grill                              Atco
# ...                                  ...                               ...
# 327657                            Rexy's         West Collingswood Heights
# 327658                            Rexy's         West Collingswood Heights
# 327659         Moss Mill Brewing Company        Lower Southampton Township
# 327660                P.C. Richard & Son   Philadelphia (Northeast Philly)
# 327661                     The Blind Guy  Santa Barbara & Ventura Counties
#
#            state   latitude   longitude  average_business_stars  \
# Unnamed: 0
# 0             PA  40.102683  -75.355972                     2.0
# 1             NJ  39.738343  -74.886403                     4.5
# 2             NJ  39.772589  -74.900347                     3.0
# 3             NJ  39.772589  -74.900347                     3.0
# 4             NJ  39.772589  -74.900347                     3.0
# ...          ...        ...         ...                     ...
# 327657        NJ  39.892485  -75.091006                     3.5
# 327658        NJ  39.892485  -75.091006                     3.5
# 327659        PA  40.148549  -75.022480                     4.0
# 327660        PA  40.046024  -75.060111                     3.0
# 327661        CA  34.420832 -119.698206                     3.5
#
#             recieved_reviews  \
# Unnamed: 0
# 0                         70
# 1                         53
# 2                         58
# 3                         58
# 4                         58
# ...                      ...
# 327657                   121
# 327658                   121
# 327659                    18
# 327660                    27
# 327661                    38
#
#                                                    categories  \
# Unnamed: 0
# 0                             Automotive, Auto Repair, Towing
# 1                        Food, Arts & Entertainment, Wineries
# 2           American (Traditional), Nightlife, Bars, Sport...
# 3           American (Traditional), Nightlife, Bars, Sport...
# 4           American (Traditional), Nightlife, Bars, Sport...
# ...                                                       ...
# 327657                            Italian, Pizza, Restaurants
# 327658                            Italian, Pizza, Restaurants
# 327659                                        Breweries, Food
# 327660      Home & Garden, Mattresses, Appliances, Compute...
# 327661                         Shades & Blinds, Home Services
#
#                                                    attributes
# Unnamed: 0
# 0                     {'BusinessAcceptsCreditCards': 'False'}
# 1           {'GoodForKids': 'False', 'RestaurantsPriceRang...
# 2           {'Alcohol': "u'full_bar'", 'BusinessAcceptsCre...
# 3           {'Alcohol': "u'full_bar'", 'BusinessAcceptsCre...
# 4           {'Alcohol': "u'full_bar'", 'BusinessAcceptsCre...
# ...                                                       ...
# 327657      {'Alcohol': "u'full_bar'", 'RestaurantsPriceRa...
# 327658      {'Alcohol': "u'full_bar'", 'RestaurantsPriceRa...
# 327659      {'RestaurantsTakeOut': 'True', 'BusinessAccept...
# 327660      {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 327661      {'ByAppointmentOnly': 'True', 'BusinessAccepts...
#
# [319059 rows x 21 columns]

# %%
test_sample_dropped_na['category'] = test_sample_dropped_na['categories'].str.split(',').str[0].str.strip()
# Out:
# /var/folders/x3/42y9jxy964lg3yyk_9zhss280000gn/T/ipykernel_68498/72811156.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_sample_dropped_na['category'] = test_sample_dropped_na['categories'].str.split(',').str[0].str.strip()

# %%
test_sample_dropped_na
# Out:
#                        business_id                 user_id  \
# Unnamed: 0
# 0           ZeJjnl4o5sffMxPTt7h6ug  CNPZ2ZjDu-lNPKi6f5wEIA
# 1           Ccs-77XZCWf1aOozv6U-Ww  nJVAtTBB-25RiomzBB8bHw
# 2           FHdgpBT2Br7BL-V3gglIkA  zZOjl_mlBoqJN22dD5nbpQ
# 3           FHdgpBT2Br7BL-V3gglIkA  DWO5d7GJWB2Mmuv67yY_fQ
# 4           FHdgpBT2Br7BL-V3gglIkA  fJrZ-1B0ngdgM_2qQY_6BA
# ...                            ...                     ...
# 327657      HuoKX6R9VC5yn9xj-xUT8w  7ThsVyQniXAH0THHqQpLJw
# 327658      HuoKX6R9VC5yn9xj-xUT8w  YbgXTYO_87L1GzIrmHHoiQ
# 327659      r_kRUzLVOws0qdSXINGuQA  qvPylVHr8-0_hmjDl2iX4g
# 327660      XZGOTAmHF1fdOfXMES3kaA  yR6bO_X610KIJZm2i8uOiw
# 327661      5-dALZnUy43LJM5d8SAeyw  gR6zPKYEI1OaEZH7Q0FFVg
#
#                                                          text  cool  stars  \
# Unnamed: 0
# 0           I tried to give this company the benefit of th...     0    1.0
# 1           We ended up here through serendipity... White ...     0    5.0
# 2           Bouncers were actively enforcing CDC/ social d...     0    5.0
# 3           Its a place that I comfortable but I hate when...     0    2.0
# 4           Great food and great staff! There racks Mack b...     0    5.0
# ...                                                       ...   ...    ...
# 327657      Was there last night, great food all around.  ...     0    5.0
# 327658      Amazing food! A very cozy atmosphere. As good ...     0    5.0
# 327659      Came in for the Eagles game and had a wonderfu...     0    5.0
# 327660      I always shop here. The salespeople are honest...     0    5.0
# 327661      Super convenient, good price, great job - I'm ...     0    5.0
#
#                                  date  funny               review_id  useful  \
# Unnamed: 0
# 0           2015-09-09 15:02:48+00:00      0  Zs2sKoUKASUe_WsGpQuE8A       5
# 1           2017-11-18 19:59:59+00:00      0  Eju6FaSp93TC_g06mwwFzA       0
# 2           2020-06-27 04:51:22+00:00      0  ulSlOe8dnv8mjLvLtly8hQ       0
# 3           2016-01-08 22:35:17+00:00      0  dISAAuF9njJb6pT2J1ILuQ       0
# 4           2019-04-12 20:31:51+00:00      0  MlSZu7iI4pbCl7MY0eFXgA       0
# ...                               ...    ...                     ...     ...
# 327657      2013-08-23 00:28:20+00:00      0  9DWpXzU0wI0sJXmaqQWe9g       1
# 327658      2015-04-08 22:53:47+00:00      0  0ys_6YRgC5xrsU8bzQ2RdQ       0
# 327659      2018-10-28 17:12:19+00:00      0  EIhs_ZGmYcANgXvuTHC9Rw       0
# 327660      2019-08-05 20:01:46+00:00      0  e6_Ji3VFnxr6Jau-zG5vAA       0
# 327661      2017-08-20 19:16:35+00:00      0  JeAqXFCO0P9wvcn53m1DMA       0
#
#             average_user_stars  ...                          name  \
# Unnamed: 0                      ...
# 0                         2.20  ...  Samantha's Towing & Recovery
# 1                         2.82  ...  Amalthea Cellars Farm Winery
# 2                         3.67  ...             Racks Pub & Grill
# 3                         3.85  ...             Racks Pub & Grill
# 4                         3.67  ...             Racks Pub & Grill
# ...                        ...  ...                           ...
# 327657                    5.00  ...                        Rexy's
# 327658                    4.00  ...                        Rexy's
# 327659                    5.00  ...     Moss Mill Brewing Company
# 327660                    4.07  ...            P.C. Richard & Son
# 327661                    4.20  ...                 The Blind Guy
#
#                                         city state   latitude   longitude  \
# Unnamed: 0
# 0                                        kop    PA  40.102683  -75.355972
# 1                                       Atco    NJ  39.738343  -74.886403
# 2                                       Atco    NJ  39.772589  -74.900347
# 3                                       Atco    NJ  39.772589  -74.900347
# 4                                       Atco    NJ  39.772589  -74.900347
# ...                                      ...   ...        ...         ...
# 327657             West Collingswood Heights    NJ  39.892485  -75.091006
# 327658             West Collingswood Heights    NJ  39.892485  -75.091006
# 327659            Lower Southampton Township    PA  40.148549  -75.022480
# 327660       Philadelphia (Northeast Philly)    PA  40.046024  -75.060111
# 327661      Santa Barbara & Ventura Counties    CA  34.420832 -119.698206
#
#             average_business_stars  recieved_reviews  \
# Unnamed: 0
# 0                              2.0                70
# 1                              4.5                53
# 2                              3.0                58
# 3                              3.0                58
# 4                              3.0                58
# ...                            ...               ...
# 327657                         3.5               121
# 327658                         3.5               121
# 327659                         4.0                18
# 327660                         3.0                27
# 327661                         3.5                38
#
#                                                    categories  \
# Unnamed: 0
# 0                             Automotive, Auto Repair, Towing
# 1                        Food, Arts & Entertainment, Wineries
# 2           American (Traditional), Nightlife, Bars, Sport...
# 3           American (Traditional), Nightlife, Bars, Sport...
# 4           American (Traditional), Nightlife, Bars, Sport...
# ...                                                       ...
# 327657                            Italian, Pizza, Restaurants
# 327658                            Italian, Pizza, Restaurants
# 327659                                        Breweries, Food
# 327660      Home & Garden, Mattresses, Appliances, Compute...
# 327661                         Shades & Blinds, Home Services
#
#                                                    attributes  \
# Unnamed: 0
# 0                     {'BusinessAcceptsCreditCards': 'False'}
# 1           {'GoodForKids': 'False', 'RestaurantsPriceRang...
# 2           {'Alcohol': "u'full_bar'", 'BusinessAcceptsCre...
# 3           {'Alcohol': "u'full_bar'", 'BusinessAcceptsCre...
# 4           {'Alcohol': "u'full_bar'", 'BusinessAcceptsCre...
# ...                                                       ...
# 327657      {'Alcohol': "u'full_bar'", 'RestaurantsPriceRa...
# 327658      {'Alcohol': "u'full_bar'", 'RestaurantsPriceRa...
# 327659      {'RestaurantsTakeOut': 'True', 'BusinessAccept...
# 327660      {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 327661      {'ByAppointmentOnly': 'True', 'BusinessAccepts...
#
#                           category
# Unnamed: 0
# 0                       Automotive
# 1                             Food
# 2           American (Traditional)
# 3           American (Traditional)
# 4           American (Traditional)
# ...                            ...
# 327657                     Italian
# 327658                     Italian
# 327659                   Breweries
# 327660               Home & Garden
# 327661             Shades & Blinds
#
# [319059 rows x 22 columns]

# %%
test_sample_dropped_na['category'].nunique()
# Out:
# 1017

# %%
categories = test_sample_dropped_na['category'].value_counts()
selected_categories = categories[categories > 50].index.tolist()
filtered_dataset = test_sample_dropped_na[test_sample_dropped_na['category'].isin(selected_categories)]

# %%
filtered_dataset
# Out:
#                        business_id                 user_id  \
# Unnamed: 0
# 0           ZeJjnl4o5sffMxPTt7h6ug  CNPZ2ZjDu-lNPKi6f5wEIA
# 1           Ccs-77XZCWf1aOozv6U-Ww  nJVAtTBB-25RiomzBB8bHw
# 2           FHdgpBT2Br7BL-V3gglIkA  zZOjl_mlBoqJN22dD5nbpQ
# 3           FHdgpBT2Br7BL-V3gglIkA  DWO5d7GJWB2Mmuv67yY_fQ
# 4           FHdgpBT2Br7BL-V3gglIkA  fJrZ-1B0ngdgM_2qQY_6BA
# ...                            ...                     ...
# 327656      sjwuxotWDxG__ebwcn5eOw  eWBvAeUTsm2dvIbToF0kGg
# 327657      HuoKX6R9VC5yn9xj-xUT8w  7ThsVyQniXAH0THHqQpLJw
# 327658      HuoKX6R9VC5yn9xj-xUT8w  YbgXTYO_87L1GzIrmHHoiQ
# 327659      r_kRUzLVOws0qdSXINGuQA  qvPylVHr8-0_hmjDl2iX4g
# 327660      XZGOTAmHF1fdOfXMES3kaA  yR6bO_X610KIJZm2i8uOiw
#
#                                                          text  cool  stars  \
# Unnamed: 0
# 0           I tried to give this company the benefit of th...     0    1.0
# 1           We ended up here through serendipity... White ...     0    5.0
# 2           Bouncers were actively enforcing CDC/ social d...     0    5.0
# 3           Its a place that I comfortable but I hate when...     0    2.0
# 4           Great food and great staff! There racks Mack b...     0    5.0
# ...                                                       ...   ...    ...
# 327656      This family run business is wonderful.. I call...     0    5.0
# 327657      Was there last night, great food all around.  ...     0    5.0
# 327658      Amazing food! A very cozy atmosphere. As good ...     0    5.0
# 327659      Came in for the Eagles game and had a wonderfu...     0    5.0
# 327660      I always shop here. The salespeople are honest...     0    5.0
#
#                                  date  funny               review_id  useful  \
# Unnamed: 0
# 0           2015-09-09 15:02:48+00:00      0  Zs2sKoUKASUe_WsGpQuE8A       5
# 1           2017-11-18 19:59:59+00:00      0  Eju6FaSp93TC_g06mwwFzA       0
# 2           2020-06-27 04:51:22+00:00      0  ulSlOe8dnv8mjLvLtly8hQ       0
# 3           2016-01-08 22:35:17+00:00      0  dISAAuF9njJb6pT2J1ILuQ       0
# 4           2019-04-12 20:31:51+00:00      0  MlSZu7iI4pbCl7MY0eFXgA       0
# ...                               ...    ...                     ...     ...
# 327656      2020-05-05 19:20:38+00:00      0  aUEPrisZwthJpWTDXGucyA       0
# 327657      2013-08-23 00:28:20+00:00      0  9DWpXzU0wI0sJXmaqQWe9g       1
# 327658      2015-04-08 22:53:47+00:00      0  0ys_6YRgC5xrsU8bzQ2RdQ       0
# 327659      2018-10-28 17:12:19+00:00      0  EIhs_ZGmYcANgXvuTHC9Rw       0
# 327660      2019-08-05 20:01:46+00:00      0  e6_Ji3VFnxr6Jau-zG5vAA       0
#
#             average_user_stars  ...                          name  \
# Unnamed: 0                      ...
# 0                         2.20  ...  Samantha's Towing & Recovery
# 1                         2.82  ...  Amalthea Cellars Farm Winery
# 2                         3.67  ...             Racks Pub & Grill
# 3                         3.85  ...             Racks Pub & Grill
# 4                         3.67  ...             Racks Pub & Grill
# ...                        ...  ...                           ...
# 327656                    1.73  ...    Fischer's Appliance Repair
# 327657                    5.00  ...                        Rexy's
# 327658                    4.00  ...                        Rexy's
# 327659                    5.00  ...     Moss Mill Brewing Company
# 327660                    4.07  ...            P.C. Richard & Son
#
#                                        city state   latitude  longitude  \
# Unnamed: 0
# 0                                       kop    PA  40.102683 -75.355972
# 1                                      Atco    NJ  39.738343 -74.886403
# 2                                      Atco    NJ  39.772589 -74.900347
# 3                                      Atco    NJ  39.772589 -74.900347
# 4                                      Atco    NJ  39.772589 -74.900347
# ...                                     ...   ...        ...        ...
# 327656             Feasterville-Trevose, PA    PA  40.146638 -74.995226
# 327657            West Collingswood Heights    NJ  39.892485 -75.091006
# 327658            West Collingswood Heights    NJ  39.892485 -75.091006
# 327659           Lower Southampton Township    PA  40.148549 -75.022480
# 327660      Philadelphia (Northeast Philly)    PA  40.046024 -75.060111
#
#             average_business_stars  recieved_reviews  \
# Unnamed: 0
# 0                              2.0                70
# 1                              4.5                53
# 2                              3.0                58
# 3                              3.0                58
# 4                              3.0                58
# ...                            ...               ...
# 327656                         4.5                57
# 327657                         3.5               121
# 327658                         3.5               121
# 327659                         4.0                18
# 327660                         3.0                27
#
#                                                    categories  \
# Unnamed: 0
# 0                             Automotive, Auto Repair, Towing
# 1                        Food, Arts & Entertainment, Wineries
# 2           American (Traditional), Nightlife, Bars, Sport...
# 3           American (Traditional), Nightlife, Bars, Sport...
# 4           American (Traditional), Nightlife, Bars, Sport...
# ...                                                       ...
# 327656      Appliances & Repair, Home Services, Local Serv...
# 327657                            Italian, Pizza, Restaurants
# 327658                            Italian, Pizza, Restaurants
# 327659                                        Breweries, Food
# 327660      Home & Garden, Mattresses, Appliances, Compute...
#
#                                                    attributes  \
# Unnamed: 0
# 0                     {'BusinessAcceptsCreditCards': 'False'}
# 1           {'GoodForKids': 'False', 'RestaurantsPriceRang...
# 2           {'Alcohol': "u'full_bar'", 'BusinessAcceptsCre...
# 3           {'Alcohol': "u'full_bar'", 'BusinessAcceptsCre...
# 4           {'Alcohol': "u'full_bar'", 'BusinessAcceptsCre...
# ...                                                       ...
# 327656      {'BusinessAcceptsCreditCards': 'True', 'Busine...
# 327657      {'Alcohol': "u'full_bar'", 'RestaurantsPriceRa...
# 327658      {'Alcohol': "u'full_bar'", 'RestaurantsPriceRa...
# 327659      {'RestaurantsTakeOut': 'True', 'BusinessAccept...
# 327660      {'BusinessAcceptsCreditCards': 'True', 'Restau...
#
#                           category
# Unnamed: 0
# 0                       Automotive
# 1                             Food
# 2           American (Traditional)
# 3           American (Traditional)
# 4           American (Traditional)
# ...                            ...
# 327656         Appliances & Repair
# 327657                     Italian
# 327658                     Italian
# 327659                   Breweries
# 327660               Home & Garden
#
# [310287 rows x 22 columns]

# %%
# generalizations
restaurant_categories = ['Food Stands','Brasseries','Cheese Shops','Fish & Chips','Szechuan','African','Malaysian','Acai Bowls','Waffles','Food', 'Local Flavor', 'Canadian (New)', 'Vietnamese', 'Italian', 'Buffets', 'Burgers', 'American (Traditional)', 'American (New)', 'Breakfast & Brunch', 'Sandwiches', 'Seafood', 'Mexican', 'Pizza', 'Cajun/Creole', 'Sushi Bars', 'Chinese', 'Japanese', 'Steakhouses', 'Cafes', 'Salad', 'Fast Food', 'Bakeries', 'Ice Cream & Frozen Yogurt', 'Desserts', 'Barbeque', 'Thai', 'Specialty Food', 'Asian Fusion', 'Southern', 'Diners', 'Mediterranean', 'Delis', 'Caterers', 'Chicken Wings', 'Vegetarian', 'Indian', 'Comfort Food', 'Latin American', 'French', 'Vegan', 'Greek', 'Gluten-Free', 'Tex-Mex', 'Korean', 'Soup', 'Donuts', 'Live/Raw Food', 'Tacos', 'Tapas/Small Plates', 'Gastropubs', 'Food Delivery Services', 'Pakistani', 'Tapas Bars', 'Cheesesteaks', 'Soul Food', 'Ethnic Food', 'Middle Eastern', 'German', 'Bagels', 'Food Trucks', 'Hot Dogs', 'Noodles', 'Creperies', 'Spanish', 'Caribbean', 'Chicken Shop', 'Ramen', 'Cuban', 'Irish', 'Basque', 'Halal', 'Dim Sum', 'New Mexican Cuisine', 'Poke', 'Seafood Markets', 'British', 'Gelato', 'Cupcakes', 'Ethiopian', 'Peruvian', 'Falafel', 'Custom Cakes', 'Pasta Shops', 'Kebab', 'Hot Pot', 'Puerto Rican', 'Dominican', 'Salvadoran', 'Cafeteria', 'Pancakes', 'Senegalese', 'Sri Lankan', 'Parent Cafes','Food Banks','Food Banks','Afghan','Izakaya','Indonesian','Imported Food','Venezuelan','Pretzels','Smokehouse','Shanghainese','Patisserie/Cake Shop','Kosher','Shaved Ice','Filipino','Personal Chefs','Chocolatiers & Shops','Irish Pub','Bed & Breakfast','Taiwanese','Brazilian','Modern European','Wraps','Cantonese','Hawaiian','Candy Stores']
beauty = ["Men's Hair Salons",'Nail Technicians','Beauty & Spas', 'Nail Salons', 'Cosmetics & Beauty Supply', 'Hair Salons', 'Massage', 'Skin Care', 'Waxing', 'Eyelash Service', 'Barbers', 'Tanning', 'Threading Services', 'Day Spas', 'Piercing', 'Blow Dry/Out Services', 'Makeup Artists', 'Hair Removal', 'Eyebrow Services', 'Hair Stylists', 'Tattoo', 'Laser Hair Removal', 'Massage Therapy', 'Pedicures', 'Medical Spas', 'Hair Extensions', 'Reflexology', 'Hair Loss Centers', 'Acupuncture', 'Pole Dancing Classes', 'Float Spa', 'Cryotherapy', 'Sugaring', 'Permanent Makeup', 'Saunas','Massage Schools']
bars = ['Beer Gardens','Wineries','Bars', 'Nightlife', 'Beer', 'Wine Bars', 'Cocktail Bars', 'Sports Bars', 'Pubs', 'Breweries', 'Gastropubs', 'Beer Bar', 'Wine Tasting Room', 'Dive Bars', 'Karaoke', 'Speakeasies', 'Gay Bars', 'Juice Bars & Smoothies', 'Hookah Bars', 'Brewpubs', 'Cigar Bars', 'Champagne Bars', 'Tiki Bars','Meaderies','Distilleries','Whiskey Bars']
hotels = ['Hotels','Resorts']
auto = ['Gas Stations','Used','Auto Repair','Car Dealers','Oil Change Stations','Auto Parts & Supplies','Tires','Car Wash','Body Shops','Car Rental','Auto Detailing','Auto Loan Providers','Trailer Rental','Departments of Motor Vehicles','Motorcycle Rental','Mobile Dent Repair','Motorsport Vehicle Dealers','Bike tours','Crane Services','Auto Insurance','Car Share Services','Motorsport Vehicle Repairs','Wheel & Rim Repair','Transmission Repair','Windshield Installation & Repair','Auto Glass Services','Used Car Dealers']
venues = ['Wedding Planning','Venues & Event Spaces','Party & Event Planning','Music Venues']
fitness = ['Fitness & Instruction','Gyms','Kickboxing','Aerial Fitness','Yoga']
entertainment = ['Cinema','Museums','Tours','Performing Arts','Arts & Crafts','Jazz & Blues','Landmarks & Historical Buildings','Golf','Art Galleries','Festivals','Stadiums & Arenas','Zoos','Hiking','Bike Rentals','Playgrounds','Professional Sports Teams','Recreation Centers','Art Tours','Country Clubs','Decks & Railing','Mountain Biking','Dinner Theater','Tabletop Games','Aerial Tours','Party Bike Rentals','Game Truck Rental','Psychic Mediums', "Walking Tours", "Boat Tours", "Brewery Tours", "Wine Tours", "Air Tours", "Hot Air Balloons",  "Aerial Tours",'Buses','Firearm Training','Disc Golf','High Fidelity Audio Equipment','Vacation Rental Agents','Matchmakers','Free Diving','Ranches','Bicycles','Farm Equipment Repair','Golf Lessons','Racing Experience','Face Painting','Botanical Gardens','Comedy Clubs','Sports Clubs','Gun/Rifle Ranges','Amusement Parks','Photographers','Cards & Stationery','Fishing','Boat Charters','Bowling','Arcades','Airports','Escape Games','Boating','Casinos','Beaches','Art Museums']
medical = ['Hospitals','Urgent Care','Doctors','Dentists','General Dentistry','Eyewear & Opticians','Medical Centers','Cosmetic Dentists','Chiropractors','Optometrists','Reflexology','Orthodontists','Periodontists','Medical Cannabis Referrals','Pain Management','Surgeons','Allergists','Anesthesiologists','Body Contouring','Dialysis Clinics','Reproductive Health Services','Memory Care','Preventive Medicine','Lice Services','Medical Transportation','Prosthodontists','CPR Classes','Retina Specialists','Nephrologists','Sex Therapists','Ophthalmologists','Obstetricians & Gynecologists','Dermatologists','Physical Therapy','Oral Surgeons','Pharmacy','Pediatric Dentists','Family Practice','Diagnostic Services']
nightlife = ['Dance Clubs','Strip Clubs','Adult Entertainment','Dance Clubs']
home_services = ['Garage Door Services','Laundry Services','Nurseries & Gardening','Home & Garden','Building Supplies','Movers','Apartments','Real Estate','Contractors','Heating & Air Conditioning/HVAC','Furniture Stores','Home Decor','Plumbing','Appliances & Repair','Mattresses','Sewing & Alterations','Home Cleaning','Appliances','Pest Control','Property Management','Landscaping','Kitchen & Bath','Real Estate Agents','Electricians','Carpeting','Packing Services','Commercial Real Estate','Decks & Railing','Chimney Sweeps','Countertop Installation','Home Network Installation','Roof Inspectors','Outdoor Power Equipment Services','Home & Rental Insurance','House Sitters','Assisted Living Facilities','Bounce House Rentals','Awnings','Safety Equipment','Internet Service Providers','Windows Installation','Roofing','Carpet Cleaning','Flooring','Security Systems','Keys & Locksmiths','Tree Services','Water Heater Installation/Repair']
shopping = ['Electronics','Mobile Phones','Bridal','Discount Store','Hardware Stores','Antiques','Department Stores','Jewelry','Fashion','Sporting Goods',"Women's Clothing",'Drugstores','Convenience Stores','Accessories','Trainers','Health Markets','Shopping Centers','Shoe Stores','Thrift Stores',"Men's Clothing",'Piercing','Tobacco Shops','Hobby Shops','Shoe Repair','Screen Printing/T-Shirt Printing','Rugs','Hunting & Fishing Supplies','Wigs','Sunglasses','Hockey Equipment','Storefront Clinics','Snorkeling','Perfume','Local Fish Stores','Concept Shops','Jewelry Repair','Bike Repair/Maintenance','Watches','Guns & Ammo','Vape Shops',"Children's Clothing",'Mobile Phone Repair','Spray Tanning','Electronics Repair','Computers','Sports Wear','Bikes','Toy Stores','Printing Services','Music & DVDs','Bookstores','Outdoor Gear','IT Services & Computer Repair','Street Vendors']
coffee_tea = ['Bubble Tea','Coffee Roasteries','Tea Rooms','Internet Cafes']
pets = ['Pet Services','Veterinarians','Pet Stores','Pet Hospice','Pet Insurance','Pet Photography','Pet Groomers','Pets']
groceries = ['Fruits & Veggies','Wholesale Stores','Wholesalers','Organic Stores','Farmers Market','Meat Shops']
legal = ['Public Services & Government','Shipping Centers','Self Storage','Legal Services','Divorce & Family Law','Billing Services','Land Surveying','Fingerprinting','Traffic Ticketing Law','Investing','Excavation Services','Aestheticians','Environmental Abatement','Junk Removal & Hauling','Legal Services','Home Inspectors','Towing','Couriers & Delivery Services','Financial Services','Notaries','Real Estate Services','Transportation']
florist = ['Florists','Gift Shops']
education = ['Books','Bookbinding','Career Counseling','Tutoring Centers','Parenting Classes','Buddhist Temples','Architects','Religious Schools','Vocal Coach','Self-defense Classes','Bail Bondsmen','Day Camps','Smog Check Stations','Bookbinding','Religious Organizations','Community Service/Non-Profit','Specialty Schools','Education']

# %%
import numpy as np

# %%
filtered_dataset['Main_Category'] = np.select(
    [
        filtered_dataset['category'].isin(restaurant_categories),
        filtered_dataset['category'].isin(beauty),
        filtered_dataset['category'].isin(bars),
        filtered_dataset['category'].isin(hotels),
        filtered_dataset['category'].isin(auto),
        filtered_dataset['category'].isin(venues),
        filtered_dataset['category'].isin(fitness),
        filtered_dataset['category'].isin(entertainment),
        filtered_dataset['category'].isin(medical),
        filtered_dataset['category'].isin(nightlife),
        filtered_dataset['category'].isin(home_services),
        filtered_dataset['category'].isin(shopping),
        filtered_dataset['category'].isin(coffee_tea),
        filtered_dataset['category'].isin(pets),
        filtered_dataset['category'].isin(groceries),
        filtered_dataset['category'].isin(legal),
        filtered_dataset['category'].isin(florist),
        filtered_dataset['category'].isin(education)
    ],
    [
        'Restaurant',
        'Beauty',
        'Bars',
        'Hotels',
        'Auto',
        'Venues',
        'Fitness',
        'Entertainment',
        'Medical',
        'Nightlife',
        'Home_Services',
        'Shopping',
        'Coffee_Tea',
        'Pets',
        'Groceries',
        'Legal',
        'Florist',
        'Education'
    ],
    default='Other'
)
# Out:
# /var/folders/x3/42y9jxy964lg3yyk_9zhss280000gn/T/ipykernel_68498/241104135.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dataset['Main_Category'] = np.select(

# %%
filtered_dataset
# Out:
#                        business_id                 user_id  \
# Unnamed: 0
# 0           ZeJjnl4o5sffMxPTt7h6ug  CNPZ2ZjDu-lNPKi6f5wEIA
# 1           Ccs-77XZCWf1aOozv6U-Ww  nJVAtTBB-25RiomzBB8bHw
# 2           FHdgpBT2Br7BL-V3gglIkA  zZOjl_mlBoqJN22dD5nbpQ
# 3           FHdgpBT2Br7BL-V3gglIkA  DWO5d7GJWB2Mmuv67yY_fQ
# 4           FHdgpBT2Br7BL-V3gglIkA  fJrZ-1B0ngdgM_2qQY_6BA
# ...                            ...                     ...
# 327656      sjwuxotWDxG__ebwcn5eOw  eWBvAeUTsm2dvIbToF0kGg
# 327657      HuoKX6R9VC5yn9xj-xUT8w  7ThsVyQniXAH0THHqQpLJw
# 327658      HuoKX6R9VC5yn9xj-xUT8w  YbgXTYO_87L1GzIrmHHoiQ
# 327659      r_kRUzLVOws0qdSXINGuQA  qvPylVHr8-0_hmjDl2iX4g
# 327660      XZGOTAmHF1fdOfXMES3kaA  yR6bO_X610KIJZm2i8uOiw
#
#                                                          text  cool  stars  \
# Unnamed: 0
# 0           I tried to give this company the benefit of th...     0    1.0
# 1           We ended up here through serendipity... White ...     0    5.0
# 2           Bouncers were actively enforcing CDC/ social d...     0    5.0
# 3           Its a place that I comfortable but I hate when...     0    2.0
# 4           Great food and great staff! There racks Mack b...     0    5.0
# ...                                                       ...   ...    ...
# 327656      This family run business is wonderful.. I call...     0    5.0
# 327657      Was there last night, great food all around.  ...     0    5.0
# 327658      Amazing food! A very cozy atmosphere. As good ...     0    5.0
# 327659      Came in for the Eagles game and had a wonderfu...     0    5.0
# 327660      I always shop here. The salespeople are honest...     0    5.0
#
#                                  date  funny               review_id  useful  \
# Unnamed: 0
# 0           2015-09-09 15:02:48+00:00      0  Zs2sKoUKASUe_WsGpQuE8A       5
# 1           2017-11-18 19:59:59+00:00      0  Eju6FaSp93TC_g06mwwFzA       0
# 2           2020-06-27 04:51:22+00:00      0  ulSlOe8dnv8mjLvLtly8hQ       0
# 3           2016-01-08 22:35:17+00:00      0  dISAAuF9njJb6pT2J1ILuQ       0
# 4           2019-04-12 20:31:51+00:00      0  MlSZu7iI4pbCl7MY0eFXgA       0
# ...                               ...    ...                     ...     ...
# 327656      2020-05-05 19:20:38+00:00      0  aUEPrisZwthJpWTDXGucyA       0
# 327657      2013-08-23 00:28:20+00:00      0  9DWpXzU0wI0sJXmaqQWe9g       1
# 327658      2015-04-08 22:53:47+00:00      0  0ys_6YRgC5xrsU8bzQ2RdQ       0
# 327659      2018-10-28 17:12:19+00:00      0  EIhs_ZGmYcANgXvuTHC9Rw       0
# 327660      2019-08-05 20:01:46+00:00      0  e6_Ji3VFnxr6Jau-zG5vAA       0
#
#             average_user_stars  ...                             city  state  \
# Unnamed: 0                      ...
# 0                         2.20  ...                              kop     PA
# 1                         2.82  ...                             Atco     NJ
# 2                         3.67  ...                             Atco     NJ
# 3                         3.85  ...                             Atco     NJ
# 4                         3.67  ...                             Atco     NJ
# ...                        ...  ...                              ...    ...
# 327656                    1.73  ...         Feasterville-Trevose, PA     PA
# 327657                    5.00  ...        West Collingswood Heights     NJ
# 327658                    4.00  ...        West Collingswood Heights     NJ
# 327659                    5.00  ...       Lower Southampton Township     PA
# 327660                    4.07  ...  Philadelphia (Northeast Philly)     PA
#
#              latitude  longitude average_business_stars  recieved_reviews  \
# Unnamed: 0
# 0           40.102683 -75.355972                    2.0                70
# 1           39.738343 -74.886403                    4.5                53
# 2           39.772589 -74.900347                    3.0                58
# 3           39.772589 -74.900347                    3.0                58
# 4           39.772589 -74.900347                    3.0                58
# ...               ...        ...                    ...               ...
# 327656      40.146638 -74.995226                    4.5                57
# 327657      39.892485 -75.091006                    3.5               121
# 327658      39.892485 -75.091006                    3.5               121
# 327659      40.148549 -75.022480                    4.0                18
# 327660      40.046024 -75.060111                    3.0                27
#
#                                                    categories  \
# Unnamed: 0
# 0                             Automotive, Auto Repair, Towing
# 1                        Food, Arts & Entertainment, Wineries
# 2           American (Traditional), Nightlife, Bars, Sport...
# 3           American (Traditional), Nightlife, Bars, Sport...
# 4           American (Traditional), Nightlife, Bars, Sport...
# ...                                                       ...
# 327656      Appliances & Repair, Home Services, Local Serv...
# 327657                            Italian, Pizza, Restaurants
# 327658                            Italian, Pizza, Restaurants
# 327659                                        Breweries, Food
# 327660      Home & Garden, Mattresses, Appliances, Compute...
#
#                                                    attributes  \
# Unnamed: 0
# 0                     {'BusinessAcceptsCreditCards': 'False'}
# 1           {'GoodForKids': 'False', 'RestaurantsPriceRang...
# 2           {'Alcohol': "u'full_bar'", 'BusinessAcceptsCre...
# 3           {'Alcohol': "u'full_bar'", 'BusinessAcceptsCre...
# 4           {'Alcohol': "u'full_bar'", 'BusinessAcceptsCre...
# ...                                                       ...
# 327656      {'BusinessAcceptsCreditCards': 'True', 'Busine...
# 327657      {'Alcohol': "u'full_bar'", 'RestaurantsPriceRa...
# 327658      {'Alcohol': "u'full_bar'", 'RestaurantsPriceRa...
# 327659      {'RestaurantsTakeOut': 'True', 'BusinessAccept...
# 327660      {'BusinessAcceptsCreditCards': 'True', 'Restau...
#
#                           category  Main_Category
# Unnamed: 0
# 0                       Automotive          Other
# 1                             Food     Restaurant
# 2           American (Traditional)     Restaurant
# 3           American (Traditional)     Restaurant
# 4           American (Traditional)     Restaurant
# ...                            ...            ...
# 327656         Appliances & Repair  Home_Services
# 327657                     Italian     Restaurant
# 327658                     Italian     Restaurant
# 327659                   Breweries           Bars
# 327660               Home & Garden  Home_Services
#
# [310287 rows x 23 columns]

# %%
filtered_dataset['Main_Category'].value_counts()
# Out:
# Main_Category
# Restaurant       138338
# Other             91445
# Bars              30991
# Beauty            14640
# Shopping           6632
# Home_Services      6132
# Auto               5539
# Entertainment      4155
# Medical            2773
# Hotels             2113
# Venues             1868
# Legal              1278
# Fitness            1075
# Pets                815
# Education           753
# Coffee_Tea          546
# Groceries           541
# Nightlife           393
# Florist             260
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
top_10_categories = filtered_dataset['Main_Category'].value_counts().sort_values(ascending=False).head(10)
plt.figure(figsize=(10, 8))
top_10_categories.plot(kind='bar')
plt.title('Top 10 Location Categories')
plt.xlabel('Category')
plt.ylabel('Number of Locations')
plt.show()

# %%
filtered_dataset.drop(columns=['categories'], inplace = True)
# Out:
# /var/folders/x3/42y9jxy964lg3yyk_9zhss280000gn/T/ipykernel_68498/582518720.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dataset.drop(columns=['categories'], inplace = True)

# %%
filtered_dataset
# Out:
#                        business_id                 user_id  \
# Unnamed: 0
# 0           ZeJjnl4o5sffMxPTt7h6ug  CNPZ2ZjDu-lNPKi6f5wEIA
# 1           Ccs-77XZCWf1aOozv6U-Ww  nJVAtTBB-25RiomzBB8bHw
# 2           FHdgpBT2Br7BL-V3gglIkA  zZOjl_mlBoqJN22dD5nbpQ
# 3           FHdgpBT2Br7BL-V3gglIkA  DWO5d7GJWB2Mmuv67yY_fQ
# 4           FHdgpBT2Br7BL-V3gglIkA  fJrZ-1B0ngdgM_2qQY_6BA
# ...                            ...                     ...
# 327656      sjwuxotWDxG__ebwcn5eOw  eWBvAeUTsm2dvIbToF0kGg
# 327657      HuoKX6R9VC5yn9xj-xUT8w  7ThsVyQniXAH0THHqQpLJw
# 327658      HuoKX6R9VC5yn9xj-xUT8w  YbgXTYO_87L1GzIrmHHoiQ
# 327659      r_kRUzLVOws0qdSXINGuQA  qvPylVHr8-0_hmjDl2iX4g
# 327660      XZGOTAmHF1fdOfXMES3kaA  yR6bO_X610KIJZm2i8uOiw
#
#                                                          text  cool  stars  \
# Unnamed: 0
# 0           I tried to give this company the benefit of th...     0    1.0
# 1           We ended up here through serendipity... White ...     0    5.0
# 2           Bouncers were actively enforcing CDC/ social d...     0    5.0
# 3           Its a place that I comfortable but I hate when...     0    2.0
# 4           Great food and great staff! There racks Mack b...     0    5.0
# ...                                                       ...   ...    ...
# 327656      This family run business is wonderful.. I call...     0    5.0
# 327657      Was there last night, great food all around.  ...     0    5.0
# 327658      Amazing food! A very cozy atmosphere. As good ...     0    5.0
# 327659      Came in for the Eagles game and had a wonderfu...     0    5.0
# 327660      I always shop here. The salespeople are honest...     0    5.0
#
#                                  date  funny               review_id  useful  \
# Unnamed: 0
# 0           2015-09-09 15:02:48+00:00      0  Zs2sKoUKASUe_WsGpQuE8A       5
# 1           2017-11-18 19:59:59+00:00      0  Eju6FaSp93TC_g06mwwFzA       0
# 2           2020-06-27 04:51:22+00:00      0  ulSlOe8dnv8mjLvLtly8hQ       0
# 3           2016-01-08 22:35:17+00:00      0  dISAAuF9njJb6pT2J1ILuQ       0
# 4           2019-04-12 20:31:51+00:00      0  MlSZu7iI4pbCl7MY0eFXgA       0
# ...                               ...    ...                     ...     ...
# 327656      2020-05-05 19:20:38+00:00      0  aUEPrisZwthJpWTDXGucyA       0
# 327657      2013-08-23 00:28:20+00:00      0  9DWpXzU0wI0sJXmaqQWe9g       1
# 327658      2015-04-08 22:53:47+00:00      0  0ys_6YRgC5xrsU8bzQ2RdQ       0
# 327659      2018-10-28 17:12:19+00:00      0  EIhs_ZGmYcANgXvuTHC9Rw       0
# 327660      2019-08-05 20:01:46+00:00      0  e6_Ji3VFnxr6Jau-zG5vAA       0
#
#             average_user_stars  ...                          name  \
# Unnamed: 0                      ...
# 0                         2.20  ...  Samantha's Towing & Recovery
# 1                         2.82  ...  Amalthea Cellars Farm Winery
# 2                         3.67  ...             Racks Pub & Grill
# 3                         3.85  ...             Racks Pub & Grill
# 4                         3.67  ...             Racks Pub & Grill
# ...                        ...  ...                           ...
# 327656                    1.73  ...    Fischer's Appliance Repair
# 327657                    5.00  ...                        Rexy's
# 327658                    4.00  ...                        Rexy's
# 327659                    5.00  ...     Moss Mill Brewing Company
# 327660                    4.07  ...            P.C. Richard & Son
#
#                                        city state   latitude  longitude  \
# Unnamed: 0
# 0                                       kop    PA  40.102683 -75.355972
# 1                                      Atco    NJ  39.738343 -74.886403
# 2                                      Atco    NJ  39.772589 -74.900347
# 3                                      Atco    NJ  39.772589 -74.900347
# 4                                      Atco    NJ  39.772589 -74.900347
# ...                                     ...   ...        ...        ...
# 327656             Feasterville-Trevose, PA    PA  40.146638 -74.995226
# 327657            West Collingswood Heights    NJ  39.892485 -75.091006
# 327658            West Collingswood Heights    NJ  39.892485 -75.091006
# 327659           Lower Southampton Township    PA  40.148549 -75.022480
# 327660      Philadelphia (Northeast Philly)    PA  40.046024 -75.060111
#
#             average_business_stars  recieved_reviews  \
# Unnamed: 0
# 0                              2.0                70
# 1                              4.5                53
# 2                              3.0                58
# 3                              3.0                58
# 4                              3.0                58
# ...                            ...               ...
# 327656                         4.5                57
# 327657                         3.5               121
# 327658                         3.5               121
# 327659                         4.0                18
# 327660                         3.0                27
#
#                                                    attributes  \
# Unnamed: 0
# 0                     {'BusinessAcceptsCreditCards': 'False'}
# 1           {'GoodForKids': 'False', 'RestaurantsPriceRang...
# 2           {'Alcohol': "u'full_bar'", 'BusinessAcceptsCre...
# 3           {'Alcohol': "u'full_bar'", 'BusinessAcceptsCre...
# 4           {'Alcohol': "u'full_bar'", 'BusinessAcceptsCre...
# ...                                                       ...
# 327656      {'BusinessAcceptsCreditCards': 'True', 'Busine...
# 327657      {'Alcohol': "u'full_bar'", 'RestaurantsPriceRa...
# 327658      {'Alcohol': "u'full_bar'", 'RestaurantsPriceRa...
# 327659      {'RestaurantsTakeOut': 'True', 'BusinessAccept...
# 327660      {'BusinessAcceptsCreditCards': 'True', 'Restau...
#
#                           category  Main_Category
# Unnamed: 0
# 0                       Automotive          Other
# 1                             Food     Restaurant
# 2           American (Traditional)     Restaurant
# 3           American (Traditional)     Restaurant
# 4           American (Traditional)     Restaurant
# ...                            ...            ...
# 327656         Appliances & Repair  Home_Services
# 327657                     Italian     Restaurant
# 327658                     Italian     Restaurant
# 327659                   Breweries           Bars
# 327660               Home & Garden  Home_Services
#
# [310287 rows x 22 columns]

# %%
state_location_counts = filtered_dataset['state'].value_counts().head(10)
plt.figure(figsize=(10, 8))
state_location_counts.sort_values(ascending = False).plot(kind='bar', color = 'Orange')
plt.title('Top 10 State Locations')
plt.xlabel('Number of Locations')
plt.ylabel('Category')
plt.show()
