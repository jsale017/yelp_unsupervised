# %%
import pandas as pd

test_sample = pd.read_csv('under-sample.csv')
# Out:
# /var/folders/zp/sq6bzsp91fz1sl3107mgk5gc0000gn/T/ipykernel_18808/2574737977.py:3: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   test_sample = pd.read_csv('under-sample.csv')

# %%
import re

# %%
test_sample
# Out:
#         Unnamed: 0             business_id                 user_id  \
# 0                0  4AxmAGObMPTDqbJK3EgNgQ  WDX_KkxwI8VYOF3RHpNLpA
# 1                1  II7CpZjGyx8aFTu3wJbQNw  pgh8UtO2K13GVMv4Ih-jEw
# 2                2  ul0MGusQZBGo4CqiVh6VcA  vgiUst2zH7Zzs2FdISwQdQ
# 3                3  4vvu78FMlZyQwZf0bBUkLQ  ZzFwLI4AC9MyCBwY-kulEA
# 4                4  mRtGKvoxQLSh-tf2qBBoLg  6903ibtDSpwMDvD9Yp33wg
# ...            ...                     ...                     ...
# 327975      327975  YNAFgpoVfg1LQmxKpOh8jQ  z7THtOjTBf2hFgUU46MGlw
# 327976      327976  kGY6SZKnu9g-yWCpEGZs6w  QNvibXA1_DAqpxxQgRLpyQ
# 327977      327977  duYoXnIsUygOWz8SjLThzA  INkmTXqkvsIldZ8wMeHzqA
# 327978      327978  zQ-CO0jHvJEsr3HRWHnobw  tSXM662aLwGS_RsVzeINAA
# 327979      327979  zQ-CO0jHvJEsr3HRWHnobw  lAW03ccfMEuRZiDqvVgc0w
#
#                                                      text  cool  stars  \
# 0       I discovered my new favorite food truck in the...     1    5.0
# 1       Sean Byrd was our guide on the City Tour. He w...     0    5.0
# 2       Super fun parade on the Sunday afternoon befor...     1    5.0
# 3       Horrible. I had read boisterous articles compa...     0    1.0
# 4       I ordered an Arnold Palmer over the sweltering...     0    2.0
# ...                                                   ...   ...    ...
# 327975  Good selections of on tap craft brews, good se...     0    2.0
# 327976  I recently moved to the area from California a...     1    5.0
# 327977  What can I say...\n\nWe went to the St Albert ...     1    1.0
# 327978  Nello's is one of my all time favorites. I alw...     0    5.0
# 327979  I've come here twice now for dinner.\n\nThe re...     2    4.0
#
#                              date  funny               review_id  useful  ...  \
# 0       2016-01-21 06:21:55+00:00      0  fVBt5kq8lyVSK2RcpY9XQA       2  ...
# 1       2021-01-24 21:04:52+00:00      0  3Sjk89h1OLVdEm9fqoggnQ       1  ...
# 2       2016-02-13 17:40:22+00:00      1  E5-7WlkTKnnC0XlsALwRfg       1  ...
# 3       2019-05-26 18:45:25+00:00      1  JYGPNWLy8uxnxzjdNPWBQw       0  ...
# 4       2013-09-05 23:17:55+00:00      0  EA0FGcHTsgBcGpa_e1g7GA       0  ...
# ...                           ...    ...                     ...     ...  ...
# 327975  2018-04-23 19:41:56+00:00      0  vzRQ6fMxna6EJ_Q6Hkrs7A       0  ...
# 327976  2015-03-11 08:43:57+00:00      1  E-12Xayd4_PrlBGNk_-kbQ       5  ...
# 327977  2015-06-08 04:45:23+00:00      0  m2vkgIRl9dMIeibvF-G6MQ       0  ...
# 327978  2019-06-10 01:51:46+00:00      0  u_pVvrejJC9a2vJ9rLca9g       0  ...
# 327979  2017-03-02 21:50:46+00:00      1  Vw8p9ZhTiD5YZzjvXOBvUg       7  ...
#
#                                  address          city  state latitude  \
# 0                                    NaN          Reno     NV      NaN
# 1                                    NaN   New Orleans     LA      NaN
# 2                          St Charles Ae   New Orleans     LA      NaN
# 3                        Pennsylvania St  Indianapolis     IN      NaN
# 4                     18th St & Logan Sq  Philadelphia     PA      NaN
# ...                                  ...           ...    ...      ...
# 327975               16 Rayborn Crescent  Saint Albert     AB  T8N 4B1
# 327976               205A Carnegie Drive    St. Albert     AB  T8N 5B2
# 327977                A-388 St Albert Rd    St. Albert     AB  T8N 5N6
# 327978  512 Saint Albert Trail, Suite 4A     St Albert     AB  T8N 5Z1
# 327979  512 Saint Albert Trail, Suite 4A     St Albert     AB  T8N 5Z1
#
#          longitude average_business_stars recieved_reviews  \
# 0      -119.813803                    4.5             11.0
# 1       -90.077750                    5.0              6.0
# 2       -90.080723                    4.5              9.0
# 3       -86.155944                    3.5             11.0
# 4       -75.168697                    3.5             34.0
# ...            ...                    ...              ...
# 327975 -113.642913                    3.5             15.0
# 327976 -113.576604                    4.0              7.0
# 327977 -113.626233                    2.5             11.0
# 327978 -113.629268                    4.0             57.0
# 327979 -113.629268                    4.0             57.0
#
#                                                categories  \
# 0                  Food, German, Food Trucks, Restaurants
# 1                       Hotels & Travel, Bus Tours, Tours
# 2                                            Local Flavor
# 3           Arts & Entertainment, Festivals, Local Flavor
# 4                            Food, Bakeries, Coffee & Tea
# ...                                                   ...
# 327975  Bars, Restaurants, Food, Beer, Wine & Spirits,...
# 327976  Pilates, Health & Medical, Fitness & Instructi...
# 327977  Fast Food, Ice Cream & Frozen Yogurt, Restaura...
# 327978  Mediterranean, Restaurants, Gluten-Free, Itali...
# 327979  Mediterranean, Restaurants, Gluten-Free, Itali...
#
#                                                attributes  \
# 0       {'BusinessAcceptsCreditCards': 'True', 'Alcoho...
# 1                                                     NaN
# 2                                 {'GoodForKids': 'True'}
# 3                                 {'GoodForKids': 'True'}
# 4       {'RestaurantsPriceRange2': '2', 'BusinessParki...
# ...                                                   ...
# 327975  {'RestaurantsReservations': 'True', 'Restauran...
# 327976  {'GoodForKids': 'True', 'ByAppointmentOnly': '...
# 327977  {'WiFi': "u'no'", 'NoiseLevel': "u'very_loud'"...
# 327978  {'OutdoorSeating': 'False', 'BikeParking': 'Fa...
# 327979  {'OutdoorSeating': 'False', 'BikeParking': 'Fa...
#
#                                           tip_review
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 327975                                           NaN
# 327976                                           NaN
# 327977                                           NaN
# 327978                                           NaN
# 327979  Delicious lattes!  Get it with the Tiramisu!
#
# [327980 rows x 24 columns]

# %%
text = test_sample['text']

# %%
text_df = pd.DataFrame(text)
text_df
# Out:
#                                                      text
# 0       I discovered my new favorite food truck in the...
# 1       Sean Byrd was our guide on the City Tour. He w...
# 2       Super fun parade on the Sunday afternoon befor...
# 3       Horrible. I had read boisterous articles compa...
# 4       I ordered an Arnold Palmer over the sweltering...
# ...                                                   ...
# 327975  Good selections of on tap craft brews, good se...
# 327976  I recently moved to the area from California a...
# 327977  What can I say...\n\nWe went to the St Albert ...
# 327978  Nello's is one of my all time favorites. I alw...
# 327979  I've come here twice now for dinner.\n\nThe re...
#
# [327980 rows x 1 columns]

# %%
text_df= pd.DataFrame(text_df.text.str.lower())
text_df = pd.DataFrame(text_df.text.str.replace('\n\n',''))
text_df = pd.DataFrame(text_df.text.str.replace('/[^a-zA-Z0-9 ]/g', ""))
text_df = pd.DataFrame(text_df['text'].str.replace(r'\.', ''))

# %%
pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in /Users/josesalerno/Library/Python/3.9/lib/python/site-packages (3.8.1)
# Requirement already satisfied: joblib in /Users/josesalerno/Library/Python/3.9/lib/python/site-packages (from nltk) (1.3.2)
# Requirement already satisfied: click in /Users/josesalerno/Library/Python/3.9/lib/python/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: tqdm in /Users/josesalerno/Library/Python/3.9/lib/python/site-packages (from nltk) (4.66.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/josesalerno/Library/Python/3.9/lib/python/site-packages (from nltk) (2023.12.25)
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/josesalerno/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
reviews = text_df['text'].tolist()
tokenized_sentences = [word_tokenize(review) for review in reviews]
# Out:
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x10555edc0>>
# Traceback (most recent call last):
#   File "/Users/josesalerno/Library/Python/3.9/lib/python/site-packages/ipykernel/ipkernel.py", line 770, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
# KeyboardInterrupt:

# %%
tokenized_sentences
# Out:
# [['i',
#   'discovered',
#   'my',
#   'new',
#   'favorite',
#   'food',
#   'truck',
#   'in',
#   'the',
#   'reno/sparks',
#   'area',
#   'a',
#   'few',
#   'days',
#   'ago',
#   '.',
#   'schnitzel',
#   "'s",
#   'austrian',
#   'grill',
#   'is',
#   'amazing',
#   '!',
#   'it',
#   'is',
#   'also',
#   'a',
#   'wonderful',
#   'place',
#   'to',
#   'eat',
#   'gluten',
#   'free',
#   '.',
#   'basically',
#   ',',
#   'everything',
#   'except',
#   'their',
#   'bread',
#   'can',
#   'be',
#   '(',
#   'or',
#   'already',
#   'is',
#   ')',
#   'gluten',
#   'free.for',
#   'those',
#   'who',
#   'eat',
#   'gluten',
#   'free',
#   'by',
#   'choice',
#   ',',
#   'it',
#   'sounds',
#   'like',
#   'you',
#   'can',
#   'eat',
#   'their',
#   'gf',
#   'ciabatta',
#   '...',
#   'but',
#   'she',
#   'does',
#   "n't",
#   'feel',
#   'safe',
#   'serving',
#   'it',
#   'to',
#   'people',
#   'who',
#   'are',
#   'celiac',
#   'or',
#   'have',
#   'allergic',
#   'issues',
#   'right',
#   'now',
#   '.',
#   '(',
#   'there',
#   'may',
#   'be',
#   'a',
#   'cross',
#   'contamination',
#   'issue',
#   'with',
#   'the',
#   'supplier',
#   'currently',
#   '.',
#   ')',
#   'kirsten',
#   'is',
#   'extremely',
#   'personable',
#   'and',
#   'very',
#   'knowledgeable',
#   'about',
#   'gluten',
#   'issues',
#   '!',
#   'i',
#   'ordered',
#   'the',
#   '(',
#   'gluten',
#   'free',
#   ')',
#   'pork',
#   'schnitzel',
#   'with',
#   'red',
#   'beet',
#   'and',
#   'apple',
#   'salad',
#   ',',
#   'cucumber',
#   'salad',
#   ',',
#   'and',
#   'ligonberry',
#   'jam',
#   '.',
#   'it',
#   'is',
#   'shocking',
#   'how',
#   'wonderful',
#   'this',
#   'schnitzel',
#   'is',
#   'with',
#   'a',
#   'gluten',
#   'free',
#   'breading',
#   '.',
#   'it',
#   'is',
#   'perfect',
#   '...',
#   'not',
#   'too',
#   'dry',
#   ',',
#   'soggy',
#   ',',
#   'nor',
#   'too',
#   'thick.the',
#   'platters',
#   'come',
#   'with',
#   'two',
#   'sides',
#   'and',
#   'one',
#   'condiment',
#   '.',
#   'they',
#   'also',
#   'serve',
#   'their',
#   'entrees',
#   'as',
#   'a',
#   'sandwich.i',
#   'also',
#   'had',
#   'the',
#   'opportunity',
#   'to',
#   'sample',
#   'several',
#   'of',
#   'their',
#   'items',
#   'and',
#   'loved',
#   'everything',
#   '.',
#   'my',
#   'favorite',
#   'sides',
#   'were',
#   'the',
#   'red',
#   'beet',
#   'and',
#   'apple',
#   'salad',
#   '(',
#   'this',
#   'was',
#   'crazy',
#   'good',
#   'even',
#   'though',
#   'it',
#   'sounded',
#   'a',
#   'bit',
#   'odd',
#   'to',
#   'me',
#   'at',
#   'first',
#   ')',
#   ',',
#   'cucumber',
#   'salad',
#   ',',
#   'chilled',
#   'chickpea',
#   'salad',
#   ',',
#   'and',
#   'sauerkraut',
#   '.',
#   'their',
#   'other',
#   'sides',
#   'are',
#   'austrian',
#   'potato',
#   'salad',
#   ',',
#   'mixed',
#   'salad',
#   ',',
#   'and',
#   'french',
#   'fries.my',
#   'favorite',
#   'entree',
#   'currently',
#   'is',
#   'the',
#   'pork',
#   'schnitzel',
#   '.',
#   'i',
#   'can',
#   'not',
#   'wait',
#   'to',
#   'try',
#   'their',
#   'fish',
#   'schnitzel',
#   '.',
#   'i',
#   'arrived',
#   'later',
#   'in',
#   'their',
#   'day',
#   ',',
#   'so',
#   'they',
#   'had',
#   'run',
#   'out',
#   'of',
#   'the',
#   'fish',
#   '(',
#   'i',
#   'believe',
#   'it',
#   "'s",
#   'haddock',
#   ')',
#   '.',
#   'i',
#   'also',
#   'got',
#   'to',
#   'sample',
#   'their',
#   'bratwurst',
#   ',',
#   'currywurst',
#   ',',
#   'and',
#   'cranberry',
#   'horseradish',
#   'cream',
#   '.',
#   'oh',
#   'my',
#   '!',
#   'their',
#   'bratwurst',
#   'is',
#   'an',
#   'authentic',
#   'german',
#   'bratwurst',
#   'and',
#   'in',
#   'my',
#   'opinion',
#   'is',
#   'honestly',
#   'the',
#   'tastiest',
#   'sausage',
#   'in',
#   'town',
#   '!',
#   'it',
#   'has',
#   'a',
#   'perfect',
#   'snap',
#   'when',
#   'you',
#   'bite',
#   'into',
#   'it',
#   'and',
#   'tremendous',
#   'flavors',
#   '.',
#   'i',
#   'was',
#   'a',
#   'bit',
#   'hesitant',
#   'to',
#   'sample',
#   'the',
#   'currywurst',
#   ',',
#   'because',
#   'i',
#   'have',
#   'never',
#   'been',
#   'a',
#   'fan',
#   'of',
#   'curry',
#   '.',
#   'maybe',
#   'i',
#   'have',
#   "n't",
#   'had',
#   'good',
#   'curry',
#   'the',
#   'few',
#   'times',
#   'i',
#   "'ve",
#   'had',
#   'it',
#   'before',
#   '(',
#   'who',
#   'knows',
#   ')',
#   '....',
#   'but',
#   'this',
#   'was',
#   'so',
#   'good',
#   'that',
#   'i',
#   'wished',
#   'i',
#   'had',
#   'some',
#   'bread',
#   'to',
#   'sop',
#   'the',
#   'rest',
#   'of',
#   'it',
#   'up',
#   '.',
#   'now',
#   'about',
#   'the',
#   'cranberry',
#   'horseradish',
#   'cream',
#   '.',
#   'aaaamazing',
#   '!',
#   '!',
#   '!',
#   'i',
#   'know',
#   'it',
#   'may',
#   'sound',
#   'a',
#   'bit',
#   'crazy',
#   'and',
#   'i',
#   'am',
#   'not',
#   'really',
#   'into',
#   'straight',
#   'horseradish',
#   ',',
#   'but',
#   'this',
#   'is',
#   'crazy',
#   'good',
#   'and',
#   'slightly',
#   'tamer',
#   'than',
#   'a',
#   'nice',
#   'quality',
#   'wasabi',
#   '.',
#   'i',
#   'totally',
#   'recommend',
#   'this',
#   'with',
#   'whatever',
#   'you',
#   'order',
#   'if',
#   'you',
#   'can',
#   'handle',
#   'some',
#   'heat.so',
#   'how',
#   'much',
#   'do',
#   'i',
#   'really',
#   'love',
#   'schnitzel',
#   "'s",
#   'austrian',
#   'grill',
#   '?',
#   'so',
#   'much',
#   'that',
#   'i',
#   'told',
#   'two',
#   'workers',
#   'i',
#   'did',
#   "n't",
#   'even',
#   'know',
#   'at',
#   'our',
#   'local',
#   'natural',
#   'grocers',
#   'later',
#   'that',
#   'day',
#   'in',
#   'quite',
#   'a',
#   'bit',
#   'of',
#   'detail',
#   'and',
#   'it',
#   'inspired',
#   'me',
#   'to',
#   'start',
#   'blogging',
#   'about',
#   'great',
#   'places',
#   'to',
#   'eat',
#   'gluten',
#   'free',
#   'in',
#   'the',
#   'reno/sparks',
#   'area',
#   '.',
#   'in',
#   'conclusion',
#   ':',
#   '*',
#   'the',
#   'food',
#   'here',
#   'is',
#   'amazing',
#   '!',
#   '*',
#   'you',
#   'can',
#   'safely',
#   'eat',
#   'gluten',
#   'free',
#   'here',
#   'with',
#   'almost',
#   'every',
#   'item',
#   'available',
#   'to',
#   'you',
#   '.',
#   '*',
#   'the',
#   'service',
#   'is',
#   'top',
#   'notch',
#   '.',
#   'i',
#   'felt',
#   'like',
#   'i',
#   'have',
#   'known',
#   'them',
#   'for',
#   'a',
#   'long',
#   'time',
#   'even',
#   'though',
#   'this',
#   'was',
#   'my',
#   'first',
#   'visit',
#   '.',
#   '*',
#   'where',
#   'else',
#   'can',
#   'you',
#   'get',
#   'amazing',
#   'gluten',
#   'free',
#   'schnitzels',
#   '?'],
#  ['sean',
#   'byrd',
#   'was',
#   'our',
#   'guide',
#   'on',
#   'the',
#   'city',
#   'tour',
#   '.',
#   'he',
#   'was',
#   'excellent',
#   '.',
#   'very',
#   'knowledgeable',
#   'and',
#   'held',
#   'everyone',
#   "'s",
#   'attention',
#   'the',
#   'entire',
#   'time',
#   '.',
#   'we',
#   'learned',
#   'so',
#   'much',
#   'about',
#   'the',
#   'city',
#   'and',
#   'surrounding',
#   'area',
#   'including',
#   'history',
#   'from',
#   'its',
#   'founding',
#   'and',
#   'including',
#   'the',
#   'hurricane',
#   'katrina',
#   'disaster',
#   'and',
#   'the',
#   'affects',
#   'of',
#   'covid',
#   '.',
#   'we',
#   'now',
#   'have',
#   'more',
#   'ideas',
#   'of',
#   'where',
#   'we',
#   'want',
#   'to',
#   'visit',
#   '.',
#   'the',
#   'only',
#   'thing',
#   'that',
#   'could',
#   'have',
#   'made',
#   'it',
#   'better',
#   'would',
#   'have',
#   'been',
#   'a',
#   'map',
#   'with',
#   'the',
#   'route',
#   'marked',
#   'because',
#   'being',
#   'from',
#   'out',
#   'of',
#   'state',
#   'and',
#   'our',
#   'first',
#   'visit',
#   ',',
#   'we',
#   'can',
#   'easily',
#   'get',
#   'direction',
#   'turned',
#   '.',
#   'plus',
#   'we',
#   'would',
#   'like',
#   'to',
#   'be',
#   'able',
#   'to',
#   'mark',
#   'on',
#   'a',
#   'map',
#   'to',
#   'know',
#   'where',
#   'we',
#   'want',
#   'to',
#   'go',
#   'on',
#   'our',
#   'own',
#   '.',
#   'we',
#   'recommend',
#   'taking',
#   'this',
#   'tour',
#   'the',
#   'very',
#   'first',
#   'day',
#   'you',
#   'visit',
#   'new',
#   'orleans',
#   '.',
#   'very',
#   'good',
#   'tour',
#   'for',
#   'the',
#   'price',
#   '.'],
#  ['super',
#   'fun',
#   'parade',
#   'on',
#   'the',
#   'sunday',
#   'afternoon',
#   'before',
#   'mardi',
#   'gras',
#   '.',
#   'the',
#   'route',
#   'is',
#   'long',
#   'and',
#   'it',
#   'runs',
#   'right',
#   'by',
#   'my',
#   'place',
#   '.',
#   'this',
#   'parade',
#   'is',
#   'unique',
#   'and',
#   'one',
#   'of',
#   'my',
#   'favorites',
#   'because',
#   'they',
#   'attempt',
#   'to',
#   'pass',
#   'in',
#   'front',
#   'of',
#   'all',
#   'the',
#   'extended',
#   'healthcare',
#   'facilities',
#   'that',
#   'care',
#   'for',
#   'people',
#   'with',
#   'disabilities',
#   'and',
#   'illnesses',
#   'in',
#   'new',
#   'orleans',
#   '.',
#   'a',
#   'generous',
#   'and',
#   'caring',
#   'krewe',
#   'that',
#   'makes',
#   'mardi',
#   'gras',
#   'and',
#   'new',
#   'orleans',
#   'so',
#   'special',
#   '!',
#   'the',
#   'floats',
#   'are',
#   'huge',
#   'and',
#   'there',
#   'are',
#   'many',
#   '.',
#   'the',
#   'riders',
#   'look',
#   'like',
#   'they',
#   "'re",
#   'having',
#   'a',
#   'blast',
#   'and',
#   'are',
#   'super',
#   'generous',
#   '.',
#   'it',
#   "'s",
#   'a',
#   'great',
#   'way',
#   'to',
#   'get',
#   'your',
#   'sunday',
#   'afternoon',
#   'started',
#   'and',
#   'carry',
#   'you',
#   'through',
#   'the',
#   'long',
#   'mardi',
#   'gras',
#   'stretch',
#   '.'],
#  ['horrible',
#   '.',
#   'i',
#   'had',
#   'read',
#   'boisterous',
#   'articles',
#   'comparing',
#   'this',
#   'parade',
#   'to',
#   'the',
#   'big',
#   'ones',
#   ',',
#   'such',
#   'as',
#   'the',
#   'macy',
#   "'s",
#   'thanksgiving',
#   'day',
#   'parade',
#   '.',
#   'now',
#   ',',
#   'i',
#   'knew',
#   'it',
#   'could',
#   "n't",
#   'be',
#   'that',
#   'good',
#   '.',
#   'but',
#   ',',
#   'i',
#   'thought',
#   'it',
#   'would',
#   'be',
#   'a',
#   'well',
#   'put',
#   'together',
#   'and',
#   'entertaining',
#   'parade',
#   '.',
#   'boy',
#   ',',
#   'was',
#   'i',
#   'wrong',
#   '.',
#   'there',
#   'were',
#   'huge',
#   'gaps',
#   'in',
#   'between',
#   'the',
#   'different',
#   '``',
#   'floats',
#   "''",
#   '(',
#   'i',
#   'use',
#   'this',
#   'term',
#   'loosely',
#   ')',
#   '.',
#   'mostly',
#   ',',
#   'it',
#   'was',
#   'marching',
#   'bands',
#   'and',
#   'maroon',
#   'camaros',
#   'carrying',
#   'indy',
#   'drivers',
#   'and',
#   'their',
#   'wives',
#   '(',
#   'who',
#   'were',
#   'taking',
#   'selfies',
#   'and',
#   'video',
#   'on',
#   'their',
#   'phones',
#   ')',
#   '.',
#   'there',
#   'were',
#   'multiple',
#   'times',
#   'where',
#   'everyone',
#   'thought',
#   'the',
#   'parade',
#   'must',
#   'be',
#   'over',
#   'because',
#   'we',
#   'had',
#   "n't",
#   'seen',
#   'anyone',
#   'else',
#   'come',
#   'by',
#   'in',
#   'quite',
#   'some',
#   'time',
#   '.',
#   'children',
#   'and',
#   'adults',
#   'alike',
#   'were',
#   'bored',
#   '.',
#   'everyone',
#   'around',
#   'us',
#   'were',
#   'whining',
#   'and',
#   'ready',
#   'to',
#   'start',
#   'the',
#   'dreaded',
#   'walk',
#   'back',
#   'to',
#   'the',
#   'car',
#   '.',
#   'and',
#   'we',
#   'did',
#   '.',
#   'we',
#   'wo',
#   "n't",
#   'be',
#   'back',
#   '.',
#   'save',
#   'your',
#   'money',
#   ',',
#   'time',
#   ',',
#   'and',
#   'sanity',
#   '.',
#   'if',
#   'you',
#   "'re",
#   'interested-',
#   'watch',
#   'it',
#   'on',
#   'tv',
#   '.'],
#  ['i',
#   'ordered',
#   'an',
#   'arnold',
#   'palmer',
#   'over',
#   'the',
#   'sweltering',
#   'labor',
#   'day',
#   'weekend',
#   '.',
#   'trying',
#   'to',
#   'cut',
#   'down',
#   'on',
#   'the',
#   'sugar',
#   'content',
#   ',',
#   'i',
#   'asked',
#   'for',
#   '1/2',
#   'unsweetened',
#   'iced',
#   'tea',
#   'and',
#   '1/2',
#   'lemonade',
#   '.',
#   'i',
#   'think',
#   'they',
#   'gave',
#   'me',
#   'sweetened',
#   'iced',
#   'tea',
#   'though',
#   'because',
#   'it',
#   'was',
#   'still',
#   'cloyingly',
#   'sweet',
#   ',',
#   'which',
#   'was',
#   'unpleasant',
#   'on',
#   'a',
#   'hot',
#   'day',
#   ',',
#   'rather',
#   'than',
#   'refreshing',
#   '.',
#   'i',
#   'think',
#   'i',
#   'would',
#   'have',
#   'preferred',
#   'starbucks',
#   'or',
#   'even',
#   'dunkin',
#   'donuts',
#   'better',
#   '.',
#   'the',
#   'location',
#   'and',
#   'decor',
#   'of',
#   'this',
#   'milk',
#   'and',
#   'honey',
#   'location',
#   'is',
#   'beautiful',
#   'and',
#   'scenic',
#   'though',
#   '.'],
#  ['i',
#   'have',
#   "n't",
#   'been',
#   'to',
#   'borden',
#   'park',
#   'in',
#   'a',
#   'few',
#   'years',
#   'and',
#   'they',
#   'had',
#   'put',
#   'in',
#   'a',
#   'few',
#   'reno',
#   "'s",
#   '.',
#   'the',
#   'washroom',
#   'area',
#   'looks',
#   'very',
#   'nice',
#   'and',
#   'clean',
#   '!',
#   'there',
#   'is',
#   'also',
#   'a',
#   'wait',
#   'area',
#   'for',
#   'people',
#   '(',
#   'families',
#   ')',
#   '.i',
#   'came',
#   'here',
#   'to',
#   'help',
#   'at',
#   'the',
#   'yelp',
#   'booth',
#   'with',
#   'jennie',
#   'for',
#   'the',
#   'porkapolloza',
#   'event',
#   '.',
#   'the',
#   'weather',
#   'was',
#   'fantastic',
#   ',',
#   'beautiful',
#   'day',
#   'and',
#   'the',
#   'smell',
#   'of',
#   'bbq',
#   'everywhere',
#   '...',
#   'great',
#   'venue',
#   ',',
#   'good',
#   'times',
#   '.',
#   'i',
#   'will',
#   'be',
#   'back',
#   '!'],
#  ['i',
#   'went',
#   'to',
#   'launch',
#   'event',
#   'for',
#   'this',
#   'years',
#   'festival',
#   'and',
#   'found',
#   'out',
#   'this',
#   'years',
#   'craft',
#   'beer',
#   'festival',
#   'is',
#   'going',
#   'to',
#   'be',
#   'even',
#   'better',
#   '!',
#   'there',
#   'are',
#   'going',
#   'to',
#   'be',
#   'new',
#   'things',
#   'to',
#   'do',
#   'and',
#   'see',
#   'such',
#   'as',
#   'beer',
#   'and',
#   'chocolate',
#   'pairings',
#   ',',
#   'new',
#   'craft',
#   'distillery',
#   'district',
#   ',',
#   'and',
#   'new',
#   'vip',
#   'experience',
#   '.',
#   'the',
#   'beer',
#   'u',
#   'section',
#   'will',
#   'be',
#   'larger',
#   'and',
#   'also',
#   'have',
#   'a',
#   'cask',
#   'stage',
#   '.',
#   'i',
#   "'m",
#   'loving',
#   'the',
#   'cask',
#   'beers',
#   '!',
#   'the',
#   'brewers',
#   'try',
#   'crazy',
#   'stuff',
#   'and',
#   'it',
#   'does',
#   "n't",
#   'always',
#   'work',
#   'out',
#   'but',
#   'on',
#   'the',
#   'other',
#   'hand',
#   ',',
#   'some',
#   'of',
#   'the',
#   'best',
#   'beer',
#   'i',
#   "'ve",
#   'ever',
#   'had',
#   'is',
#   'one',
#   'off',
#   'cask',
#   'beer',
#   '.',
#   'i',
#   'asked',
#   'about',
#   'the',
#   'new',
#   'vip',
#   'experience',
#   'and',
#   'found',
#   'out',
#   'it',
#   'now',
#   'includes',
#   'a',
#   'vip',
#   'only',
#   'washroom',
#   'area',
#   'as',
#   'well',
#   'as',
#   'a',
#   'vip',
#   'only',
#   'area',
#   '.',
#   'sounds',
#   'pretty',
#   'neat',
#   'for',
#   'when',
#   'it',
#   'gets',
#   'busy',
#   'at',
#   'the',
#   'washrooms',
#   '.',
#   'we',
#   'were',
#   'treated',
#   'to',
#   'a',
#   'wonderful',
#   'flowery',
#   'and',
#   'fruity',
#   'but',
#   'delicious',
#   'witbier',
#   'style',
#   'called',
#   '``',
#   'the',
#   'lion',
#   ',',
#   'the',
#   'wit',
#   'and',
#   'the',
#   'wardrobe',
#   "''",
#   '.',
#   'this',
#   'beer',
#   'was',
#   'brewed',
#   'by',
#   'the',
#   'olds',
#   'college',
#   'brewing',
#   'program',
#   '.',
#   'i',
#   'can',
#   'see',
#   'myself',
#   'on',
#   'a',
#   'nice',
#   'patio',
#   'somewhere',
#   'drinking',
#   'one',
#   'of',
#   'these',
#   'beers',
#   'this',
#   'summer',
#   '.',
#   'i',
#   'ca',
#   "n't",
#   'wait',
#   'for',
#   'the',
#   'edmonton',
#   'craft',
#   'beer',
#   'festival',
#   'this',
#   'year',
#   '!',
#   'so',
#   'many',
#   'breweries',
#   'making',
#   'so',
#   'many',
#   'amazing',
#   'beers',
#   '!'],
#  ['this',
#   'mall',
#   'is',
#   'just',
#   'sad',
#   '.',
#   'the',
#   'only',
#   'reasons',
#   'i',
#   'ever',
#   'go',
#   'here',
#   'are',
#   '1',
#   ')',
#   'safeway',
#   '2',
#   ')',
#   'futureshop',
#   'and',
#   '3',
#   ')',
#   'the',
#   'northgate',
#   'public',
#   'helth',
#   'centre',
#   '.',
#   'everything',
#   'else',
#   'is',
#   'pretty',
#   'abysmal',
#   '.',
#   'the',
#   'food',
#   'court',
#   'has',
#   'zip',
#   'for',
#   'options',
#   'and',
#   'most',
#   'of',
#   'the',
#   'stores',
#   'feel',
#   'either',
#   'extremely',
#   'dated',
#   'or',
#   ',',
#   'dare',
#   'i',
#   'say',
#   ',',
#   'ghetto',
#   '.',
#   'i',
#   'give',
#   'it',
#   'two',
#   'stars',
#   'because',
#   'it',
#   "'s",
#   'always',
#   'clean',
#   'and',
#   'well',
#   'cared',
#   'for',
#   'and',
#   'there',
#   'are',
#   'the',
#   'three',
#   'things',
#   'of',
#   'use',
#   'there',
#   '.',
#   'it',
#   'definitely',
#   'needs',
#   'an',
#   'update',
#   '.'],
#  ['ernest',
#   "'s",
#   'is',
#   'a',
#   'really',
#   'great',
#   'place',
#   'to',
#   'enjoy',
#   'a',
#   'fine',
#   'dining',
#   'experience',
#   'at',
#   'very',
#   'reasonable',
#   'price',
#   ',',
#   'either',
#   'to',
#   'catch',
#   'up',
#   'with',
#   'friends',
#   'or',
#   'entertain',
#   'guests',
#   '.',
#   'students',
#   'in',
#   'the',
#   'culinary',
#   'arts',
#   'and',
#   'hospitality',
#   'management',
#   'programs',
#   'work',
#   'in',
#   'the',
#   'restaurant',
#   ',',
#   'so',
#   'the',
#   'menu',
#   'does',
#   'change',
#   'quite',
#   'frequently',
#   ',',
#   'as',
#   'a',
#   'result',
#   'of',
#   'this',
#   '.',
#   'and',
#   'likely',
#   'also',
#   'changes',
#   'due',
#   'to',
#   'what',
#   'ingredients',
#   'are',
#   'available',
#   'durinf',
#   'the',
#   'season',
#   '.',
#   'i',
#   "'ve",
#   'only',
#   'been',
#   'able',
#   'to',
#   'ever',
#   'stop',
#   'in',
#   'during',
#   'dinner',
#   'service',
#   ',',
#   'but',
#   'on',
#   'friday',
#   "'s",
#   'during',
#   'lunch',
#   ',',
#   'they',
#   'often',
#   'have',
#   'a',
#   'student',
#   'showcase',
#   'buffet',
#   'which',
#   'i',
#   "'ve",
#   'always',
#   'heard',
#   'such',
#   'good',
#   'things',
#   'about',
#   '!',
#   'dinner',
#   'service',
#   'is',
#   'always',
#   'top',
#   'notch',
#   ',',
#   'and',
#   'the',
#   'food',
#   'is',
#   'always',
#   'is',
#   'creative/imaginative',
#   ',',
#   'and',
#   'plated',
#   'beautifully',
#   '.',
#   'no',
#   'matter',
#   ',',
#   'what',
#   'you',
#   'end',
#   'up',
#   'ordering',
#   ',',
#   'you',
#   'wont',
#   'end',
#   'up',
#   'disappointed',
#   '.',
#   'if',
#   'you',
#   'swing',
#   'by',
#   'on',
#   'tuesdays/wednesdays',
#   ',',
#   'they',
#   'do',
#   'offer',
#   'a',
#   'prixe',
#   'fixe',
#   'menu',
#   'which',
#   'they',
#   'change',
#   'the',
#   'name',
#   'of',
#   'from',
#   'time',
#   'to',
#   'time',
#   ',',
#   'and',
#   'even',
#   'have',
#   'the',
#   'option',
#   'of',
#   'including',
#   'a',
#   'flight',
#   'of',
#   'wine',
#   'with',
#   'each',
#   'course',
#   '!',
#   'the',
#   'only',
#   'downside',
#   'is',
#   'that',
#   'this',
#   'place',
#   'is',
#   'a',
#   'pretty',
#   'happening',
#   'place',
#   ',',
#   'and',
#   'usually',
#   'requires',
#   'a',
#   'bit',
#   'of',
#   'planning',
#   'in',
#   'advance',
#   ',',
#   'especially',
#   'if',
#   'you',
#   'want',
#   'a',
#   'friday',
#   'night',
#   'reservation',
#   'or',
#   'a',
#   'reservation',
#   'around',
#   'the',
#   'holidays',
#   '.',
#   'dinner',
#   'reservations',
#   'on',
#   'a',
#   'weeknight',
#   'are',
#   'a',
#   'lot',
#   'easier',
#   'to',
#   'manage',
#   'on',
#   'a',
#   'shorter',
#   'timeline',
#   '!',
#   'and',
#   'they',
#   'do',
#   'also',
#   'have',
#   'free',
#   'parking',
#   'after',
#   '5pm',
#   '!'],
#  ['unfortunately',
#   'my',
#   'experience',
#   'has',
#   'been',
#   'good',
#   'but',
#   'not',
#   'anything',
#   'exceptional',
#   '.',
#   'i',
#   'honestly',
#   'come',
#   'here',
#   'because',
#   'i',
#   "'m",
#   'closer',
#   'to',
#   'kingsway',
#   'garden',
#   'mall',
#   'and',
#   'going',
#   'all',
#   'the',
#   'way',
#   'to',
#   'a',
#   'davids',
#   'tea',
#   'would',
#   'be',
#   'inconvenient',
#   '.',
#   'their',
#   'tea',
#   'is',
#   'full',
#   'of',
#   'fragrant',
#   'and',
#   'the',
#   'ones',
#   'i',
#   "'ve",
#   'bought',
#   'at',
#   'teavana',
#   'have',
#   'always',
#   'been',
#   'good',
#   '.',
#   'i',
#   "'m",
#   'not',
#   'super',
#   'knowledgable',
#   'about',
#   'loose',
#   'leaf',
#   'teas',
#   ',',
#   'but',
#   'i',
#   'do',
#   'like',
#   'it',
#   'a',
#   'lot',
#   'better',
#   'than',
#   'tea',
#   'from',
#   'tea',
#   'bags',
#   '.',
#   'their',
#   'staff',
#   'seems',
#   'to',
#   'know',
#   'what',
#   'they',
#   "'re",
#   'talking',
#   'about',
#   'and',
#   'if',
#   'you',
#   'happen',
#   'to',
#   'be',
#   'looking',
#   'for',
#   'something',
#   'specific',
#   ',',
#   'they',
#   "'d",
#   'be',
#   'able',
#   'to',
#   'find',
#   'you',
#   'a',
#   'tea',
#   'you',
#   "'ll",
#   'love',
#   '.',
#   'aside',
#   'from',
#   'loose',
#   'leaf',
#   'teas',
#   ',',
#   'they',
#   'have',
#   'an',
#   'assortment',
#   'of',
#   'tea',
#   'tins',
#   ',',
#   'tea',
#   'cups',
#   ',',
#   'kettles',
#   ',',
#   'pots',
#   ',',
#   'etc',
#   '.',
#   'like',
#   'any',
#   'other',
#   'specialty',
#   'tea',
#   'shops',
#   ',',
#   'their',
#   'products',
#   'are',
#   'pricy',
#   ',',
#   'but',
#   'i',
#   'guess',
#   'you',
#   'get',
#   'what',
#   'you',
#   'pay',
#   'for',
#   '...'],
#  ['i',
#   'used',
#   'to',
#   'be',
#   'very',
#   'meh',
#   'about',
#   'this',
#   'festival',
#   ',',
#   'but',
#   'i',
#   'found',
#   'myself',
#   'in',
#   'the',
#   'neighbourhood',
#   'this',
#   'year',
#   'and',
#   'decided',
#   'to',
#   'peruse',
#   'the',
#   'stalls',
#   '-',
#   'huge',
#   'improvement',
#   ',',
#   'and',
#   'worthy',
#   'of',
#   'an',
#   'upgrade',
#   'from',
#   '2',
#   'to',
#   '3.5',
#   'stars',
#   '!',
#   'in',
#   'the',
#   'past',
#   ',',
#   'i',
#   'found',
#   'it',
#   'was',
#   'filled',
#   'with',
#   'mostly',
#   '2',
#   'star',
#   'restaurants',
#   'hawking',
#   'their',
#   'greasy',
#   ',',
#   'uninspired',
#   'eats',
#   '.',
#   'this',
#   'year',
#   'there',
#   'was',
#   'definitely',
#   'lots',
#   'of',
#   'intriguing',
#   'and',
#   'tasty',
#   'offerings',
#   'that',
#   'slanted',
#   'foodie',
#   ':',
#   'pig',
#   'tail',
#   'with',
#   'bacon',
#   'bean',
#   'ragout',
#   'from',
#   'solstice',
#   ',',
#   'pork',
#   'tacos',
#   'with',
#   'kimchi',
#   'slaw',
#   'and',
#   'lemon',
#   'thyme',
#   'aioli',
#   'from',
#   'fairmont',
#   'hotel',
#   'macdonald',
#   ',',
#   'bison',
#   'canneloni',
#   'with',
#   'wild',
#   'mushrooms',
#   'from',
#   'fantasia',
#   ',',
#   'maple',
#   'thyme',
#   'creamed',
#   'corn',
#   'from',
#   'northern',
#   'chicken',
#   '...',
#   '(',
#   'i',
#   'tried',
#   'all',
#   'of',
#   'the',
#   'above',
#   'and',
#   'they',
#   'were',
#   'all',
#   'good',
#   'sized',
#   'portions',
#   'and',
#   'delicious',
#   '!',
#   ')',
#   'there',
#   'is',
#   'still',
#   'a',
#   'good',
#   'dose',
#   'of',
#   'the',
#   'usual',
#   'suspects',
#   'including',
#   'a',
#   'smattering',
#   'of',
#   'ethnic',
#   'cuisines',
#   '(',
#   'with',
#   'ethiopian',
#   ',',
#   'afghan',
#   ',',
#   'korean',
#   ',',
#   'indian',
#   ',',
#   'thai',
#   ',',
#   'chinese',
#   ',',
#   'italian',
#   'and',
#   'more',
#   ')',
#   ',',
#   'food',
#   'trucks',
#   ',',
#   'desserts',
#   '(',
#   'including',
#   'the',
#   'new',
#   'and',
#   'excellent',
#   'fanfan',
#   'patisserie',
#   ')',
#   ',',
#   'and',
#   'drinks',
#   '(',
#   'lemonade',
#   ',',
#   'bubble',
#   'tea',
#   'and',
#   'grizzly',
#   'paw',
#   'sodas',
#   ')',
#   '...',
#   'lines',
#   'were',
#   'surprisingly',
#   'short',
#   'on',
#   'a',
#   'saturday',
#   'around',
#   'lunch',
#   'time',
#   '.',
#   'location',
#   'is',
#   'great',
#   'at',
#   'churchill',
#   'square',
#   'with',
#   'a',
#   'main',
#   'stage',
#   'and',
#   'nightly',
#   'concerts',
#   ',',
#   'as',
#   'well',
#   'as',
#   'a',
#   'beer',
#   'garden',
#   '.',
#   'you',
#   'pay',
#   'via',
#   'tickets',
#   ',',
#   'which',
#   'are',
#   'on',
#   'the',
#   'expensive',
#   'side',
#   ':',
#   '5',
#   'for',
#   '7.75.',
#   'most',
#   'dishes',
#   'are',
#   'are',
#   'between',
#   '2-4',
#   'tickets',
#   '.',
#   '2',
#   'things',
#   'to',
#   'consider',
#   ':',
#   '1',
#   ')',
#   'the',
#   'festival',
#   'ends',
#   'on',
#   'a',
#   'saturday',
#   ',',
#   'not',
#   'a',
#   'sunday',
#   '(',
#   'i',
#   'made',
#   'that',
#   'mistake',
#   'in',
#   'years',
#   'past',
#   ')',
#   ',',
#   '2',
#   ')',
#   'you',
#   'can',
#   'prepurchase',
#   'tickets',
#   'online',
#   'before',
#   'the',
#   'festival',
#   'at',
#   'a',
#   '20',
#   '%',
#   'discount',
#   '.',
#   'too',
#   'bad',
#   'i',
#   'rediscovered',
#   'this',
#   'much',
#   'improved',
#   'food',
#   'fest',
#   'on',
#   'the',
#   'last',
#   'day',
#   '-',
#   'i',
#   'will',
#   'definitely',
#   'check',
#   'it',
#   'out',
#   'again',
#   'next',
#   'year',
#   '!'],
#  ['i',
#   "'d",
#   'been',
#   'craving',
#   'blueberry',
#   'ice',
#   'cream',
#   'for',
#   'weeks',
#   ',',
#   'but',
#   'strange',
#   'series',
#   'of',
#   'events',
#   'have',
#   'prevented',
#   'me',
#   'from',
#   'getting',
#   'my',
#   'hands',
#   'on',
#   'any',
#   '.',
#   'at',
#   '9:40',
#   'this',
#   'evening',
#   ',',
#   'i',
#   'decided',
#   'the',
#   'moment',
#   'was',
#   'right',
#   'then',
#   '.',
#   'we',
#   'flew',
#   'to',
#   'this',
#   'location',
#   ',',
#   'the',
#   'closest',
#   'to',
#   'our',
#   'apartment',
#   '.',
#   'we',
#   'blew',
#   'in',
#   'the',
#   'door',
#   'at',
#   '9:50',
#   ',',
#   'thinking',
#   'we',
#   "'d",
#   'be',
#   'greeted',
#   'by',
#   'surly',
#   'teens',
#   '.',
#   'absolutely',
#   'not',
#   'the',
#   'case',
#   '.',
#   'we',
#   'were',
#   'served',
#   'with',
#   'smiles',
#   'from',
#   'start',
#   'to',
#   'finish',
#   'by',
#   'anastasia',
#   ',',
#   'and',
#   'had',
#   'a',
#   'lovely',
#   'time',
#   'as',
#   'we',
#   'ate',
#   'our',
#   'ice',
#   'cream',
#   '...',
#   'in',
#   'the',
#   'car',
#   '(',
#   'our',
#   'own',
#   'fault',
#   ')',
#   '.',
#   'and',
#   'yes',
#   ',',
#   'they',
#   'had',
#   'blueberry',
#   ',',
#   'which',
#   'was',
#   'delicious',
#   '.'],
#  ['i',
#   "'ve",
#   'been',
#   'waiting',
#   'for',
#   'years',
#   'to',
#   'try',
#   'this',
#   'place',
#   '...',
#   'before',
#   'it',
#   'was',
#   'too',
#   'busy',
#   'to',
#   'get',
#   'into',
#   'then',
#   'of',
#   'course',
#   'fuckin',
#   'covid',
#   '...',
#   'but',
#   'we',
#   'had',
#   'a',
#   'chance',
#   'to',
#   'go',
#   'last',
#   'week',
#   'thank',
#   'the',
#   'lord',
#   '!',
#   'it',
#   "'s",
#   'such',
#   'a',
#   'cool',
#   'space',
#   'that',
#   'makes',
#   'you',
#   'feel',
#   'comfy',
#   'as',
#   'soon',
#   'as',
#   'you',
#   'sit',
#   'down.we',
#   'started',
#   'with',
#   'queso',
#   'verde',
#   'absolutely',
#   'phenomenal',
#   '!',
#   'it',
#   "'s",
#   'deep',
#   'fried',
#   'cheese',
#   'in',
#   'a',
#   'pool',
#   'of',
#   'salsa',
#   'verde',
#   'served',
#   'with',
#   'warm',
#   'tortillas',
#   '...',
#   'whether',
#   'you',
#   'wan',
#   'na',
#   'eat',
#   'it',
#   'like',
#   'a',
#   'taco',
#   'or',
#   'just',
#   'jam',
#   'the',
#   'tortillas',
#   'into',
#   'the',
#   'mess',
#   'it',
#   'is',
#   'absolutely',
#   'delicious',
#   '!',
#   'highly',
#   'recommend',
#   'you',
#   'get',
#   'this',
#   '..',
#   'it',
#   'is',
#   'unbelievable',
#   '!',
#   'we',
#   'got',
#   '3',
#   'different',
#   'types',
#   'of',
#   'taco',
#   "'s",
#   'for',
#   'our',
#   'main',
#   'course',
#   '...',
#   'carne',
#   'asada',
#   ',',
#   'carnitas',
#   ',',
#   'and',
#   'shrimp',
#   '...',
#   'the',
#   'carne',
#   'asada',
#   'was',
#   'like',
#   'really',
#   'really',
#   'great',
#   '...',
#   'meat',
#   'cooked',
#   'well',
#   'with',
#   'chili',
#   'oil',
#   'and',
#   'cilantro',
#   '.',
#   'my',
#   'favourite',
#   'taco',
#   'of',
#   'the',
#   'night',
#   'by',
#   'a',
#   'mile',
#   '.',
#   'the',
#   'shrimp',
#   'taco',
#   "'s",
#   'were',
#   'also',
#   'tasty',
#   ',',
#   'fresh',
#   'shrimp',
#   'and',
#   'slaw',
#   '..',
#   'maybe',
#   'a',
#   'shade',
#   'to',
#   'much',
#   'batter',
#   '.',
#   'the',
#   'carnitas',
#   '...',
#   'ya',
#   'not',
#   'awesome',
#   '..',
#   'pretty',
#   'tough',
#   'pork',
#   'and',
#   'hard',
#   'to',
#   'eat',
#   '.',
#   'i',
#   "'ll",
#   'chalk',
#   'that',
#   'one',
#   'up',
#   'to',
#   'just',
#   'being',
#   'open',
#   'with',
#   'a',
#   'new',
#   'menu.service',
#   'was',
#   'absolutely',
#   'spectacular',
#   ',',
#   'our',
#   'server',
#   'was',
#   'extremely',
#   'attentive',
#   ',',
#   'friendly',
#   ',',
#   'and',
#   'charming',
#   '.',
#   'happy',
#   'hour',
#   'prices',
#   'are',
#   'very',
#   'reasonable',
#   'as',
#   'well',
#   '.',
#   'i',
#   "'m",
#   'not',
#   'sure',
#   'alley',
#   'kat',
#   'is',
#   'capable',
#   'of',
#   'making',
#   'an',
#   'authentic',
#   'mexican',
#   'tasting',
#   'beer',
#   'but',
#   'for',
#   '5',
#   'bucks',
#   'sure',
#   'i',
#   "'ll",
#   'drink',
#   'it',
#   ',',
#   'and',
#   '5',
#   'dollar',
#   'margaritas',
#   '...',
#   'beautiful',
#   '!',
#   'i',
#   'loved',
#   'our',
#   'experience',
#   'and',
#   'ca',
#   "n't",
#   'wait',
#   'to',
#   'go',
#   'back',
#   'as',
#   'soon',
#   'as',
#   'possible',
#   '!',
#   'great',
#   'job',
#   'guys',
#   '!',
#   'cheers',
#   'andy'],
#  ['modern',
#   'latin',
#   'american',
#   'restaurant',
#   'in',
#   'the',
#   'heart',
#   'of',
#   'edmonton',
#   '.',
#   'right',
#   'next',
#   'to',
#   'the',
#   'stadium',
#   ',',
#   'so',
#   'great',
#   'for',
#   'a',
#   'pre-',
#   'or',
#   'post-',
#   'game',
#   'dinner',
#   'or',
#   'drink',
#   '.',
#   'interesting',
#   'and',
#   'creative',
#   'cuisine',
#   ',',
#   'an',
#   'excellent',
#   'rotisserie',
#   '(',
#   'chicken',
#   'or',
#   'beef',
#   ')',
#   'menu',
#   ',',
#   'and',
#   'smaller',
#   'dishes',
#   'to',
#   'share',
#   '.',
#   'small',
#   'menu',
#   ',',
#   'but',
#   'carefully',
#   'created',
#   '.',
#   'overall',
#   'tasty',
#   'food',
#   ',',
#   'but',
#   '...',
#   'no',
#   'real',
#   'salads',
#   '!',
#   'if',
#   'you',
#   'are',
#   'looking',
#   'for',
#   'your',
#   'classic',
#   'veggies-on-greens',
#   'favorite',
#   ',',
#   'you',
#   'wo',
#   "n't",
#   'find',
#   'it',
#   'there',
#   '.',
#   'disappointing',
#   ',',
#   'as',
#   'meat',
#   '+meat',
#   'is',
#   'not',
#   'my',
#   'favorite',
#   'selection',
#   'for',
#   'meals',
#   '.',
#   'nevertheless',
#   ',',
#   'the',
#   'decor',
#   'is',
#   'superb',
#   ',',
#   'and',
#   'it',
#   'was',
#   'an',
#   'overall',
#   'positive',
#   'experience',
#   '...'],
#  ['i',
#   'really',
#   'wanted',
#   'to',
#   'give',
#   'them',
#   'a',
#   'try',
#   'as',
#   'i',
#   'was',
#   'walking',
#   'through',
#   'edmonton',
#   'street',
#   'performers',
#   'food',
#   'trucks',
#   'and',
#   'unfortunately',
#   'they',
#   'are',
#   'only',
#   'a',
#   'food',
#   'truck',
#   'as',
#   'they',
#   'do',
#   'not',
#   'have',
#   'a',
#   'restaurant',
#   'in',
#   'town',
#   ',',
#   'which',
#   'is',
#   'too',
#   'bad',
#   'because',
#   'their',
#   'food',
#   'is',
#   'delicious',
#   'as',
#   'all',
#   'vietnamese',
#   'food',
#   'are.vietnamese',
#   'are',
#   'cool',
#   'meals',
#   'for',
#   'warm',
#   'summer',
#   'nights',
#   '.',
#   'and',
#   'as',
#   'for',
#   'the',
#   'service',
#   'was',
#   ',',
#   'i',
#   'left',
#   'my',
#   'boyfriend',
#   'to',
#   'grab',
#   'my',
#   'food',
#   'while',
#   'i',
#   'grab',
#   'lemonade',
#   'for',
#   'us',
#   'which',
#   'was',
#   'only',
#   'a',
#   'couple',
#   'of',
#   'minutes',
#   ',',
#   'and',
#   'my',
#   'food',
#   'was',
#   'out',
#   'ready',
#   'for',
#   'me',
#   'to',
#   'pick',
#   'up',
#   '.',
#   'talk',
#   'about',
#   'quick',
#   'service',
#   '.'],
#  ['i',
#   'wish',
#   'they',
#   'had',
#   'one',
#   'of',
#   'these',
#   'in',
#   'vegas',
#   '!',
#   '!',
#   '!',
#   'it',
#   'was',
#   'delicious',
#   'and',
#   'entertaining',
#   'to',
#   'watch',
#   '!',
#   'my',
#   'family',
#   'of',
#   '6',
#   'all',
#   'loved',
#   'it',
#   '.',
#   'i',
#   'ordered',
#   'the',
#   'vanilla',
#   'icecream',
#   'with',
#   'chocolate',
#   'chips',
#   'and',
#   'reeses',
#   'mix',
#   'ins',
#   '.'],
#  ['i',
#   "'m",
#   'a',
#   'big',
#   'fan',
#   'of',
#   'every',
#   'famoso',
#   'in',
#   'town',
#   'and',
#   'this',
#   'location',
#   'is',
#   'not',
#   'the',
#   'exception',
#   '.',
#   'the',
#   'atmosphere',
#   'is',
#   'great',
#   ',',
#   'layout',
#   'is',
#   'well',
#   'designed',
#   ',',
#   'the',
#   'new',
#   'shared',
#   'tables',
#   'are',
#   'a',
#   'great',
#   'excuse',
#   'to',
#   'talk',
#   'to',
#   'other',
#   'people',
#   'and',
#   'make',
#   'new',
#   'friends',
#   'and',
#   'the',
#   'food',
#   'is',
#   'fabulous',
#   '.',
#   'usually',
#   'i',
#   'order',
#   'the',
#   'small',
#   'pizzetta',
#   'and',
#   'the',
#   'side',
#   'of',
#   'salad',
#   'or',
#   'soup',
#   'and',
#   'this',
#   'time',
#   'was',
#   'not',
#   'the',
#   'exception',
#   '.',
#   'i',
#   'ordered',
#   'a',
#   'pepperoni',
#   '&',
#   'roasted',
#   'mushroom',
#   'pizzetta',
#   'and',
#   'a',
#   'caesar',
#   'salad.the',
#   'pizzetta',
#   ',',
#   '~',
#   '7',
#   "''",
#   'diameter',
#   ',',
#   'was',
#   'perfectly',
#   'baked',
#   ',',
#   'hand-tossed',
#   'and',
#   'with',
#   'delicious',
#   'rosted',
#   'mushrooms',
#   '.',
#   'the',
#   'salad',
#   'can',
#   'speak',
#   'for',
#   'it',
#   'self',
#   ',',
#   'the',
#   'perfect',
#   'combination',
#   'with',
#   'romaine',
#   'lettuce',
#   ',',
#   'prosciutto',
#   'crisps',
#   ',',
#   'grana',
#   'padano',
#   ',',
#   'and',
#   'the',
#   '#',
#   'famoso',
#   'caesar',
#   'dressing',
#   '!',
#   'if',
#   'i',
#   "'m",
#   'in',
#   'the',
#   'mood',
#   'for',
#   'a',
#   'dessert',
#   'i',
#   'will',
#   'order',
#   'the',
#   'famoso',
#   "'s",
#   'authentic',
#   'tiramisu',
#   '.',
#   'every',
#   'bit',
#   'is',
#   'yummy.this',
#   'place',
#   'is',
#   'great',
#   'for',
#   'groups',
#   ',',
#   'friends',
#   ',',
#   'couples',
#   'or',
#   'families.the',
#   'service',
#   'is',
#   'one',
#   'of',
#   'the',
#   'most',
#   'important',
#   'reasons',
#   'while',
#   'i',
#   'keep',
#   'visiting',
#   'this',
#   'location',
#   '.',
#   'they',
#   'all',
#   'are',
#   'so',
#   'nice',
#   ',',
#   'and',
#   'since',
#   'famoso',
#   'decided',
#   'to',
#   'change',
#   'the',
#   'way',
#   'that',
#   'you',
#   'can',
#   'order',
#   'and',
#   'pay',
#   'this',
#   'place',
#   'is',
#   'even',
#   'better.if',
#   'you',
#   'are',
#   'in',
#   'the',
#   'neighborhood',
#   'or',
#   'going',
#   'to',
#   'a',
#   'movie',
#   'or',
#   'on',
#   'your',
#   'way',
#   'out',
#   'of',
#   'the',
#   'theater',
#   'i',
#   'recommend',
#   'you',
#   'to',
#   'stop',
#   'by',
#   'famoso',
#   'and',
#   'to',
#   'enjoy',
#   'one',
#   'of',
#   'their',
#   'specialties',
#   '.'],
#  ['it',
#   "'s",
#   'bad',
#   'enough',
#   'when',
#   'you',
#   'get',
#   'into',
#   'an',
#   'accident',
#   '...',
#   'what',
#   'sucks',
#   'even',
#   'more',
#   'is',
#   'when',
#   'you',
#   'have',
#   'to',
#   'pay',
#   'to',
#   'get',
#   'it',
#   'fixed',
#   '.',
#   'i',
#   'was',
#   'skeptical',
#   'from',
#   'seeing',
#   'the',
#   'other',
#   'comment',
#   'on',
#   'here',
#   'but',
#   'know',
#   'that',
#   'they',
#   'have',
#   'a',
#   'long',
#   'time',
#   'reputation',
#   'and',
#   'not',
#   'just',
#   'one',
#   'yelp',
#   '.',
#   'gary',
#   'and',
#   'his',
#   'team',
#   'did',
#   'amazing',
#   'job',
#   'repairing',
#   'the',
#   'rear',
#   'end',
#   'of',
#   'my',
#   'chrysler',
#   '300',
#   '..',
#   'the',
#   'paint',
#   'work',
#   'was',
#   'flawless',
#   'and',
#   'duplicating',
#   'metal',
#   'flake',
#   'work',
#   'is',
#   'painful',
#   '!',
#   'great',
#   'work',
#   'and',
#   'fast',
#   '!',
#   'thank',
#   'you',
#   'so',
#   'much',
#   'for',
#   'helping',
#   'me',
#   'out',
#   '!',
#   'well',
#   'deserved',
#   'yelp',
#   '!'],
#  ['hooliganz',
#   'is',
#   "n't",
#   'on',
#   'my',
#   'top',
#   '20',
#   'places',
#   'to',
#   'go',
#   'in',
#   'the',
#   'city',
#   ',',
#   'but',
#   'it',
#   "'s",
#   'ok.',
#   'it',
#   "'s",
#   'your',
#   'average',
#   'pub',
#   'with',
#   'food',
#   'and',
#   'drinks',
#   '.',
#   'nothing',
#   'special',
#   ',',
#   'as',
#   'you',
#   "'d",
#   'expect',
#   '.',
#   'the',
#   'coolest',
#   'thing',
#   'it',
#   "'s",
#   'got',
#   'going',
#   'for',
#   'it',
#   'is',
#   'its',
#   'name',
#   '.',
#   'they',
#   'frequently',
#   'have',
#   'local',
#   'bands',
#   'here',
#   'and',
#   'charge',
#   'low',
#   'or',
#   'no',
#   'cover',
#   '.',
#   'it',
#   "'s",
#   'a',
#   'smaller',
#   'place',
#   ',',
#   'pretty',
#   'dark',
#   'inside',
#   ',',
#   'and',
#   'there',
#   "'s",
#   'karaoke',
#   'on',
#   'thursday',
#   'and',
#   'friday',
#   'nights',
#   ',',
#   'for',
#   'those',
#   'who',
#   'want',
#   'to',
#   'stretch',
#   'their',
#   'vocal',
#   'chords',
#   'after',
#   'a',
#   'few',
#   'drinks',
#   '.',
#   'the',
#   'crowd',
#   "'s",
#   'always',
#   'changing',
#   ',',
#   'except',
#   'for',
#   'a',
#   'small',
#   'semi-regular',
#   'core',
#   'group',
#   'that',
#   'comes',
#   'here',
#   '.',
#   'hooliganz',
#   'has',
#   'a',
#   'good',
#   'downtown',
#   '124',
#   'street',
#   'location',
#   'and',
#   'it',
#   "'ll",
#   'do',
#   'if',
#   'you',
#   'want',
#   'to',
#   'stay',
#   'in',
#   'the',
#   'area',
#   'but',
#   'do',
#   "n't",
#   'feel',
#   'like',
#   'boston',
#   'pizza',
#   ',',
#   'col.',
#   'mustard',
#   "'s",
#   'or',
#   'roxie',
#   "'s",
#   'for',
#   'your',
#   'evening',
#   "'s",
#   'entertainment',
#   '.',
#   'for',
#   'other',
#   'options',
#   'you',
#   "'d",
#   'have',
#   'to',
#   'go',
#   'a',
#   'little',
#   'east',
#   'or',
#   'west',
#   ',',
#   'toward',
#   '142',
#   'st.',
#   ',',
#   '104',
#   'ave',
#   'or',
#   'jasper',
#   '.'],
#  ['i',
#   'came',
#   'to',
#   'canteen',
#   'for',
#   'my',
#   'birthday',
#   'brunch',
#   'with',
#   'a',
#   'few',
#   'friends',
#   'on',
#   'sunday',
#   '.',
#   'you',
#   'definitely',
#   'need',
#   'to',
#   'make',
#   'a',
#   'reservation',
#   'for',
#   'this',
#   'time',
#   'because',
#   'it',
#   'was',
#   'really',
#   'busy',
#   '!',
#   'i',
#   'used',
#   'the',
#   'opentable',
#   'app',
#   'to',
#   'do',
#   'it',
#   'and',
#   'it',
#   'worked',
#   'out',
#   'really',
#   'nice',
#   '.',
#   'they',
#   'were',
#   'really',
#   'accommodating',
#   'because',
#   'we',
#   'had',
#   'one',
#   'extra',
#   'person.everyone',
#   'was',
#   'really',
#   'happy',
#   'with',
#   'their',
#   'meal',
#   '.',
#   '5/9',
#   'people',
#   'got',
#   'the',
#   'pork',
#   'belly',
#   'which',
#   'got',
#   'rave',
#   'reviews',
#   '.',
#   'i',
#   'had',
#   'the',
#   'lemon',
#   'blueberry',
#   'flapjacks',
#   'which',
#   'were',
#   'really',
#   'yummy',
#   '.',
#   'it',
#   'was',
#   'a',
#   'big',
#   'portion',
#   'and',
#   'i',
#   'could',
#   "n't",
#   'finish',
#   'it',
#   'all',
#   '.',
#   'i',
#   'tried',
#   'a',
#   'bit',
#   'of',
#   'my',
#   'sisters',
#   'egg',
#   'florentine',
#   'too',
#   'and',
#   'the',
#   'best',
#   'part',
#   'about',
#   'that',
#   'was',
#   'the',
#   'brussel',
#   'sprouts',
#   '!',
#   'they',
#   'were',
#   'perfectly',
#   'cooked.they',
#   'had',
#   'americanos',
#   'available',
#   'for',
#   'coffee',
#   'which',
#   'was',
#   'cool',
#   '.',
#   'service',
#   'was',
#   'good',
#   ',',
#   'food',
#   'came',
#   'out',
#   'quickly',
#   ',',
#   'waters',
#   'were',
#   'filled',
#   'and',
#   'we',
#   'were',
#   'happy.the',
#   'decor',
#   'was',
#   'really',
#   'nice',
#   'as',
#   'well',
#   '.',
#   'overall',
#   'i',
#   'would',
#   'definitely',
#   'come',
#   'back',
#   'and',
#   'try',
#   'some',
#   'dinner',
#   'here',
#   '!'],
#  ['i',
#   'was',
#   'shocked',
#   'at',
#   'how',
#   'awesome',
#   'the',
#   'selection',
#   'is',
#   'at',
#   'this',
#   'goodwill',
#   '.',
#   'it',
#   'was',
#   "n't",
#   'like',
#   'value',
#   'village',
#   ',',
#   'where',
#   'i',
#   'can',
#   'go',
#   'through',
#   '50',
#   'shirts',
#   'without',
#   'finding',
#   'anything',
#   'good',
#   '.',
#   'as',
#   'i',
#   'was',
#   'going',
#   'through',
#   'all',
#   'the',
#   'racks',
#   ',',
#   'there',
#   'was',
#   'almost',
#   'always',
#   'something',
#   'cool',
#   'and',
#   'different',
#   '.',
#   'i',
#   'found',
#   'this',
#   'one',
#   'amazing',
#   'brown',
#   'button-down',
#   'dress',
#   ',',
#   'but',
#   'i',
#   'was',
#   'so',
#   'disappointed',
#   ',',
#   'when',
#   'it',
#   'was',
#   'slightly',
#   'too',
#   'small',
#   '.',
#   'i',
#   'would',
#   'also',
#   'definitely',
#   'suggest',
#   'this',
#   'place',
#   ',',
#   'if',
#   'you',
#   "'re",
#   'moving',
#   'out',
#   'for',
#   'the',
#   'first',
#   'time',
#   'and',
#   'ca',
#   "n't",
#   'afford',
#   'new',
#   'furniture',
#   '.',
#   'i',
#   'saw',
#   'some',
#   'really',
#   'decent',
#   'couches',
#   'and',
#   'coffee',
#   'tables',
#   'for',
#   'super',
#   'cheap',
#   '.',
#   'while',
#   'i',
#   'was',
#   'here',
#   'with',
#   'a',
#   'friend',
#   ',',
#   'we',
#   'found',
#   'some',
#   'awesome',
#   'stuff',
#   'in',
#   'the',
#   'book',
#   'section',
#   '.',
#   'my',
#   'friend',
#   'collects',
#   'those',
#   'old',
#   'little',
#   'golden',
#   'books/records',
#   ',',
#   'an',
#   'he',
#   'found',
#   'a',
#   'couple',
#   'here',
#   'that',
#   'were',
#   'in',
#   'excellent',
#   'condition',
#   '.',
#   'i',
#   'also',
#   'found',
#   'an',
#   'old',
#   'webster',
#   "'s",
#   'hardcover',
#   'grammar',
#   'book',
#   'that',
#   'was',
#   'in',
#   'perfect',
#   'condition',
#   '.',
#   'i',
#   'love',
#   'goodwill',
#   ',',
#   'but',
#   'i',
#   'do',
#   'find',
#   'some',
#   'of',
#   'the',
#   'prices',
#   'a',
#   'bit',
#   'high',
#   '.',
#   'still',
#   ',',
#   'it',
#   "'s",
#   'cheaper',
#   'than',
#   'buying',
#   'anything',
#   'new',
#   ',',
#   'and',
#   'sometimes',
#   'it',
#   "'s",
#   'worth',
#   'it',
#   ',',
#   'when',
#   'you',
#   'find',
#   'something',
#   'really',
#   'unique',
#   '.'],
#  ['we',
#   'ordered',
#   'from',
#   'this',
#   'restaurant',
#   'tonight',
#   'through',
#   'skip',
#   'the',
#   'dishes',
#   'and',
#   'honestly',
#   ',',
#   'this',
#   'is',
#   'the',
#   'best',
#   'take',
#   'out',
#   'asian',
#   'food',
#   'we',
#   "'ve",
#   'ever',
#   'had',
#   '.',
#   'we',
#   'ordered',
#   'spring',
#   'rolls',
#   ',',
#   'lemon',
#   'chicken',
#   ',',
#   'fried',
#   'rice',
#   ',',
#   'ginger',
#   'beef',
#   ',',
#   'sweet',
#   'and',
#   'sour',
#   'pork',
#   'and',
#   'chicken',
#   'chow',
#   'mein',
#   '.',
#   'the',
#   'food',
#   'arrived',
#   'piping',
#   'hot',
#   'and',
#   'in',
#   'very',
#   'durable',
#   'containers',
#   '.',
#   'my',
#   'only',
#   'complaint',
#   'would',
#   'be',
#   'that',
#   'the',
#   'spring',
#   'rolls',
#   'did',
#   "n't",
#   'have',
#   'an',
#   'accompanying',
#   'sauce',
#   'which',
#   'was',
#   'a',
#   'little',
#   'disappointing',
#   'but',
#   'they',
#   'were',
#   'good',
#   'on',
#   'their',
#   'own',
#   '.',
#   'i',
#   'almost',
#   'always',
#   'put',
#   'soya',
#   'sauce',
#   'and',
#   'hot',
#   'sauce',
#   'on',
#   'my',
#   'rice',
#   'but',
#   'the',
#   'chicken',
#   'friend',
#   'rice',
#   'was',
#   'so',
#   'good',
#   'on',
#   'it',
#   "'s",
#   'own',
#   'that',
#   'it',
#   'was',
#   "n't",
#   'even',
#   'necessary',
#   '.',
#   'i',
#   "'ll",
#   'definitely',
#   'be',
#   'saving',
#   'the',
#   'menu',
#   'from',
#   'this',
#   'place',
#   '!'],
#  ['in',
#   'your',
#   'hometown',
#   ',',
#   'you',
#   'have',
#   'your',
#   'go-tos',
#   'for',
#   'best',
#   'food',
#   'and',
#   'service',
#   '.',
#   'when',
#   'travelling',
#   ',',
#   'especially',
#   'solo',
#   ',',
#   'it',
#   "'s",
#   'a',
#   'crapshoot',
#   '.',
#   'was',
#   'feeling',
#   'bbq',
#   'or',
#   'mexican',
#   'tonight',
#   ',',
#   'so',
#   'yelp',
#   'is',
#   'my',
#   'buddy',
#   '...',
#   'or',
#   'so',
#   'i',
#   'thought',
#   '.',
#   'huma',
#   'was',
#   'the',
#   'mex',
#   'choice',
#   'but',
#   'when',
#   'i',
#   'arrived',
#   '(',
#   '7pm',
#   'saturday',
#   ')',
#   'place',
#   'was',
#   'packed',
#   'and',
#   'i',
#   'did',
#   "n't",
#   'want',
#   'to',
#   'stand',
#   'outside',
#   'waiting',
#   '.',
#   'kitty',
#   'corner',
#   'is',
#   'a',
#   'grill',
#   ',',
#   'a',
#   'thai',
#   'spot',
#   ',',
#   'pizza',
#   'and',
#   'yes',
#   ',',
#   'fired',
#   'up',
#   'bbq',
#   '.',
#   'a',
#   'quick',
#   'check',
#   'of',
#   'the',
#   'yelp',
#   'reveals',
#   '4',
#   'stars',
#   '...',
#   'though',
#   'i',
#   "'m",
#   'looking',
#   'at',
#   'an',
#   'empty',
#   'parking',
#   'lot',
#   '.',
#   'inside',
#   ',',
#   'i',
#   'notice',
#   'one',
#   'gal',
#   'behind',
#   'the',
#   'counter',
#   ',',
#   'no',
#   'customers',
#   '.',
#   'tables',
#   'all',
#   'need',
#   'a',
#   'wipe',
#   'down',
#   '.',
#   'she',
#   'clearly',
#   'does',
#   "n't",
#   'take',
#   'pride',
#   'in',
#   'her',
#   'work',
#   '.',
#   'so',
#   'i',
#   "'m",
#   'on',
#   'alert',
#   'here',
#   ',',
#   'and',
#   'i',
#   'ask',
#   'her',
#   'what',
#   "'s",
#   'good',
#   '.',
#   'she',
#   'recommends',
#   'the',
#   'brisket',
#   ',',
#   'which',
#   'is',
#   'not',
#   '$',
#   '13',
#   'or',
#   '$',
#   '14',
#   'like',
#   'other',
#   'bbq',
#   'on',
#   'the',
#   'menu',
#   ',',
#   'but',
#   '$',
#   '17',
#   '.',
#   'comes',
#   'with',
#   '3',
#   'sides',
#   ',',
#   'reviews',
#   'i',
#   'saw',
#   'liked',
#   'the',
#   'beans',
#   ',',
#   'and',
#   'the',
#   'corn',
#   '.',
#   'but',
#   'as',
#   'i',
#   "'m",
#   'looking',
#   'through',
#   'a',
#   'glass',
#   'window',
#   ',',
#   'i',
#   'can',
#   'see',
#   'the',
#   'beans',
#   'look',
#   'like',
#   'they',
#   "'ve",
#   'been',
#   'in',
#   'there',
#   'all',
#   'afternoon',
#   ',',
#   'the',
#   'corn',
#   'is',
#   'on',
#   'it',
#   "'s",
#   'last',
#   'scoop',
#   ',',
#   'and',
#   'sorry',
#   ',',
#   'the',
#   'mac',
#   'n',
#   'cheese',
#   'scared',
#   'me',
#   'off',
#   '.',
#   'looked',
#   'like',
#   'nobody',
#   'had',
#   'any',
#   'all',
#   'day',
#   ',',
#   'dry',
#   'as',
#   'the',
#   'desert',
#   '.',
#   'the',
#   'brisket',
#   'was',
#   'a',
#   'good',
#   'portion',
#   ',',
#   'she',
#   'poured',
#   'some',
#   'bbq',
#   'sauce',
#   'on',
#   ',',
#   'then',
#   'scooped',
#   'the',
#   'last',
#   'of',
#   'the',
#   'corn',
#   'and',
#   'a',
#   'pitiful',
#   'amount',
#   'of',
#   'beans',
#   'on',
#   'my',
#   'plate',
#   ',',
#   'plus',
#   'one',
#   'of',
#   'the',
#   'last',
#   'two',
#   'slices',
#   'of',
#   'cornbread',
#   '(',
#   'again',
#   ',',
#   'skimpy',
#   ',',
#   'what',
#   'was',
#   'there',
#   'should',
#   'have',
#   'been',
#   'one',
#   'piece',
#   ')',
#   '.',
#   'onto',
#   'a',
#   'tray',
#   'with',
#   'a',
#   '``',
#   'medium',
#   "''",
#   'sweet',
#   'tea',
#   'at',
#   'just',
#   'under',
#   '$',
#   '20',
#   '.',
#   'brisket',
#   ':',
#   'good',
#   ',',
#   'tender',
#   ',',
#   'just',
#   'a',
#   'slight',
#   'bit',
#   'dry',
#   'and',
#   'lukewarm',
#   ',',
#   'spots',
#   'that',
#   'were',
#   'cold',
#   '.',
#   'could',
#   'have',
#   'used',
#   'a',
#   'quick',
#   'reheat',
#   '.',
#   'i',
#   'wish',
#   'she',
#   'had',
#   'given',
#   'me',
#   'a',
#   'side',
#   'of',
#   'bbq',
#   'sauce',
#   'because',
#   'what',
#   'she',
#   'put',
#   'on',
#   'only',
#   'covered',
#   'the',
#   'top',
#   'slice',
#   '.',
#   'beans',
#   ':',
#   'flavorful',
#   ',',
#   'smokey-spicy',
#   'and',
#   'good',
#   'enough',
#   'for',
#   'nearly',
#   'being',
#   'dried',
#   'up',
#   '.',
#   'skimped',
#   'on',
#   'the',
#   'portion',
#   '.',
#   'corn',
#   ':',
#   'okay',
#   ',',
#   'good',
#   'flavor',
#   'but',
#   'lukewarm',
#   'and',
#   'again',
#   'skimpy',
#   'portion',
#   '.',
#   'sweet',
#   'tea',
#   ':',
#   'perfect',
#   'sweetness',
#   ',',
#   'but',
#   'i',
#   'would',
#   'have',
#   'liked',
#   'a',
#   'bit',
#   'of',
#   'ice',
#   'in',
#   'it',
#   'and',
#   'a',
#   'lemon',
#   'slice.summary',
#   ':',
#   'i',
#   "'ve",
#   'had',
#   'much',
#   'better',
#   ',',
#   'fresher',
#   ',',
#   'hotter',
#   'bbq',
#   'for',
#   'half',
#   'this',
#   'price',
#   '.',
#   'commanding',
#   'a',
#   'premium',
#   'for',
#   'this',
#   'brisket',
#   'was',
#   "n't",
#   'worth',
#   'it',
#   '.',
#   'and',
#   'i',
#   "'m",
#   'being',
#   'nice',
#   'when',
#   'i',
#   'say',
#   'i',
#   'could',
#   'have',
#   'gone',
#   'to',
#   'a',
#   'buffet',
#   'where',
#   'i',
#   'would',
#   'have',
#   'found',
#   'all',
#   'these',
#   'items',
#   'and',
#   'much',
#   'more',
#   'for',
#   'a',
#   'similar',
#   'price',
#   ',',
#   'plus',
#   'dessert',
#   '.',
#   'if',
#   'you',
#   "'re",
#   'gon',
#   'na',
#   'let',
#   'food',
#   'sit',
#   'in',
#   'pans',
#   'for',
#   'hours',
#   ',',
#   'best',
#   'you',
#   'not',
#   'put',
#   'in',
#   'a',
#   'display',
#   'case',
#   'for',
#   'customers',
#   'to',
#   'wonder',
#   'about',
#   '.'],
#  ['they',
#   'must',
#   'over',
#   'book',
#   'rooms',
#   '.',
#   'booked',
#   'a',
#   'room',
#   'at',
#   '630',
#   ',',
#   'got',
#   'in',
#   'after',
#   '7.',
#   'went',
#   'to',
#   'the',
#   'washroom',
#   'and',
#   'walked',
#   'by',
#   'the',
#   'employee',
#   'room',
#   'and',
#   'overheard',
#   'an',
#   'employee',
#   'saying',
#   '``',
#   'that',
#   'group',
#   'is',
#   'really',
#   'dumb',
#   "''",
#   'update',
#   'the',
#   'owner',
#   'contacted',
#   'me',
#   'immediately',
#   'for',
#   'more',
#   'details',
#   'to',
#   'investigate',
#   'the',
#   'incident',
#   '.',
#   'he',
#   'took',
#   'matters',
#   'seriously',
#   '.',
#   'he',
#   'really',
#   'wanted',
#   'to',
#   'show',
#   'the',
#   'group',
#   'that',
#   'this',
#   'was',
#   'a',
#   'one-off',
#   'so',
#   'we',
#   'all',
#   'went',
#   'back',
#   'recently',
#   '.',
#   'we',
#   'had',
#   'a',
#   'really',
#   'great',
#   'time',
#   '.',
#   'we',
#   'got',
#   'in',
#   'right',
#   'on',
#   'time',
#   'and',
#   'all',
#   'the',
#   'staff',
#   'were',
#   'friendly',
#   'and',
#   'energetic',
#   'which',
#   'really',
#   'made',
#   'us',
#   'enjoy',
#   'the',
#   'experience',
#   '.',
#   'we',
#   'have',
#   'now',
#   'done',
#   'all',
#   'the',
#   'rooms',
#   'at',
#   'escape',
#   'city',
#   'and',
#   'definitely',
#   'think',
#   'they',
#   'have',
#   'the',
#   'best',
#   'rooms',
#   'in',
#   'the',
#   'city',
#   '.',
#   'will',
#   'be',
#   'returning',
#   'for',
#   'the',
#   'next',
#   'new',
#   'room',
#   '!'],
#  ['sbarro',
#   'does',
#   "n't",
#   'make',
#   'my',
#   'favorite',
#   'pizza',
#   'but',
#   'they',
#   'sure',
#   'do',
#   'make',
#   'the',
#   'best',
#   'way',
#   'for',
#   'me',
#   'to',
#   'feed',
#   'my',
#   'family',
#   'of',
#   '4',
#   'a',
#   'quick',
#   'and',
#   'affordable',
#   'supper',
#   'in',
#   'an',
#   'otherwise',
#   'extremely',
#   'expensive',
#   'and',
#   'greasy/deep',
#   'fried',
#   'mall',
#   'food',
#   'court.we',
#   "'ve",
#   'visited',
#   'two',
#   'locations',
#   'now',
#   'and',
#   'both',
#   'allowed',
#   'us',
#   'to',
#   'pick',
#   'any',
#   '6',
#   'slices',
#   'of',
#   'our',
#   'choice',
#   'to',
#   'make',
#   'a',
#   'full',
#   'pizza',
#   'which',
#   'works',
#   'out',
#   'to',
#   'pretty',
#   'close',
#   'the',
#   'same',
#   'price',
#   'as',
#   'buying',
#   '3',
#   'single',
#   'slices.both',
#   'kiddos',
#   'are',
#   'quite',
#   'picky',
#   'and',
#   'both',
#   'were',
#   'happy',
#   'with',
#   'their',
#   'choices.sbarro',
#   ',',
#   'you',
#   'get',
#   'a',
#   'thumbs',
#   'up',
#   'from',
#   'me',
#   ':',
#   '-',
#   ')'],
#  ['i',
#   "'m",
#   'really',
#   'happy',
#   'with',
#   'studio',
#   'nails',
#   'in',
#   'southgate',
#   'i',
#   'been',
#   'getting',
#   'my',
#   'nail',
#   'done',
#   'with',
#   'them',
#   'for',
#   'almost',
#   '5',
#   'years',
#   'now',
#   ',',
#   'i',
#   'do',
#   "n't",
#   'change',
#   'it',
#   'them',
#   'for',
#   'anything',
#   'the',
#   'lady',
#   'who',
#   'does',
#   'my',
#   'nail',
#   'it',
#   "'s",
#   'kayla',
#   'she',
#   'almost',
#   'does',
#   'a',
#   'good',
#   'job',
#   'and',
#   'she',
#   'never',
#   'say',
#   'no',
#   'i',
#   'ca',
#   "n't",
#   'do',
#   'that',
#   '.',
#   'i',
#   'show',
#   'her',
#   'this',
#   'crazy',
#   'ideas',
#   'that',
#   'i',
#   'wan',
#   'na',
#   'do',
#   'she',
#   'almost',
#   'does',
#   'it',
#   'exactly',
#   'the',
#   'same',
#   'which',
#   'i',
#   "'m",
#   'amazed',
#   'by',
#   'it',
#   '.',
#   'i',
#   'give',
#   'them',
#   '5',
#   'start',
#   'and',
#   'awesome',
#   'review',
#   'for',
#   'it',
#   'you',
#   'guys',
#   'should',
#   'check',
#   'them',
#   'out',
#   '.'],
#  ['the',
#   'staff',
#   'was',
#   'wonderful',
#   'the',
#   'front',
#   'desk',
#   'guy',
#   'was',
#   'so',
#   'friendly',
#   'which',
#   'is',
#   'so',
#   'nice',
#   'after',
#   'a',
#   'long',
#   'long',
#   'day',
#   'we',
#   'got',
#   'a',
#   'queen',
#   'suite',
#   '(',
#   'two',
#   'queen',
#   'beds',
#   'in',
#   'separate',
#   'areas',
#   ')',
#   'and',
#   'it',
#   'was',
#   'nice',
#   'but',
#   'wished',
#   'both',
#   'rooms',
#   'had',
#   'a',
#   'tv',
#   'in',
#   'them',
#   'we',
#   'order',
#   'room',
#   'service',
#   'and',
#   'it',
#   'was',
#   'so',
#   'yummy',
#   'the',
#   'appetizer',
#   'was',
#   'a',
#   'little',
#   'small',
#   'for',
#   'price',
#   '(',
#   'salmon',
#   'on',
#   'toast',
#   ')',
#   'but',
#   'it',
#   'was',
#   'so',
#   'wonderful',
#   'beef',
#   'sandwich',
#   'and',
#   'caesar',
#   'salad',
#   'was',
#   'delicious',
#   'the',
#   'fries',
#   'had',
#   'their',
#   'steak',
#   'spice',
#   'on',
#   'them',
#   'and',
#   'they',
#   'were',
#   'one',
#   'of',
#   'the',
#   'best',
#   'fries',
#   'i',
#   'have',
#   'had',
#   'the',
#   'breakfast',
#   'buffet',
#   'came',
#   'with',
#   'the',
#   'room',
#   ',',
#   'the',
#   'eggs',
#   ',',
# ...
#   'packed',
#   ',',
#   'the',
#   'service',
#   'was',
#   'great',
#   ',',
#   'and',
#   'the',
#   'food',
#   'was',
#   'expertly',
#   'brought',
#   'out',
#   'and',
#   'served.first',
#   'off',
#   ',',
#   'the',
#   'interior',
#   'is',
#   'a',
#   'cute',
#   'take',
#   'on',
#   'a',
#   'sports',
#   'bar',
#   ',',
#   'with',
#   'some',
#   'vaguely',
#   'mexican',
#   'themed',
#   'flare',
#   ',',
#   'in',
#   'the',
#   'form',
#   'of',
#   'bathroom',
#   'doors',
#   ',',
#   'signage',
#   ',',
#   'etc',
#   '.',
#   'there',
#   'is',
#   'a',
#   'big',
#   'bar',
#   ',',
#   'with',
#   '3',
#   'tvs',
#   '-',
#   'at',
#   'the',
#   'time',
#   'they',
#   'were',
#   'broadcasting',
#   'hockey',
#   ',',
#   'and',
#   '2',
#   'other',
#   'sports',
#   'channels',
#   '.',
#   'evidently',
#   ',',
#   'there',
#   'is',
#   'happy',
#   'hour',
#   'at',
#   'the',
#   'bar',
#   'and',
#   'the',
#   'drink',
#   'specials',
#   'sounded',
#   'pretty',
#   'great.we',
#   'ordered',
#   'too',
#   'much',
#   'food',
#   ',',
#   'but',
#   'it',
#   'was',
#   'all',
#   'great',
#   '.',
#   'upon',
#   'seating',
#   ',',
#   'you',
#   "'re",
#   'served',
#   'the',
#   'standard',
#   'salsas',
#   'and',
#   'chips',
#   ',',
#   'they',
#   'were',
#   'pretty',
#   'good',
#   '!',
#   'we',
#   'ordered',
#   'guacamole',
#   'as',
#   'an',
#   'appetizer',
#   ',',
#   'and',
#   'abuela',
#   "'s",
#   'empanadas',
#   'at',
#   'the',
#   'request',
#   'of',
#   'my',
#   'dad',
#   '.',
#   'the',
#   'empanadas',
#   'come',
#   '3',
#   'to',
#   'an',
#   'order',
#   ',',
#   'and',
#   'they',
#   "'re",
#   'piled',
#   'high',
#   'with',
#   'sour',
#   'cream',
#   ',',
#   'queso',
#   'fresco',
#   ',',
#   'and',
#   'lettuce',
#   '.',
#   'the',
#   'empanadas',
#   'themselves',
#   'were',
#   'really',
#   'delicious',
#   '-',
#   'it',
#   "'s",
#   'a',
#   'corn',
#   'corn',
#   'empanada',
#   'filled',
#   'with',
#   'chipotle',
#   'tomato',
#   'pulled',
#   'chicken',
#   'and',
#   'caramelized',
#   'onion',
#   '.',
#   'the',
#   'toppings',
#   'were',
#   'really',
#   'good',
#   ',',
#   'but',
#   'made',
#   'it',
#   'difficult',
#   'to',
#   'consume',
#   '.',
#   'the',
#   'guacamole',
#   'was',
#   'great',
#   '-',
#   'standard',
#   'guacamole',
#   ',',
#   'nothing',
#   'special',
#   'or',
#   'especially',
#   'fresh',
#   '-',
#   'but',
#   'we',
#   'still',
#   'devoured',
#   'it',
#   'nonetheless.for',
#   'dinner',
#   ',',
#   'my',
#   'dad',
#   'really',
#   'wanted',
#   'the',
#   'chicken',
#   'tinga',
#   'tacos',
#   '(',
#   'polla',
#   'vieja',
#   ',',
#   'i',
#   'believe',
#   '?',
#   ')',
#   ',',
#   'which',
#   'are',
#   'only',
#   'offered',
#   'on',
#   'the',
#   'lunch',
#   'menu',
#   '-',
#   'our',
#   'waitress',
#   'happily',
#   'obliged',
#   'and',
#   'allowed',
#   'him',
#   'to',
#   'order',
#   'that',
#   '.',
#   'three',
#   'tacos',
#   'on',
#   'a',
#   'plate',
#   ',',
#   'which',
#   'is',
#   'a',
#   'perfect',
#   'lunch',
#   'portion',
#   ',',
#   'but',
#   'made',
#   'my',
#   'dinner',
#   'look',
#   'like',
#   'a',
#   'feast',
#   'for',
#   'a',
#   'king',
#   '(',
#   'or',
#   '2',
#   '!',
#   ')',
#   '.',
#   'i',
#   'ordered',
#   'the',
#   'steak',
#   'fajitas',
#   ',',
#   'which',
#   'is',
#   'a',
#   'super',
#   'large',
#   'amount',
#   'of',
#   'food',
#   '.',
#   'it',
#   'was',
#   'served',
#   'with',
#   'side',
#   'of',
#   'beans',
#   ',',
#   'cheese',
#   ',',
#   'and',
#   'sour',
#   'cream',
#   '.',
#   'there',
#   'were',
#   '4',
#   'tortillas',
#   ',',
#   'but',
#   'was',
#   "n't",
#   'able',
#   'to',
#   'eat',
#   'more',
#   'than',
#   '2',
#   '!',
#   'the',
#   'steak',
#   'was',
#   'delicious',
#   ',',
#   'and',
#   'the',
#   'peppers/onions',
#   'were',
#   'perfectly',
#   'prepared',
#   '.',
#   'solid',
#   'dish',
#   '.',
#   'my',
#   'dad',
#   'ordered',
#   'an',
#   'el',
#   'catrin',
#   '-',
#   'his',
#   'new',
#   'favorite',
#   'drink',
#   'and',
#   'he',
#   'will',
#   'not',
#   'stop',
#   'talking',
#   'about',
#   'it',
#   '.',
#   'he',
#   "'s",
#   'asked',
#   'the',
#   'restaurant',
#   'for',
#   'the',
#   'recipe',
#   ',',
#   'but',
#   'to',
#   'no',
#   'avail',
#   '-',
#   'he',
#   "'s",
#   'gone',
#   'out',
#   'and',
#   'even',
#   'purchased',
#   'all',
#   'the',
#   'ingredients',
#   'to',
#   'make',
#   'this',
#   'smokey',
#   'delicious',
#   'drink',
#   '(',
#   'currently',
#   'still',
#   'in',
#   'the',
#   'workshopping',
#   'stage',
#   ')',
#   '.',
#   'it',
#   "'s",
#   'definitely',
#   'not',
#   'my',
#   'drink',
#   ',',
#   'but',
#   'expertly',
#   'made',
#   'and',
#   'served',
#   'in',
#   'a',
#   'rocks',
#   'glass',
#   '-',
#   'it',
#   'was',
#   'really',
#   'pretty',
#   '!',
#   '(',
#   'it',
#   "'s",
#   'bitter',
#   'truth',
#   'jerry',
#   'thomas',
#   'bitters',
#   ',',
#   'simple',
#   'syrup',
#   ',',
#   'el',
#   'buho',
#   'mezcal',
#   ',',
#   'and',
#   'casamigos',
#   'reposado',
#   ')',
#   '.is',
#   'this',
#   'the',
#   'best',
#   'mexican',
#   'food',
#   'i',
#   "'ve",
#   'ever',
#   'had',
#   '?',
#   'no',
#   ',',
#   'but',
#   'it',
#   "'s",
#   'damn',
#   'good',
#   '.',
#   'good',
#   'quality',
#   'ingredients',
#   ',',
#   'a',
#   'fun',
#   'menu',
#   ',',
#   'and',
#   'plenty',
#   'of',
#   'offerings',
#   '.',
#   'i',
#   'wo',
#   "n't",
#   'hesitate',
#   'to',
#   'come',
#   'back',
#   'in',
#   'the',
#   'future',
#   '.',
#   'a',
#   'fun',
#   'place',
#   'with',
#   'an',
#   'upbeat',
#   'atmosphere',
#   '-',
#   'the',
#   'menu',
#   'is',
#   'large',
#   ',',
#   'and',
#   'looking',
#   'forward',
#   'to',
#   'working',
#   'my',
#   'way',
#   'through',
#   'it',
#   '.'],
#  ['wow',
#   ',',
#   'i',
#   "'m",
#   'genuinely',
#   'shocked',
#   'by',
#   'the',
#   'negative',
#   'reviews',
#   '(',
#   'and',
#   'i',
#   'do',
#   "n't",
#   'understand',
#   'why',
#   'someone',
#   'would',
#   'be',
#   'a',
#   'camper',
#   'there',
#   'for',
#   '4',
#   'years',
#   ',',
#   'and',
#   'an',
#   'employee',
#   'for',
#   '9',
#   ',',
#   'if',
#   'it',
#   'was',
#   'so',
#   'utterly',
#   'awful',
#   '?',
#   ')',
#   '.we',
#   'were',
#   'blown',
#   'away',
#   'by',
#   'the',
#   'camp',
#   'when',
#   'we',
#   'first',
#   'visited',
#   '-',
#   'the',
#   'camp',
#   'itself',
#   'is',
#   'stunning',
#   ':',
#   'multiple',
#   'pools',
#   ',',
#   'lake',
#   ',',
#   'shady',
#   'trees',
#   'everywhere',
#   ',',
#   'etc',
#   '.',
#   'my',
#   'son',
#   'loves',
#   'it',
#   'there',
#   'and',
#   'could',
#   "n't",
#   'be',
#   'happier',
#   'at',
#   'camp',
#   '.',
#   'his',
#   'favorite',
#   'things',
#   'are',
#   'gaga',
#   'and',
#   'color',
#   'wars',
#   '.',
#   'he',
#   'says',
#   'he',
#   'wants',
#   'to',
#   'keep',
#   'going',
#   'back',
#   'every',
#   'summer',
#   'until',
#   'he',
#   'can',
#   'be',
#   'a',
#   'counselor',
#   'there',
#   '.'],
#  ['wonderful',
#   'authentic',
#   'mexican',
#   'food',
#   '.',
#   'friendly',
#   'service',
#   'and',
#   'nice',
#   'atmosphere',
#   '.',
#   'been',
#   'here',
#   'several',
#   'times',
#   'and',
#   'it',
#   'is',
#   'consistent',
#   '.',
#   'great',
#   'local',
#   'restaurant',
#   '.'],
#  ['authentic',
#   'mexican',
#   'food',
#   'and',
#   'friendly',
#   'service',
#   '!',
#   '!',
#   'the',
#   'food',
#   'was',
#   'delicious',
#   'and',
#   'so',
#   'were',
#   'the',
#   'margaritas',
#   ',',
#   'fresh',
#   'lime',
#   'nice-no',
#   'pre-made',
#   'mix',
#   '!',
#   'the',
#   'guacamole',
#   'was',
#   'also',
#   'fresh',
#   'and',
#   'delicious',
#   '.',
#   'we',
#   'will',
#   'definitely',
#   'be',
#   'going',
#   'back',
#   'and',
#   'they',
#   'have',
#   'a',
#   'cute',
#   'outside',
#   'deck',
#   'area',
#   'i',
#   'would',
#   'like',
#   'to',
#   'eat',
#   'on',
#   'when',
#   'it',
#   'is',
#   'not',
#   'as',
#   'hot',
#   'outside',
#   '.'],
#  ['very',
#   'disappointed',
#   'to',
#   'much',
#   'to',
#   'list',
#   'wo',
#   "n't",
#   'be',
#   'returning',
#   '.',
#   'very',
#   'dry',
#   'chicken',
#   'in',
#   'my',
#   'enchilada',
#   'do',
#   "n't",
#   'believe',
#   'the',
#   'hype',
#   'i',
#   "'ve",
#   'been',
#   'in',
#   'the',
#   'food',
#   'business',
#   'for',
#   'over',
#   '30yrs',
#   '.',
#   'i',
#   'can',
#   'tell',
#   'you',
#   'the',
#   'food',
#   'is',
#   'pre',
#   'made',
#   'and',
#   'then',
#   'reheated',
#   'no',
#   'way',
#   'it',
#   'would',
#   'be',
#   'that',
#   'dry',
#   'if',
#   'it',
#   'was',
#   'freshly',
#   'made'],
#  ['great',
#   'little',
#   'place',
#   'in',
#   'medford',
#   'lakes',
#   '.',
#   'always',
#   'a',
#   'great',
#   'variety',
#   'of',
#   'flavors',
#   'and',
#   'choices',
#   '.',
#   'service',
#   'is',
#   'always',
#   'good',
#   'and',
#   'the',
#   'ice',
#   'cream',
#   'itself',
#   'is',
#   'top-notch',
#   '.',
#   'can',
#   'get',
#   'pricey',
#   ',',
#   'and',
#   'they',
#   'only',
#   'accept',
#   'cash',
#   '.'],
#  ['sushi',
#   'is',
#   'always',
#   'good',
#   '.',
#   'great',
#   'party',
#   'trays',
#   'when',
#   'you',
#   'have',
#   'alot',
#   'of',
#   'sushi',
#   'lovers',
#   '.',
#   'soups',
#   'and',
#   'appetizers',
#   'are',
#   'really',
#   'good',
#   'too',
#   '.',
#   'only',
#   'issue',
#   'is',
#   'sometimes',
#   'they',
#   'are',
#   's',
#   'l',
#   'o',
#   'w',
#   'with',
#   'orders',
#   '.',
#   'tell',
#   'you',
#   '20',
#   'min',
#   'and',
#   '40',
#   'min',
#   'later',
#   '...',
#   'but',
#   'other',
#   'than',
#   'that',
#   'it',
#   "'s",
#   'great',
#   '.'],
#  ['jasmine',
#   'is',
#   'great',
#   '!',
#   'i',
#   'have',
#   'been',
#   'going',
#   'to',
#   'this',
#   'spot',
#   'ever',
#   'since',
#   'i',
#   'was',
#   'a',
#   'kid',
#   '.',
#   'after',
#   'moving',
#   'away',
#   'and',
#   'living',
#   'in',
#   'multiple',
#   'cities',
#   'and',
#   'various',
#   'countries',
#   ',',
#   'i',
#   'still',
#   'crave',
#   'this',
#   'place',
#   '.',
#   'not',
#   'only',
#   'is',
#   'the',
#   'food',
#   'delicious',
#   'but',
#   'the',
#   'service',
#   'is',
#   'amazing',
#   '.',
#   'each',
#   'time',
#   'i',
#   'have',
#   'arrived',
#   ',',
#   'you',
#   'are',
#   'warmly',
#   'greeted',
#   'by',
#   'one',
#   'of',
#   'the',
#   'owners',
#   '.',
#   'they',
#   'serve',
#   'a',
#   'wide',
#   'variety',
#   'of',
#   'food',
#   'from',
#   'asia',
#   '-',
#   'depending',
#   'on',
#   'your',
#   'preference',
#   'or',
#   'daily',
#   'craving',
#   '.',
#   'they',
#   'serve',
#   'thai',
#   ',',
#   'japanese',
#   ',',
#   'chinese',
#   ',',
#   'and',
#   'vietnamese',
#   '.',
#   'their',
#   'sushi',
#   'is',
#   'delicious',
#   'and',
#   'fresh',
#   '.',
#   'i',
#   'always',
#   'order',
#   'the',
#   'chef',
#   'specials',
#   'and',
#   'the',
#   'recommendations',
#   'made',
#   'by',
#   'the',
#   'server',
#   '-',
#   'they',
#   'have',
#   'never',
#   'steered',
#   'me',
#   'wrong.they',
#   'do',
#   "n't",
#   'have',
#   'a',
#   'liquor',
#   'license',
#   'and',
#   'are',
#   'byob',
#   '-',
#   'so',
#   'swing',
#   'by',
#   'medford',
#   'wine',
#   ',',
#   'located',
#   'in',
#   'the',
#   'same',
#   'shopping',
#   'center',
#   '.'],
#  ['haddonfield',
#   "'s",
#   'finest',
#   '.',
#   'everything',
#   'we',
#   "'ve",
#   'tried',
#   'on',
#   'the',
#   'menu',
#   'has',
#   'been',
#   'fantastic',
#   '.',
#   'serving',
#   'staff',
#   'is',
#   'attentive',
#   '.',
#   'atmosphere',
#   'is',
#   'cozy',
#   'and',
#   'relaxed',
#   '.',
#   'highly',
#   'recommend',
#   'the',
#   'cap',
#   'steak',
#   'medium-rear',
#   ';',
#   'one',
#   'of',
#   'the',
#   'best',
#   'cuts',
#   'of',
#   'steak',
#   'you',
#   'can',
#   'have',
#   'and',
#   'they',
#   'prepare',
#   'it',
#   'perfectly',
#   '.',
#   'great',
#   'desserts',
#   'and',
#   'coffee',
#   'as',
#   'well',
#   '.',
#   'byob',
#   'helps',
#   'save',
#   'some',
#   'money',
#   '.',
#   'if',
#   'you',
#   'have',
#   "n't",
#   'been',
#   ',',
#   'go',
#   '.'],
#  ['best',
#   'cheesesteaks',
#   'around',
#   '!',
#   'we',
#   'order',
#   'almost',
#   'once',
#   'a',
#   'week',
#   '.',
#   'we',
#   'also',
#   'love',
#   'their',
#   'funnel',
#   'cake',
#   'fries',
#   ',',
#   'the',
#   'large',
#   'is',
#   'enough',
#   'for',
#   'the',
#   'whole',
#   'family',
#   '.'],
#  ['i',
#   'love',
#   'their',
#   'cheesesteaks',
#   ',',
#   'a',
#   'good',
#   'amount',
#   'of',
#   'steak',
#   ',',
#   'plenty',
#   'of',
#   'cheese',
#   ',',
#   'and',
#   'if',
#   'you',
#   'like',
#   'onions',
#   'you',
#   'will',
#   'definitely',
#   'get',
#   'your',
#   'monies',
#   'worth',
#   '.',
#   'they',
#   'give',
#   'you',
#   'a',
#   'card',
#   'and',
#   'for',
#   'every',
#   '10',
#   'steaks',
#   'you',
#   'order',
#   'you',
#   'get',
#   '1',
#   'free',
#   'and',
#   'i',
#   "'ve",
#   'gotten',
#   'quite',
#   'a',
#   'few',
#   'free',
#   'ones',
#   '.',
#   'people',
#   'are',
#   'really',
#   'nice',
#   'and',
#   'the',
#   'service',
#   'is',
#   'quick',
#   '.'],
#  ['came',
#   'here',
#   'with',
#   'my',
#   'family',
#   'on',
#   'a',
#   'saturday',
#   'night',
#   'and',
#   'were',
#   'seated',
#   'promptly',
#   '.',
#   'i',
#   'found',
#   'that',
#   'all',
#   'the',
#   'servers',
#   'were',
#   'all',
#   'friendly',
#   'and',
#   'attentive',
#   'with',
#   'clearing',
#   'dishes',
#   'and',
#   'refilling',
#   'waters',
#   '.',
#   'we',
#   'ordered',
#   'the',
#   'seafood',
#   'salad',
#   '(',
#   'an',
#   'appetizer',
#   'special',
#   ')',
#   'and',
#   'grilled',
#   'calamari',
#   'to',
#   'start',
#   ',',
#   'and',
#   'i',
#   'enjoyed',
#   'both',
#   'very',
#   'much',
#   '!',
#   'i',
#   'asked',
#   'that',
#   'the',
#   'dressings',
#   'come',
#   'on',
#   'the',
#   'side',
#   'and',
#   'i',
#   'did',
#   'not',
#   'have',
#   'any',
#   'issues',
#   'with',
#   'it',
#   '.',
#   'for',
#   'my',
#   'entree',
#   ',',
#   'i',
#   'got',
#   'the',
#   'whole',
#   'branzino',
#   'and',
#   'thought',
#   'it',
#   'was',
#   'really',
#   'good',
#   '!',
#   'others',
#   'got',
#   'the',
#   'lobster',
#   'ravioli',
#   ',',
#   'the',
#   'steak',
#   'special',
#   ',',
#   'and',
#   'dover',
#   'sole',
#   '.',
#   'i',
#   'personally',
#   'thought',
#   'the',
#   'steak',
#   'and',
#   'dover',
#   'sole',
#   'was',
#   'just',
#   'mediocre',
#   'and',
#   'nothing',
#   'to',
#   'brag',
#   'about',
#   '.',
#   'overall',
#   ',',
#   'i',
#   'really',
#   'enjoyed',
#   'my',
#   'entree',
#   'and',
#   'liked',
#   'the',
#   'service',
#   'here',
#   '!'],
#  ['the',
#   'place',
#   'gives',
#   'good',
#   'hair',
#   'cuts',
#   'but',
#   'i',
#   'went',
#   'there',
#   'recently',
#   'and',
#   'i',
#   'told',
#   'them',
#   'i',
#   'have',
#   'a',
#   'bald',
#   'spot',
#   ',',
#   'usually',
#   'they',
#   'hid',
#   'it',
#   'but',
#   'this',
#   'time',
#   'they',
#   'just',
#   'disregarded',
#   'that',
#   'and',
#   'maid',
#   'it',
#   'very',
#   'visible',
#   'and',
#   'they',
#   'cut',
#   'it',
#   'way',
#   'to',
#   'short',
#   '.'],
#  ['this',
#   'place',
#   'is',
#   'the',
#   'worst',
#   '.',
#   'the',
#   'manager',
#   'at',
#   'the',
#   'location',
#   'knows',
#   'it',
#   'and',
#   'does',
#   "n't",
#   'care',
#   '.',
#   'everything',
#   'about',
#   'this',
#   'location',
#   'is',
#   'gross',
#   ',',
#   'the',
#   'food',
#   'and',
#   'staff',
#   'included',
#   '.'],
#  ['went',
#   'here',
#   'with',
#   'family',
#   'and',
#   'friends',
#   'for',
#   'dinner',
#   'and',
#   'was',
#   'incredibly',
#   'impressed',
#   'by',
#   'the',
#   'service',
#   '.',
#   'we',
#   'ordered',
#   'a',
#   'variety',
#   'of',
#   'appetizers',
#   'and',
#   'mains',
#   '.',
#   'when',
#   'my',
#   'boyfriend',
#   'and',
#   'i',
#   'received',
#   'our',
#   'steaks',
#   ',',
#   'they',
#   'were',
#   'both',
#   'more',
#   'than',
#   'well',
#   'done',
#   ',',
#   'not',
#   'medium',
#   'as',
#   'requested',
#   '.',
#   'not',
#   'only',
#   'did',
#   'the',
#   'waiter',
#   'apologize',
#   'profusely',
#   'and',
#   're-do',
#   'our',
#   'orders',
#   ',',
#   'but',
#   'the',
#   'meals',
#   'were',
#   'paid',
#   'for',
#   'by',
#   'the',
#   'house',
#   ',',
#   'and',
#   'everyone',
#   'in',
#   'our',
#   'party',
#   'was',
#   'given',
#   'a',
#   'complimentary',
#   'dessert',
#   '.',
#   'this',
#   'left',
#   'a',
#   'very',
#   'good',
#   'taste',
#   'in',
#   'our',
#   'mouths',
#   'when',
#   'leaving',
#   'and',
#   'if/when',
#   'we',
#   'are',
#   'in',
#   'town',
#   'again',
#   'we',
#   'wo',
#   "n't",
#   'hesitate',
#   'to',
#   'stop',
#   'by',
#   '.'],
#  ['very',
#   'good',
#   'experience',
#   '.',
#   'dropped',
#   'in',
#   'here',
#   'based',
#   'on',
#   'a',
#   'business',
#   'meeting',
#   'in',
#   'the',
#   'area',
#   'and',
#   'was',
#   'very',
#   'surprised',
#   'and',
#   'pleased',
#   '.',
#   'great',
#   'flatbreads',
#   ',',
#   'great',
#   'wine',
#   'and',
#   'food',
#   'overall',
#   ',',
#   'and',
#   'our',
#   'waitress',
#   'was',
#   'awesome',
#   'in',
#   'the',
#   'bar',
#   'area',
#   '.',
#   'all',
#   'too',
#   'often',
#   'a',
#   'wait',
#   'staff',
#   'member',
#   'will',
#   'say',
#   '``',
#   'everything',
#   "'s",
#   'good',
#   "''",
#   'but',
#   'our',
#   'waitress',
#   'at',
#   'harvest',
#   'gave',
#   'very',
#   'specific',
#   'recommendations',
#   '.',
#   'wished',
#   'this',
#   'place',
#   'was',
#   'closer',
#   'to',
#   'home',
#   ',',
#   'i',
#   "'d",
#   'come',
#   'more',
#   'often',
#   '!',
#   'ps-',
#   'dessert',
#   'in',
#   'the',
#   'shot',
#   'glasses',
#   'was',
#   'an',
#   'awesome',
#   'idea',
#   'and',
#   'hard',
#   'to',
#   'say',
#   'no',
#   'when',
#   'they',
#   'bring',
#   'it',
#   'around',
#   '!',
#   'i',
#   'did',
#   'feel',
#   'like',
#   'the',
#   'cake',
#   'component',
#   'of',
#   'the',
#   'carrot',
#   'cake',
#   'dessert',
#   'was',
#   'lacking',
#   'in',
#   'volume',
#   '(',
#   'ie-',
#   'it',
#   'was',
#   'mostly',
#   'frosting',
#   ',',
#   'not',
#   'enough',
#   'moist',
#   'cake',
#   ')',
#   ',',
#   'but',
#   'that',
#   "'s",
#   'my',
#   'only',
#   'real',
#   'criticism',
#   '.'],
#  ...]

# %% [markdown]
# ### Bag of Words

# %%
pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in /Users/josesalerno/Library/Python/3.9/lib/python/site-packages (1.4.1.post1)
# Requirement already satisfied: scipy>=1.6.0 in /Users/josesalerno/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (1.12.0)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in /Users/josesalerno/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/josesalerno/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (3.3.0)
# Requirement already satisfied: joblib>=1.2.0 in /Users/josesalerno/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (1.3.2)
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer()

cv.fit(text_df.text)
print("Number of 'tokens'", len(cv.vocabulary_))
cv.vocabulary_
# Out:
# Number of 'tokens' 133368
# {'discovered': 36598,
#  'my': 79632,
#  'new': 81041,
#  'favorite': 44884,
#  'food': 47276,
#  'truck': 121498,
#  'in': 60175,
#  'the': 117972,
#  'reno': 98341,
#  'sparks': 110634,
#  'area': 10229,
#  'few': 45488,
#  'days': 33319,
#  'ago': 6876,
#  'schnitzel': 103925,
#  'austrian': 11841,
#  'grill': 53298,
#  'is': 62264,
#  'amazing': 8252,
#  'it': 62426,
#  'also': 8003,
#  'wonderful': 130082,
#  'place': 90496,
#  'to': 119450,
#  'eat': 39655,
#  'gluten': 51752,
#  'free': 48272,
#  'basically': 13929,
#  'everything': 42928,
#  'except': 43163,
#  'their': 118056,
#  'bread': 18802,
#  'can': 21904,
#  'be': 14335,
#  'or': 84490,
#  'already': 7980,
#  'for': 47471,
#  'those': 118499,
#  'who': 129109,
#  'by': 21018,
#  'choice': 25765,
#  'sounds': 110326,
#  'like': 69650,
#  'you': 131889,
#  'gf': 50946,
#  'ciabatta': 26247,
#  'but': 20805,
#  'she': 106198,
#  'doesn': 37467,
#  'feel': 45117,
#  'safe': 102108,
#  'serving': 105522,
#  'people': 88344,
#  'are': 10227,
#  'celiac': 23737,
#  'have': 55590,
#  'allergic': 7754,
#  'issues': 62397,
#  'right': 99951,
#  'now': 82436,
#  'there': 118151,
#  'may': 74370,
#  'cross': 31529,
#  'contamination': 29424,
#  'issue': 62392,
#  'with': 129829,
#  'supplier': 114606,
#  'currently': 32243,
#  'kirsten': 66270,
#  'extremely': 43835,
#  'personable': 88813,
#  'and': 8776,
#  'very': 125993,
#  'knowledgeable': 66603,
#  'about': 5291,
#  'ordered': 84577,
#  'pork': 91785,
#  'red': 97155,
#  'beet': 14787,
#  'apple': 9783,
#  'salad': 102276,
#  'cucumber': 31979,
#  'ligonberry': 69622,
#  'jam': 63001,
#  'shocking': 106707,
#  'how': 58299,
#  'this': 118412,
#  'breading': 18818,
#  'perfect': 88535,
#  'not': 82233,
#  'too': 119884,
#  'dry': 38781,
#  'soggy': 109657,
#  'nor': 82050,
#  'thick': 118283,
#  'platters': 90725,
#  'come': 28040,
#  'two': 122274,
#  'sides': 107334,
#  'one': 83993,
#  'condiment': 28830,
#  'they': 118250,
#  'serve': 105422,
#  'entrees': 41762,
#  'as': 10797,
#  'sandwich': 102819,
#  'had': 54492,
#  'opportunity': 84393,
#  'sample': 102689,
#  'several': 105646,
#  'of': 83329,
#  'items': 62509,
#  'loved': 71182,
#  'were': 128547,
#  'was': 127719,
#  'crazy': 31034,
#  'good': 52146,
#  'even': 42817,
#  'though': 118505,
#  'sounded': 110317,
#  'bit': 16419,
#  'odd': 83252,
#  'me': 74808,
#  'at': 11273,
#  'first': 46092,
#  'chilled': 25410,
#  'chickpea': 25293,
#  'sauerkraut': 103265,
#  'other': 85011,
#  'potato': 92076,
#  'mixed': 77302,
#  'french': 48386,
#  'fries': 48612,
#  'entree': 41757,
#  'cannot': 22085,
#  'wait': 127291,
#  'try': 121605,
#  'fish': 46121,
#  'arrived': 10615,
#  'later': 68264,
#  'day': 33285,
#  'so': 109454,
#  'run': 101649,
#  'out': 85128,
#  'believe': 15034,
#  'haddock': 54500,
#  'got': 52457,
#  'bratwurst': 18716,
#  'currywurst': 32268,
#  'cranberry': 30894,
#  'horseradish': 57986,
#  'cream': 31060,
#  'oh': 83495,
#  'an': 8669,
#  'authentic': 11858,
#  'german': 50792,
#  'opinion': 84352,
#  'honestly': 57635,
#  'tastiest': 116578,
#  'sausage': 103292,
#  'town': 120459,
#  'has': 55425,
#  'snap': 109149,
#  'when': 128874,
#  'bite': 16437,
#  'into': 61815,
#  'tremendous': 121057,
#  'flavors': 46560,
#  'hesitant': 56568,
#  'because': 14566,
#  'never': 81011,
#  'been': 14729,
#  'fan': 44434,
#  'curry': 32256,
#  'maybe': 74383,
#  'haven': 55596,
#  'times': 119080,
#  've': 125459,
#  'before': 14819,
#  'knows': 66619,
#  'that': 117932,
#  'wished': 129780,
#  'some': 109837,
#  'sop': 110100,
#  'rest': 98965,
#  'up': 124447,
#  'aaaamazing': 5047,
#  'know': 66583,
#  'sound': 110311,
#  'am': 8131,
#  'really': 96543,
#  'straight': 113104,
#  'slightly': 108507,
#  'tamer': 116112,
#  'than': 117886,
#  'nice': 81230,
#  'quality': 94963,
#  'wasabi': 127729,
#  'totally': 120274,
#  'recommend': 96987,
#  'whatever': 128794,
#  'order': 84568,
#  'if': 59501,
#  'handle': 54957,
#  'heat': 55917,
#  'much': 78963,
#  'do': 37348,
#  'love': 71172,
#  'told': 119661,
#  'workers': 130329,
#  'didn': 35800,
#  'our': 85100,
#  'local': 70395,
#  'natural': 80350,
#  'grocers': 53430,
#  'quite': 95349,
#  'detail': 35292,
#  'inspired': 61332,
#  'start': 112218,
#  'blogging': 16974,
#  'great': 52993,
#  'places': 90530,
#  'conclusion': 28761,
#  'here': 56422,
#  'safely': 102119,
#  'almost': 7907,
#  'every': 42903,
#  'item': 62500,
#  'available': 12015,
#  'service': 105450,
#  'top': 119980,
#  'notch': 82256,
#  'felt': 45221,
#  'known': 66613,
#  'them': 118073,
#  'long': 70726,
#  'time': 119048,
#  'visit': 126595,
#  'where': 128881,
#  'else': 40763,
#  'get': 50871,
#  'schnitzels': 103927,
#  'sean': 104596,
#  'byrd': 21085,
#  'guide': 53937,
#  'on': 83964,
#  'city': 26575,
#  'tour': 120368,
#  'he': 55749,
#  'excellent': 43136,
#  'held': 56125,
#  'everyone': 42915,
#  'attention': 11555,
#  'entire': 41718,
#  'we': 128082,
#  'learned': 68687,
#  'surrounding': 114813,
#  'including': 60338,
#  'history': 57071,
#  'from': 48801,
#  'its': 62571,
#  'founding': 47844,
#  'hurricane': 58836,
#  'katrina': 65269,
#  'disaster': 36476,
#  'affects': 6564,
#  'covid': 30638,
#  'more': 78337,
#  'ideas': 59411,
#  'want': 127565,
#  'only': 84066,
#  'thing': 118339,
#  'could': 30398,
#  'made': 72172,
#  'better': 15619,
#  'would': 130472,
#  'map': 73282,
#  'route': 101266,
#  'marked': 73614,
#  'being': 14947,
#  'state': 112268,
#  'easily': 39610,
#  'direction': 36310,
#  'turned': 122008,
#  'plus': 91060,
#  'able': 5234,
#  'mark': 73606,
#  'go': 51846,
#  'own': 85827,
#  'taking': 115965,
#  'orleans': 84791,
#  'price': 93040,
#  'super': 114435,
#  'fun': 49229,
#  'parade': 86811,
#  'sunday': 114310,
#  'afternoon': 6702,
#  'mardi': 73406,
#  'gras': 52826,
#  'runs': 101691,
#  'unique': 123723,
#  'favorites': 44892,
#  'attempt': 11524,
#  'pass': 87303,
#  'front': 48827,
#  'all': 7702,
#  'extended': 43735,
#  'healthcare': 55839,
#  'facilities': 44108,
#  'care': 22542,
#  'disabilities': 36377,
#  'illnesses': 59696,
#  'generous': 50580,
#  'caring': 22622,
#  'krewe': 67045,
#  'makes': 72610,
#  'special': 110765,
#  'floats': 46762,
#  'huge': 58541,
#  'many': 73262,
#  'riders': 99867,
#  'look': 70824,
#  're': 96400,
#  'having': 55618,
#  'blast': 16744,
#  'way': 128007,
#  'your': 131938,
#  'started': 112221,
#  'carry': 22897,
#  'through': 118648,
#  'stretch': 113311,
#  'horrible': 57944,
#  'read': 96444,
#  'boisterous': 17498,
#  'articles': 10713,
#  'comparing': 28360,
#  'big': 15970,
#  'ones': 84011,
#  'such': 113952,
#  'macy': 72143,
#  'thanksgiving': 117912,
#  'knew': 66500,
#  'couldn': 30404,
#  'thought': 118518,
#  'well': 128442,
#  'put': 94660,
#  'together': 119599,
#  'entertaining': 41688,
#  'boy': 18443,
#  'wrong': 130666,
#  'gaps': 49947,
#  'between': 15649,
#  'different': 35888,
#  'use': 124752,
#  'term': 117548,
#  'loosely': 70933,
#  'mostly': 78558,
#  'marching': 73386,
#  'bands': 13336,
#  'maroon': 73703,
#  'camaros': 21758,
#  'carrying': 22899,
#  'indy': 60656,
#  'drivers': 38595,
#  'wives': 129907,
#  'selfies': 105028,
#  'video': 126220,
#  'phones': 89433,
#  'multiple': 79204,
#  'must': 79507,
#  'over': 85358,
#  'hadn': 54513,
#  'seen': 104878,
#  'anyone': 9444,
#  'children': 25371,
#  'adults': 6365,
#  'alike': 7656,
#  'bored': 18009,
#  'around': 10536,
#  'us': 124722,
#  'whining': 128966,
#  'ready': 96471,
#  'dreaded': 38379,
#  'walk': 127409,
#  'back': 12648,
#  'car': 22382,
#  'did': 35788,
#  'won': 130068,
#  'save': 103354,
#  'money': 77945,
#  'sanity': 102897,
#  'interested': 61605,
#  'watch': 127824,
#  'tv': 122110,
#  'arnold': 10496,
#  'palmer': 86350,
#  'sweltering': 115222,
#  'labor': 67530,
#  'weekend': 128250,
#  'trying': 121616,
#  'cut': 32406,
#  'down': 38143,
#  'sugar': 114062,
#  'content': 29449,
#  'asked': 10954,
#  'unsweetened': 124286,
#  'iced': 59315,
#  'tea': 116881,
#  'lemonade': 68993,
#  'think': 118364,
#  'gave': 50275,
#  'sweetened': 115165,
#  'still': 112726,
#  'cloyingly': 27228,
#  'sweet': 115150,
#  'which': 128919,
#  'unpleasant': 123970,
#  'hot': 58094,
#  'rather': 96168,
#  'refreshing': 97532,
#  'preferred': 92593,
#  'starbucks': 112079,
#  'dunkin': 39154,
#  'donuts': 37794,
#  'location': 70426,
#  'decor': 33779,
#  'milk': 76517,
#  'honey': 57639,
#  'beautiful': 14514,
#  'scenic': 103722,
#  'borden': 17993,
#  'park': 86976,
#  'years': 131412,
#  'washroom': 127771,
#  'looks': 70843,
#  'clean': 26882,
#  'families': 44409,
#  'came': 21780,
#  'help': 56220,
#  'yelp': 131529,
#  'booth': 17922,
#  'jennie': 63526,
#  'porkapolloza': 91789,
#  'event': 42834,
#  'weather': 128130,
#  'fantastic': 44524,
#  'smell': 108889,
#  'bbq': 14271,
#  'everywhere': 42941,
#  'venue': 125775,
#  'will': 129416,
#  'went': 128533,
#  'launch': 68376,
#  'festival': 45415,
#  'found': 47837,
#  'craft': 30840,
#  'beer': 14742,
#  'going': 51996,
#  'things': 118353,
#  'see': 104818,
#  'chocolate': 25736,
#  'pairings': 86217,
#  'distillery': 37079,
#  'district': 37123,
#  'vip': 126518,
#  'experience': 43521,
#  'section': 104767,
#  'larger': 68125,
#  'cask': 23110,
#  'stage': 111891,
#  'loving': 71245,
#  'beers': 14767,
#  'brewers': 19039,
#  'stuff': 113541,
#  'always': 8105,
#  'work': 130312,
#  'hand': 54900,
#  'best': 15519,
#  'ever': 42852,
#  'off': 83338,
#  'includes': 60335,
#  'pretty': 92965,
#  'neat': 80541,
#  'gets': 50896,
#  'busy': 20797,
#  'washrooms': 127772,
#  'treated': 120993,
#  'flowery': 46917,
#  'fruity': 48942,
#  'delicious': 34372,
#  'witbier': 129815,
#  'style': 113652,
#  'called': 21642,
#  'lion': 69936,
#  'wit': 129811,
#  'wardrobe': 127607,
#  'brewed': 19036,
#  'olds': 83715,
#  'college': 27835,
#  'brewing': 19048,
#  'program': 93529,
#  'myself': 79729,
#  'patio': 87538,
#  'somewhere': 109906,
#  'drinking': 38536,
#  'these': 118212,
#  'summer': 114242,
#  'edmonton': 39999,
#  'year': 131400,
#  'breweries': 19038,
#  'making': 72633,
#  'mall': 72744,
#  'just': 64564,
#  'sad': 102050,
#  'reasons': 96633,
#  'safeway': 102127,
#  'futureshop': 49445,
#  'northgate': 82156,
#  'public': 94156,
#  'helth': 56252,
#  'centre': 23850,
#  'abysmal': 5457,
#  'court': 30540,
#  'zip': 132705,
#  'options': 84464,
#  'most': 78547,
#  'stores': 113006,
#  'either': 40395,
#  'dated': 33182,
#  'dare': 33058,
#  'say': 103437,
#  'ghetto': 51005,
#  'give': 51428,
#  'stars': 112140,
#  'cared': 22545,
#  'three': 118573,
#  'definitely': 34070,
#  'needs': 80640,
#  'update': 124477,
#  'ernest': 42132,
#  'enjoy': 41497,
#  'fine': 45883,
#  'dining': 36194,
#  'reasonable': 96618,
#  'catch': 23277,
#  'friends': 48597,
#  'entertain': 41682,
#  'guests': 53912,
#  'students': 113522,
#  'culinary': 32057,
#  'arts': 10765,
#  'hospitality': 58043,
#  'management': 72886,
#  'programs': 93539,
#  'restaurant': 98995,
#  'menu': 75568,
#  'does': 37464,
#  'change': 24305,
#  'frequently': 48427,
#  'result': 99132,
#  'likely': 69660,
#  'changes': 24315,
#  'due': 38951,
#  'what': 128772,
#  'ingredients': 60950,
#  'durinf': 39236,
#  'season': 104642,
#  'stop': 112960,
#  'during': 39237,
#  'dinner': 36211,
#  'friday': 48529,
#  'lunch': 71596,
#  'often': 83462,
#  'student': 113520,
#  'showcase': 106948,
#  'buffet': 20117,
#  'heard': 55861,
#  'creative': 31127,
#  'imaginative': 59755,
#  'plated': 90684,
#  'beautifully': 14519,
#  'no': 81662,
#  'matter': 74220,
#  'end': 41281,
#  'ordering': 84589,
#  'wont': 130118,
#  'disappointed': 36425,
#  'swing': 115284,
#  'tuesdays': 121807,
#  'wednesdays': 128212,
#  'offer': 83358,
#  'prixe': 93275,
#  'fixe': 46271,
#  'name': 80019,
#  'option': 84455,
#  'flight': 46687,
#  'wine': 129572,
#  'each': 39475,
#  'course': 30525,
#  'downside': 38191,
#  'happening': 55135,
#  'usually': 124811,
#  'requires': 98680,
#  'planning': 90609,
#  'advance': 6371,
#  'especially': 42345,
#  'night': 81377,
#  'reservation': 98773,
#  'holidays': 57371,
#  'reservations': 98776,
#  'weeknight': 128268,
#  'lot': 71047,
#  'easier': 39606,
#  'manage': 72878,
#  'shorter': 106854,
#  'timeline': 119063,
#  'parking': 86998,
#  'after': 6681,
#  '5pm': 3721,
#  'unfortunately': 123538,
#  'anything': 9456,
#  'exceptional': 43168,
#  'closer': 27166,
#  'kingsway': 66208,
#  'garden': 49993,
#  'davids': 33242,
#  'inconvenient': 60411,
#  'full': 49170,
#  'fragrant': 47976,
#  'bought': 18237,
#  'teavana': 116986,
#  'knowledgable': 66599,
#  'loose': 70930,
#  'leaf': 68632,
#  'teas': 116962,
#  'bags': 12943,
#  'staff': 111858,
#  'seems': 104875,
#  'talking': 116026,
#  'happen': 55125,
#  'looking': 70835,
#  'something': 109881,
#  'specific': 110810,
#  'find': 45867,
#  'll': 70232,
#  'aside': 10938,
#  'assortment': 11146,
#  'tins': 119191,
#  'cups': 32166,
#  'kettles': 65720,
#  'pots': 92127,
#  'etc': 42558,
#  'any': 9421,
#  'specialty': 110802,
#  'shops': 106817,
#  'products': 93439,
#  'pricy': 93107,
#  'guess': 53893,
#  'pay': 87729,
#  'used': 124755,
#  'meh': 75226,
#  'neighbourhood': 80763,
#  'decided': 33675,
#  'peruse': 88898,
#  'stalls': 111979,
#  'improvement': 60134,
#  'worthy': 130455,
#  'upgrade': 124496,
#  'past': 87371,
#  'filled': 45760,
#  'star': 112068,
#  'restaurants': 99017,
#  'hawking': 55649,
#  'greasy': 52989,
#  'uninspired': 123694,
#  'eats': 39700,
#  'lots': 71068,
#  'intriguing': 61863,
#  'tasty': 116591,
#  'offerings': 83367,
#  'slanted': 108339,
#  'foodie': 47316,
#  'pig': 89839,
#  'tail': 115880,
#  'bacon': 12798,
#  'bean': 14394,
#  'ragout': 95700,
#  'solstice': 109802,
#  'tacos': 115767,
#  'kimchi': 66097,
#  'slaw': 108389,
#  'lemon': 68991,
#  'thyme': 118784,
#  'aioli': 7113,
#  'fairmont': 44254,
#  'hotel': 58111,
#  'macdonald': 72020,
#  'bison': 16383,
#  'canneloni': 22053,
#  'wild': 129361,
#  'mushrooms': 79440,
#  'fantasia': 44512,
#  'maple': 73286,
#  'creamed': 31072,
#  'corn': 30018,
#  'northern': 82150,
#  'chicken': 25248,
#  'tried': 121200,
#  'above': 5301,
#  'sized': 107958,
#  'portions': 91892,
#  'dose': 37982,
#  'usual': 124807,
#  'suspects': 114896,
#  'smattering': 108874,
#  'ethnic': 42609,
#  'cuisines': 32035,
#  'ethiopian': 42606,
#  'afghan': 6627,
#  'korean': 66858,
#  'indian': 60533,
#  'thai': 117866,
#  'chinese': 25517,
#  'italian': 62442,
#  'trucks': 121509,
#  'desserts': 35240,
#  'fanfan': 44477,
#  'patisserie': 87549,
#  'drinks': 38546,
#  'bubble': 19920,
#  'grizzly': 53419,
#  'paw': 87708,
#  'sodas': 109558,
#  'lines': 69854,
#  'surprisingly': 114791,
#  'short': 106834,
#  'saturday': 103199,
#  'churchill': 26167,
#  'square': 111575,
#  'main': 72483,
#  'nightly': 81402,
#  'concerts': 28726,
#  'via': 126100,
#  'tickets': 118847,
#  'expensive': 43492,
#  'side': 107302,
#  '75': 4248,
#  'dishes': 36721,
#  'consider': 29234,
#  'ends': 41351,
#  'mistake': 77197,
#  'prepurchase': 92774,
#  'online': 84053,
#  '20': 1523,
#  'discount': 36579,
#  'bad': 12823,
#  'rediscovered': 97258,
#  'improved': 60132,
#  'fest': 45403,
#  'last': 68221,
#  'check': 24744,
#  'again': 6735,
#  'next': 81139,
#  'craving': 30984,
#  'blueberry': 17114,
#  'ice': 59299,
#  'weeks': 128272,
#  'strange': 113142,
#  'series': 105365,
#  'events': 42841,
#  'prevented': 92995,
#  'getting': 50907,
#  'hands': 54990,
#  '40': 2846,
#  'evening': 42821,
#  'moment': 77860,
#  'then': 118102,
#  'flew': 46654,
#  'closest': 27170,
#  'apartment': 9534,
#  'blew': 16857,
#  'door': 37845,
#  '50': 3294,
#  'thinking': 118368,
#  'greeted': 53172,
#  'surly': 114762,
#  'teens': 117103,
#  'absolutely': 5370,
#  'case': 23044,
#  'served': 105423,
#  'smiles': 108930,
#  'finish': 45938,
#  'anastasia': 8733,
#  'lovely': 71217,
#  'ate': 11309,
#  'fault': 44839,
#  'yes': 131610,
#  'waiting': 127309,
#  'fuckin': 49045,
#  'chance': 24274,
#  'week': 128243,
#  'thank': 117896,
#  'lord': 70981,
#  'cool': 29779,
#  'space': 110494,
#  'comfy': 28098,
#  'soon': 110039,
#  'sit': 107866,
#  'queso': 95168,
#  'verde': 125819,
#  'phenomenal': 89215,
#  'deep': 33903,
#  'fried': 48539,
#  'cheese': 24868,
#  'pool': 91630,
#  'salsa': 102459,
#  'warm': 127633,
#  'tortillas': 120182,
#  'whether': 128898,
#  'wanna': 127549,
#  'taco': 115749,
#  'mess': 75815,
#  'highly': 56761,
#  'unbelievable': 122889,
#  'types': 122339,
#  'carne': 22736,
#  'asada': 10804,
#  'carnitas': 22751,
#  'shrimp': 107042,
#  'meat': 74908,
#  'cooked': 29742,
#  'chili': 25389,
#  'oil': 83551,
#  'cilantro': 26334,
#  'favourite': 44914,
#  'mile': 76486,
#  'fresh': 48444,
#  'shade': 105814,
#  'batter': 14093,
#  'ya': 131108,
#  'awesome': 12249,
#  'tough': 120341,
#  'hard': 55201,
#  'chalk': 24174,
#  'open': 84276,
#  'spectacular': 110842,
#  'server': 105429,
#  'attentive': 11559,
#  'friendly': 48576,
#  'charming': 24542,
#  'happy': 55156,
#  'hour': 58202,
#  'prices': 93066,
#  'sure': 114707,
#  'alley': 7769,
#  'kat': 65218,
#  'capable': 22173,
#  'mexican': 75989,
#  'tasting': 116583,
#  'bucks': 19998,
#  'drink': 38524,
#  'dollar': 37578,
#  'margaritas': 73433,
#  'possible': 92002,
#  'job': 63910,
#  'guys': 54238,
#  'cheers': 24857,
#  'andy': 8883,
#  'modern': 77609,
#  'latin': 68288,
#  'american': 8397,
#  'heart': 55873,
#  'stadium': 111850,
#  'pre': 92416,
#  'post': 92011,
#  'game': 49822,
#  'interesting': 61608,
#  'cuisine': 32034,
#  'rotisserie': 101158,
#  'beef': 14682,
#  'smaller': 108822,
#  'share': 106047,
#  'small': 108816,
#  'carefully': 22556,
#  'created': 31118,
#  'overall': 85372,
#  'real': 96489,
#  'salads': 102300,
#  'classic': 26790,
#  'veggies': 125592,
#  'greens': 53127,
#  'disappointing': 36433,
#  'selection': 105000,
#  'meals': 74850,
#  'nevertheless': 81030,
#  'superb': 114438,
#  'positive': 91974,
#  'wanted': 127568,
#  'walking': 127425,
#  'street': 113252,
#  'performers': 88591,
#  'vietnamese': 126272,
#  'nights': 81413,
#  'left': 68855,
#  'boyfriend': 18464,
#  'grab': 52594,
#  'while': 128932,
#  'couple': 30500,
#  'minutes': 76860,
#  'pick': 89656,
#  'talk': 116017,
#  'quick': 95221,
#  'wish': 129776,
#  'vegas': 125531,
#  'family': 44413,
#  'vanilla': 125250,
#  'icecream': 59310,
#  'chips': 25594,
#  'reeses': 97390,
#  'mix': 77299,
#  'ins': 61211,
#  'famoso': 44426,
#  'exception': 43167,
#  'atmosphere': 11411,
#  'layout': 68532,
#  'designed': 35159,
#  'shared': 106053,
#  'tables': 115669,
#  'excuse': 43243,
#  'make': 72588,
#  'fabulous': 44051,
#  'pizzetta': 90440,
#  'soup': 110335,
#  'pepperoni': 88432,
#  'roasted': 100420,
#  'mushroom': 79437,
#  'caesar': 21337,
#  'diameter': 35659,
#  'perfectly': 88554,
#  'baked': 13036,
#  'tossed': 120229,
#  'rosted': 101103,
#  'speak': 110726,
#  'self': 105023,
#  'combination': 28015,
#  'romaine': 100804,
#  'lettuce': 69232,
#  'prosciutto': 93778,
#  'crisps': 31379,
#  'grana': 52706,
#  'padano': 86055,
#  'dressing': 38463,
#  'mood': 78216,
#  'dessert': 35238,
#  'tiramisu': 119268,
#  'yummy': 132191,
#  'groups': 53554,
#  'couples': 30504,
#  'important': 60055,
#  'keep': 65450,
#  'visiting': 126616,
#  'since': 107670,
#  'neighborhood': 80752,
#  'movie': 78789,
#  'theater': 117986,
#  'specialties': 110799,
#  'enough': 41568,
#  'accident': 5555,
#  'sucks': 113979,
#  'fixed': 46272,
#  'skeptical': 108046,
#  'seeing': 104852,
#  'comment': 28176,
#  'reputation': 98652,
#  'gary': 50104,
#  'his': 57030,
#  'team': 116920,
#  'repairing': 98437,
#  'rear': 96602,
#  'chrysler': 26055,
#  '300': 2315,
#  'paint': 86198,
#  'flawless': 46592,
#  'duplicating': 39200,
#  'metal': 75857,
#  'flake': 46358,
#  'painful': 86185,
#  'fast': 44712,
#  'helping': 56236,
#  'deserved': 35121,
#  'hooliganz': 57765,
#  'isn': 62352,
#  'ok': 83603,
#  'average': 12070,
#  'pub': 94141,
#  'nothing': 82293,
#  'expect': 43427,
#  'coolest': 29793,
#  'charge': 24474,
#  'low': 71264,
#  ...}

# %%
#dtm = cv.transform(text_df.text)
#bow = pd.DataFrame(dtm.toarray(), columns = cv.get_feature_names_out)
#bow

# %%
print('Ben 10')
# Out:
# Ben 10
