# %%
import pandas as pd

test_sample = pd.read_csv('under-sample.csv')
# Out:
# /var/folders/zp/sq6bzsp91fz1sl3107mgk5gc0000gn/T/ipykernel_5987/2574737977.py:3: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   test_sample = pd.read_csv('under-sample.csv')

# %%
test_sample.head()
# Out:
#    Unnamed: 0             business_id                 user_id  \
# 0           0  4AxmAGObMPTDqbJK3EgNgQ  WDX_KkxwI8VYOF3RHpNLpA
# 1           1  II7CpZjGyx8aFTu3wJbQNw  pgh8UtO2K13GVMv4Ih-jEw
# 2           2  ul0MGusQZBGo4CqiVh6VcA  vgiUst2zH7Zzs2FdISwQdQ
# 3           3  4vvu78FMlZyQwZf0bBUkLQ  ZzFwLI4AC9MyCBwY-kulEA
# 4           4  mRtGKvoxQLSh-tf2qBBoLg  6903ibtDSpwMDvD9Yp33wg
#
#                                                 text  cool  stars  \
# 0  I discovered my new favorite food truck in the...     1    5.0
# 1  Sean Byrd was our guide on the City Tour. He w...     0    5.0
# 2  Super fun parade on the Sunday afternoon befor...     1    5.0
# 3  Horrible. I had read boisterous articles compa...     0    1.0
# 4  I ordered an Arnold Palmer over the sweltering...     0    2.0
#
#                         date  funny               review_id  useful  ...  \
# 0  2016-01-21 06:21:55+00:00      0  fVBt5kq8lyVSK2RcpY9XQA       2  ...
# 1  2021-01-24 21:04:52+00:00      0  3Sjk89h1OLVdEm9fqoggnQ       1  ...
# 2  2016-02-13 17:40:22+00:00      1  E5-7WlkTKnnC0XlsALwRfg       1  ...
# 3  2019-05-26 18:45:25+00:00      1  JYGPNWLy8uxnxzjdNPWBQw       0  ...
# 4  2013-09-05 23:17:55+00:00      0  EA0FGcHTsgBcGpa_e1g7GA       0  ...
#
#               address          city  state latitude   longitude  \
# 0                 NaN          Reno     NV      NaN -119.813803
# 1                 NaN   New Orleans     LA      NaN  -90.077750
# 2       St Charles Ae   New Orleans     LA      NaN  -90.080723
# 3     Pennsylvania St  Indianapolis     IN      NaN  -86.155944
# 4  18th St & Logan Sq  Philadelphia     PA      NaN  -75.168697
#
#   average_business_stars recieved_reviews  \
# 0                    4.5             11.0
# 1                    5.0              6.0
# 2                    4.5              9.0
# 3                    3.5             11.0
# 4                    3.5             34.0
#
#                                       categories  \
# 0         Food, German, Food Trucks, Restaurants
# 1              Hotels & Travel, Bus Tours, Tours
# 2                                   Local Flavor
# 3  Arts & Entertainment, Festivals, Local Flavor
# 4                   Food, Bakeries, Coffee & Tea
#
#                                           attributes  tip_review
# 0  {'BusinessAcceptsCreditCards': 'True', 'Alcoho...         NaN
# 1                                                NaN         NaN
# 2                            {'GoodForKids': 'True'}         NaN
# 3                            {'GoodForKids': 'True'}         NaN
# 4  {'RestaurantsPriceRange2': '2', 'BusinessParki...         NaN
#
# [5 rows x 24 columns]

# %%
test_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 327980 entries, 0 to 327979
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Unnamed: 0              327980 non-null  int64
#  1   business_id             327980 non-null  object
#  2   user_id                 327980 non-null  object
#  3   text                    327980 non-null  object
#  4   cool                    327980 non-null  int64
#  5   stars                   327980 non-null  float64
#  6   date                    327980 non-null  object
#  7   funny                   327980 non-null  int64
#  8   review_id               327980 non-null  object
#  9   useful                  327980 non-null  int64
#  10  average_user_stars      327979 non-null  float64
#  11  yelping_since           327979 non-null  object
#  12  submitted_reviews       327979 non-null  float64
#  13  name                    327979 non-null  object
#  14  address                 324081 non-null  object
#  15  city                    327979 non-null  object
#  16  state                   327979 non-null  object
#  17  latitude                327934 non-null  object
#  18  longitude               327979 non-null  float64
#  19  average_business_stars  327979 non-null  float64
#  20  recieved_reviews        327979 non-null  float64
#  21  categories              327948 non-null  object
#  22  attributes              319604 non-null  object
#  23  tip_review              20368 non-null   object
# dtypes: float64(6), int64(4), object(14)
# memory usage: 60.1+ MB

# %% [markdown]
# #### Understanding the Dataset

# %%
## Number of unique business ID
test_sample['business_id'].nunique()
# Out:
# 85740

# %%
test_sample['user_id'].nunique()
# Out:
# 231585

# %%
test_sample['cool'].unique()
# Out:
# array([  1,   0,   3,   2,   5,  20,  13,   4,  15,   8,  14,   7,  10,
#          6, 125,  17,   9,  16,  37,  11,  47,  19,  36,  38,  23,  31,
#         46,  32,  12,  53,  22, 101,  18,  56,  25,  24,  49,  41,  28,
#         27,  30,  33, 169, 138,  50,  76, 118,  69,  62,  43,  21,  86,
#         35,  44, 147, 135,  26, 108,  34,  29,  65, 150, 172,  55,  63,
#         48, 136,  88,  54,  57, 183,  45,  51,  42,  58,  97,  39,  87,
#        370,  64, 184,  79,  83,  89, 146,  73, 159,  75,  59, 109, 145,
#         98, 126,  94,  52, 115, 105,  74, 205])

# %%
test_sample['average_business_stars'].unique()
# Out:
# array([4.5, 5. , 3.5, 4. , 2. , 3. , 2.5, 1.5, 1. , nan])

# %%
test_sample['tip_review'].isna().sum()
# Out:
# 307612

# %%
test_sample['categories'].isna().sum()
# Out:
# 32

# %%
test_sample['attributes'].unique()
# Out:
# array(['{\'BusinessAcceptsCreditCards\': \'True\', \'Alcohol\': "\'none\'", \'BusinessParking\': "{\'garage\': False, \'street\': False, \'validated\': False, \'lot\': False, \'valet\': False}", \'Caters\': \'True\', \'GoodForMeal\': "{\'dessert\': False, \'latenight\': False, \'lunch\': False, \'dinner\': False, \'brunch\': False, \'breakfast\': False}", \'BikeParking\': \'False\', \'RestaurantsDelivery\': \'False\', \'RestaurantsPriceRange2\': \'1\', \'RestaurantsTakeOut\': \'True\'}',
#        nan, "{'GoodForKids': 'True'}", ...,
#        '{\'RestaurantsDelivery\': \'True\', \'BusinessParking\': "{\'garage\': False, \'street\': False, \'validated\': False, \'lot\': True, \'valet\': False}", \'BikeParking\': \'True\', \'RestaurantsPriceRange2\': \'4\', \'Caters\': \'True\'}',
#        '{\'RestaurantsReservations\': \'True\', \'RestaurantsPriceRange2\': \'2\', \'RestaurantsTakeOut\': \'True\', \'RestaurantsGoodForGroups\': \'True\', \'OutdoorSeating\': \'True\', \'GoodForDancing\': \'False\', \'HasTV\': \'True\', \'BikeParking\': \'True\', \'Ambience\': "{\'touristy\': False, \'hipster\': False, \'romantic\': False, \'intimate\': False, \'trendy\': False, \'upscale\': False, \'classy\': False, \'casual\': False}", \'BusinessParking\': "{\'garage\': False, \'street\': False, \'validated\': False, \'lot\': True, \'valet\': False}", \'WiFi\': "\'free\'"}',
#        '{\'WiFi\': "u\'no\'", \'NoiseLevel\': "u\'very_loud\'", \'RestaurantsAttire\': "\'casual\'", \'Alcohol\': "u\'none\'", \'RestaurantsReservations\': \'False\', \'RestaurantsGoodForGroups\': \'True\', \'RestaurantsTakeOut\': \'True\', \'RestaurantsPriceRange2\': \'2\', \'GoodForKids\': \'True\', \'OutdoorSeating\': \'True\', \'RestaurantsDelivery\': \'True\', \'DriveThru\': \'True\', \'HasTV\': \'True\'}'],
#       dtype=object)

# %% [markdown]
# #### Cleaning and transforming

# %%
test_sample.drop(columns = ['address', 'tip_review'], axis = 1, inplace = True)

# %%
test_sample.set_index('Unnamed: 0', inplace=True)

# %%
nans = test_sample.isna().sum()
nans
# Out:
# business_id                  0
# user_id                      0
# text                         0
# cool                         0
# stars                        0
# date                         0
# funny                        0
# review_id                    0
# useful                       0
# average_user_stars           1
# yelping_since                1
# submitted_reviews            1
# name                         1
# city                         1
# state                        1
# latitude                    46
# longitude                    1
# average_business_stars       1
# recieved_reviews             1
# categories                  32
# attributes                8376
# dtype: int64

# %%
test_sample_dropped_na = test_sample.dropna()

# %%
test_sample_dropped_na
# Out:
#                        business_id                 user_id  \
# Unnamed: 0
# 5           Sh4zraoihis9bFldbjDR6w  N5fd36xJuEEHAHLHFirVCg
# 6           WsFZqQ8X78nOVb9Lz4vcKA  UvJugVw9PIABzdnK-bR1GQ
# 7           u5U6aoqDJz_TwKNS6t4dIw  R6M5aafvjMWxOaIzhAd44w
# 8           BzRGo0xHpUp1lxKFYdw1-A  Wa-DgCDkaB3O0xP3cJimFQ
# 9           uk8ZJQONDqdQJoLo07BjHA  a0REzCBCztw5pS0_BOTa6A
# ...                            ...                     ...
# 327975      YNAFgpoVfg1LQmxKpOh8jQ  z7THtOjTBf2hFgUU46MGlw
# 327976      kGY6SZKnu9g-yWCpEGZs6w  QNvibXA1_DAqpxxQgRLpyQ
# 327977      duYoXnIsUygOWz8SjLThzA  INkmTXqkvsIldZ8wMeHzqA
# 327978      zQ-CO0jHvJEsr3HRWHnobw  tSXM662aLwGS_RsVzeINAA
# 327979      zQ-CO0jHvJEsr3HRWHnobw  lAW03ccfMEuRZiDqvVgc0w
#
#                                                          text  cool  stars  \
# Unnamed: 0
# 5           I haven't been to Borden Park in a few years a...     3    5.0
# 6           I went to launch event for this years festival...     0    5.0
# 7           This mall is just sad. The only reasons I ever...     0    2.0
# 8           Ernest's is a really great place to enjoy a fi...     0    5.0
# 9           Unfortunately my experience has been good but ...     0    3.0
# ...                                                       ...   ...    ...
# 327975      Good selections of on tap craft brews, good se...     0    2.0
# 327976      I recently moved to the area from California a...     1    5.0
# 327977      What can I say...\n\nWe went to the St Albert ...     1    1.0
# 327978      Nello's is one of my all time favorites. I alw...     0    5.0
# 327979      I've come here twice now for dinner.\n\nThe re...     2    4.0
#
#                                  date  funny               review_id  useful  \
# Unnamed: 0
# 5           2015-06-22 13:52:58+00:00      1  8suVo8rQiU6hKR1hvkvGxg       3
# 6           2017-06-05 13:28:02+00:00      0  GDHRtRWwSmqK8x_tYLpDvQ       1
# 7           2014-04-02 23:30:50+00:00      0  kt_txOBGmemW1zHMe9NPDw       2
# 8           2018-04-28 04:14:32+00:00      0  oc6Pc0d2XDlUUjAXfQbVmg       0
# 9           2014-03-20 02:46:48+00:00      0  dfEIDw7q267fhvbZexB6Lg       0
# ...                               ...    ...                     ...     ...
# 327975      2018-04-23 19:41:56+00:00      0  vzRQ6fMxna6EJ_Q6Hkrs7A       0
# 327976      2015-03-11 08:43:57+00:00      1  E-12Xayd4_PrlBGNk_-kbQ       5
# 327977      2015-06-08 04:45:23+00:00      0  m2vkgIRl9dMIeibvF-G6MQ       0
# 327978      2019-06-10 01:51:46+00:00      0  u_pVvrejJC9a2vJ9rLca9g       0
# 327979      2017-03-02 21:50:46+00:00      1  Vw8p9ZhTiD5YZzjvXOBvUg       7
#
#             average_user_stars  ... submitted_reviews  \
# Unnamed: 0                      ...
# 5                         4.15  ...             177.0
# 6                         4.15  ...              71.0
# 7                         3.69  ...             262.0
# 8                         4.51  ...              91.0
# 9                         3.56  ...             139.0
# ...                        ...  ...               ...
# 327975                    4.05  ...              60.0
# 327976                    4.30  ...              15.0
# 327977                    2.00  ...               4.0
# 327978                    3.47  ...              47.0
# 327979                    4.03  ...            1578.0
#
#                                      name          city state latitude  \
# Unnamed: 0
# 5                             Borden Park      Edmonton    AB      T5B
# 6            Edmonton Craft Beer Festival      Edmonton    AB      T5B
# 7                        Northgate Centre      Edmonton    AB      T5E
# 8                    Ernest's Dining Room      Edmonton    AB      T5G
# 9                                 Teavana      Edmonton    AB      T5G
# ...                                   ...           ...   ...      ...
# 327975                       Beer Factory  Saint Albert    AB  T8N 4B1
# 327976      Sturgeon Valley Athletic Club    St. Albert    AB  T8N 5B2
# 327977          Dairy Queen Grill & Chill    St. Albert    AB  T8N 5N6
# 327978                 Nello's Restaurant     St Albert    AB  T8N 5Z1
# 327979                 Nello's Restaurant     St Albert    AB  T8N 5Z1
#
#              longitude  average_business_stars  recieved_reviews  \
# Unnamed: 0
# 5          -113.452413                     4.0              12.0
# 6          -113.456865                     4.5              21.0
# 7          -113.487943                     2.0              14.0
# 8          -113.502944                     4.5              13.0
# 9          -113.506020                     3.0               9.0
# ...                ...                     ...               ...
# 327975     -113.642913                     3.5              15.0
# 327976     -113.576604                     4.0               7.0
# 327977     -113.626233                     2.5              11.0
# 327978     -113.629268                     4.0              57.0
# 327979     -113.629268                     4.0              57.0
#
#                                                    categories  \
# Unnamed: 0
# 5                          Parks, Active Life, Swimming Pools
# 6               Arts & Entertainment, Festivals, Local Flavor
# 7                                  Shopping, Shopping Centers
# 8                                 Canadian (New), Restaurants
# 9                                             Tea Rooms, Food
# ...                                                       ...
# 327975      Bars, Restaurants, Food, Beer, Wine & Spirits,...
# 327976      Pilates, Health & Medical, Fitness & Instructi...
# 327977      Fast Food, Ice Cream & Frozen Yogurt, Restaura...
# 327978      Mediterranean, Restaurants, Gluten-Free, Itali...
# 327979      Mediterranean, Restaurants, Gluten-Free, Itali...
#
#                                                    attributes
# Unnamed: 0
# 5           {'GoodForKids': 'True', 'BikeParking': 'True',...
# 6                                    {'GoodForKids': 'False'}
# 7           {'BikeParking': 'True', 'BusinessParking': "{'...
# 8           {'HasTV': 'True', 'Ambience': "{'touristy': Fa...
# 9           {'RestaurantsPriceRange2': '2', 'WiFi': "u'no'...
# ...                                                       ...
# 327975      {'RestaurantsReservations': 'True', 'Restauran...
# 327976      {'GoodForKids': 'True', 'ByAppointmentOnly': '...
# 327977      {'WiFi': "u'no'", 'NoiseLevel': "u'very_loud'"...
# 327978      {'OutdoorSeating': 'False', 'BikeParking': 'Fa...
# 327979      {'OutdoorSeating': 'False', 'BikeParking': 'Fa...
#
# [319562 rows x 21 columns]

# %%
test_sample_dropped_na['category'] = test_sample_dropped_na['categories'].str.split(',').str[0]
# Out:
# /var/folders/zp/sq6bzsp91fz1sl3107mgk5gc0000gn/T/ipykernel_5987/2206027665.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_sample_dropped_na['category'] = test_sample_dropped_na['categories'].str.split(',').str[0]

# %%
test_sample_dropped_na
# Out:
#                        business_id                 user_id  \
# Unnamed: 0
# 0           4AxmAGObMPTDqbJK3EgNgQ  WDX_KkxwI8VYOF3RHpNLpA
# 2           ul0MGusQZBGo4CqiVh6VcA  vgiUst2zH7Zzs2FdISwQdQ
# 3           4vvu78FMlZyQwZf0bBUkLQ  ZzFwLI4AC9MyCBwY-kulEA
# 4           mRtGKvoxQLSh-tf2qBBoLg  6903ibtDSpwMDvD9Yp33wg
# 5           Sh4zraoihis9bFldbjDR6w  N5fd36xJuEEHAHLHFirVCg
# ...                            ...                     ...
# 327975      YNAFgpoVfg1LQmxKpOh8jQ  z7THtOjTBf2hFgUU46MGlw
# 327976      kGY6SZKnu9g-yWCpEGZs6w  QNvibXA1_DAqpxxQgRLpyQ
# 327977      duYoXnIsUygOWz8SjLThzA  INkmTXqkvsIldZ8wMeHzqA
# 327978      zQ-CO0jHvJEsr3HRWHnobw  tSXM662aLwGS_RsVzeINAA
# 327979      zQ-CO0jHvJEsr3HRWHnobw  lAW03ccfMEuRZiDqvVgc0w
#
#                                                          text  cool  stars  \
# Unnamed: 0
# 0           I discovered my new favorite food truck in the...     1    5.0
# 2           Super fun parade on the Sunday afternoon befor...     1    5.0
# 3           Horrible. I had read boisterous articles compa...     0    1.0
# 4           I ordered an Arnold Palmer over the sweltering...     0    2.0
# 5           I haven't been to Borden Park in a few years a...     3    5.0
# ...                                                       ...   ...    ...
# 327975      Good selections of on tap craft brews, good se...     0    2.0
# 327976      I recently moved to the area from California a...     1    5.0
# 327977      What can I say...\n\nWe went to the St Albert ...     1    1.0
# 327978      Nello's is one of my all time favorites. I alw...     0    5.0
# 327979      I've come here twice now for dinner.\n\nThe re...     2    4.0
#
#                                  date  funny               review_id  useful  \
# Unnamed: 0
# 0           2016-01-21 06:21:55+00:00      0  fVBt5kq8lyVSK2RcpY9XQA       2
# 2           2016-02-13 17:40:22+00:00      1  E5-7WlkTKnnC0XlsALwRfg       1
# 3           2019-05-26 18:45:25+00:00      1  JYGPNWLy8uxnxzjdNPWBQw       0
# 4           2013-09-05 23:17:55+00:00      0  EA0FGcHTsgBcGpa_e1g7GA       0
# 5           2015-06-22 13:52:58+00:00      1  8suVo8rQiU6hKR1hvkvGxg       3
# ...                               ...    ...                     ...     ...
# 327975      2018-04-23 19:41:56+00:00      0  vzRQ6fMxna6EJ_Q6Hkrs7A       0
# 327976      2015-03-11 08:43:57+00:00      1  E-12Xayd4_PrlBGNk_-kbQ       5
# 327977      2015-06-08 04:45:23+00:00      0  m2vkgIRl9dMIeibvF-G6MQ       0
# 327978      2019-06-10 01:51:46+00:00      0  u_pVvrejJC9a2vJ9rLca9g       0
# 327979      2017-03-02 21:50:46+00:00      1  Vw8p9ZhTiD5YZzjvXOBvUg       7
#
#             average_user_stars              yelping_since  submitted_reviews  \
# Unnamed: 0
# 0                         4.41  2011-04-19 03:15:49+00:00              374.0
# 2                         3.90  2013-02-12 18:10:40+00:00              270.0
# 3                         2.10  2018-05-07 20:37:46+00:00                9.0
# 4                         3.27  2008-07-10 04:59:17+00:00              215.0
# 5                         4.15  2014-08-02 19:03:27+00:00              177.0
# ...                        ...                        ...                ...
# 327975                    4.05  2011-01-27 19:27:07+00:00               60.0
# 327976                    4.30  2010-08-16 06:36:06+00:00               15.0
# 327977                    2.00  2015-04-29 23:20:59+00:00                4.0
# 327978                    3.47  2019-06-08 21:08:06+00:00               47.0
# 327979                    4.03  2011-06-03 03:06:54+00:00             1578.0
#
#                                      name          city state  \
# Unnamed: 0
# 0              Schnitzel's Austrian Grill          Reno    NV
# 2                          Krewe of Thoth   New Orleans    LA
# 3                         Indy 500 Parade  Indianapolis    IN
# 4                            Milk & Honey  Philadelphia    PA
# 5                             Borden Park      Edmonton    AB
# ...                                   ...           ...   ...
# 327975                       Beer Factory  Saint Albert    AB
# 327976      Sturgeon Valley Athletic Club    St. Albert    AB
# 327977          Dairy Queen Grill & Chill    St. Albert    AB
# 327978                 Nello's Restaurant     St Albert    AB
# 327979                 Nello's Restaurant     St Albert    AB
#
#             average_business_stars  recieved_reviews  \
# Unnamed: 0
# 0                              4.5              11.0
# 2                              4.5               9.0
# 3                              3.5              11.0
# 4                              3.5              34.0
# 5                              4.0              12.0
# ...                            ...               ...
# 327975                         3.5              15.0
# 327976                         4.0               7.0
# 327977                         2.5              11.0
# 327978                         4.0              57.0
# 327979                         4.0              57.0
#
#                                                    categories  \
# Unnamed: 0
# 0                      Food, German, Food Trucks, Restaurants
# 2                                                Local Flavor
# 3               Arts & Entertainment, Festivals, Local Flavor
# 4                                Food, Bakeries, Coffee & Tea
# 5                          Parks, Active Life, Swimming Pools
# ...                                                       ...
# 327975      Bars, Restaurants, Food, Beer, Wine & Spirits,...
# 327976      Pilates, Health & Medical, Fitness & Instructi...
# 327977      Fast Food, Ice Cream & Frozen Yogurt, Restaura...
# 327978      Mediterranean, Restaurants, Gluten-Free, Itali...
# 327979      Mediterranean, Restaurants, Gluten-Free, Itali...
#
#                                                    attributes  \
# Unnamed: 0
# 0           {'BusinessAcceptsCreditCards': 'True', 'Alcoho...
# 2                                     {'GoodForKids': 'True'}
# 3                                     {'GoodForKids': 'True'}
# 4           {'RestaurantsPriceRange2': '2', 'BusinessParki...
# 5           {'GoodForKids': 'True', 'BikeParking': 'True',...
# ...                                                       ...
# 327975      {'RestaurantsReservations': 'True', 'Restauran...
# 327976      {'GoodForKids': 'True', 'ByAppointmentOnly': '...
# 327977      {'WiFi': "u'no'", 'NoiseLevel': "u'very_loud'"...
# 327978      {'OutdoorSeating': 'False', 'BikeParking': 'Fa...
# 327979      {'OutdoorSeating': 'False', 'BikeParking': 'Fa...
#
#                         category
# Unnamed: 0
# 0                           Food
# 2                   Local Flavor
# 3           Arts & Entertainment
# 4                           Food
# 5                          Parks
# ...                          ...
# 327975                      Bars
# 327976                   Pilates
# 327977                 Fast Food
# 327978             Mediterranean
# 327979             Mediterranean
#
# [319603 rows x 20 columns]

# %%
test_sample_dropped_na['category'].nunique()
# Out:
# 1017

# %%
categories = test_sample_dropped_na['category'].value_counts()
categories
# Out:
# category
# Restaurants               56303
# Food                      16588
# Nightlife                 10863
# Bars                       9363
# American (Traditional)     8390
#                           ...
# CPR Classes                   1
# Fingerprinting                1
# Perfume                       1
# Lice Services                 1
# Hockey Equipment              1
# Name: count, Length: 1017, dtype: int64

# %%
for category in unique_categories:
    print(category)
# Out:
# Food
# Local Flavor
# Arts & Entertainment
# Parks
# Shopping
# Canadian (New)
# Tea Rooms
# Restaurants
# Vietnamese
# Italian
# Used
# Escape Games
# Beauty & Spas
# Hotels & Travel
# Active Life
# Flowers & Gifts
# Boating
# Department Stores
# Bars
# Shopping Centers
# Buffets
# Burgers
# Car Dealers
# Home Services
# Beer
# Chiropractors
# American (Traditional)
# Tobacco Shops
# Breakfast & Brunch
# Nail Salons
# American (New)
# Grocery
# Event Planning & Services
# Steakhouses
# Fast Food
# Nightlife
# Cosmetics & Beauty Supply
# Electronics
# Barbeque
# Auto Repair
# Donuts
# Home & Garden
# Wine Bars
# Automotive
# Sandwiches
# Health & Medical
# Community Service/Non-Profit
# Hair Salons
# Hospitals
# Asian Fusion
# Home Decor
# Coffee & Tea
# Desserts
# Cocktail Bars
# Szechuan
# Resorts
# Wholesale Stores
# Mattresses
# Waxing
# Gluten-Free
# Chinese
# Vitamins & Supplements
# Contractors
# Session Photography
# Local Services
# Japanese
# Used Car Dealers
# Pizza
# Cafes
# Massage
# Delis
# Fashion
# Thai
# Fitness & Instruction
# Flowers
# Korean
# Oil Change Stations
# Tires
# Indian
# Skin Care
# Bridal
# Cajun/Creole
# Hot Dogs
# Brazilian Jiu-jitsu
# Caribbean
# Comic Books
# Specialty Food
# Hobby Shops
# Sushi Bars
# Bangladeshi
# Mexican
# Soul Food
# Custom Cakes
# Video/Film Production
# Vape Shops
# Yoga
# Dog Parks
# Sports Bars
# Chicken Wings
# Outlet Stores
# Cheesesteaks
# Barbers
# Irish
# Seafood
# Hair Removal
# Junk Removal & Hauling
# Water Parks
# Pet Transportation
# Golf
# Mediterranean
# Southern
# Car Rental
# Home Cleaning
# Diners
# Bakeries
# Pubs
# Dance Clubs
# Breweries
# Pets
# Discount Store
# Vegan
# Jewelry
# Wineries
# Fish & Chips
# Gelato
# Venues & Event Spaces
# Convenience Stores
resturant_categories = ['Food','Local Flavor','Canadian (New)','Vietnamese','Italian','Buffets','Burgers','American (Traditional)','American (New)', 'Breakfast & Brunch','Sandwiches','Seafood','Mexican','Pizza', 'Cajun/Creole','Sushi Bars','Chinese','Japanese','Steakhouses','Cafes','Salad','Fast Food','Bakeries','Ice Cream & Frozen Yogurt','Desserts','Barbeque','Thai','Specialty Food','Asian Fusion','Southern','Diners','Mediterranean','Delis','Caterers','Chicken Wings','Vegetarian','Indian','Comfort Food','Latin American','French','Vegan','Greek','Gluten-Free','Tex-Mex','Korean','Soup','Donuts','Live/Raw Food','Tacos','Tapas/Small Plates','Gastropubs','Food Delivery Services','Pakistani','Tapas Bars','Cheesesteaks','Soul Food','Ethnic Food','Middle Eastern','German','Bagels','Food Trucks','Hot Dogs','Noodles','Creperies','Spanish','Caribbean','Chicken Shop','Ramen','Cuban','Irish','Basque','Halal','Dim Sum','New Mexican Cuisine','Poke','Seafood Markets','British','Gelato','Cupcakes','Ethiopian','Peruvian','Falafel','Custom Cakes','Pasta Shops','Kebab','Hot Pot','Puerto Rican','Dominican','Salvadoran','Cafeteria','Pancakes','Senegalese','Sri Lankan','Parent Cafes']
test_sample_dropped_na['main_category'] = test_sample_dropped_na['main_category'].apply(lambda x: 'Restaurants' if x in resturant_categories else x)
# Out:
# /var/folders/zp/sq6bzsp91fz1sl3107mgk5gc0000gn/T/ipykernel_5987/2953546023.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_sample_dropped_na['main_category'] = test_sample_dropped_na['category']
# /var/folders/zp/sq6bzsp91fz1sl3107mgk5gc0000gn/T/ipykernel_5987/2953546023.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_sample_dropped_na['main_category'] = test_sample_dropped_na['main_category'].apply(lambda x: 'Restaurants' if x in resturant_categories else x)

# %%
beauty = ['Nail Salons','Hair Salons','Hair Removal','Waxing','Day Spas','Skin Care','Massage','Barbers','Hair Stylists','Cosmetics & Beauty Supply','Eyelash Service','Massage Therapy','Makeup Artists','Tanning',"Men's Hair Salons",'Float Spa']
test_sample_dropped_na['main_category'] = test_sample_dropped_na['main_category'].apply(lambda x: 'Beauty & Spas' if x in beauty else x)
# Out:
# /var/folders/zp/sq6bzsp91fz1sl3107mgk5gc0000gn/T/ipykernel_5987/3533099631.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_sample_dropped_na['main_category'] = test_sample_dropped_na['main_category'].apply(lambda x: 'Beauty & Spas' if x in beauty else x)

# %%
bars = ['Cocktail Bars','Beer','Pubs','Sports Bars','Wine Bars','Breweries','Beer Bar','Dive Bars','Wine Tasting Classes','Meaderies']
test_sample_dropped_na['main_category'] = test_sample_dropped_na['main_category'].apply(lambda x: 'Bars' if x in bars else x)
# Out:
# /var/folders/zp/sq6bzsp91fz1sl3107mgk5gc0000gn/T/ipykernel_5987/2479137130.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_sample_dropped_na['main_category'] = test_sample_dropped_na['main_category'].apply(lambda x: 'Bars' if x in bars else x)

# %%
hotels = ['Hotels','Resorts']
test_sample_dropped_na['main_category'] = test_sample_dropped_na['main_category'].apply(lambda x: 'Hotels & Travel' if x in hotels else x)
# Out:
# /var/folders/zp/sq6bzsp91fz1sl3107mgk5gc0000gn/T/ipykernel_5987/882038581.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_sample_dropped_na['main_category'] = test_sample_dropped_na['main_category'].apply(lambda x: 'Hotels & Travel' if x in hotels else x)

# %%
auto = ['Auto Repair','Car Dealers','Oil Change Stations','Auto Parts & Supplies','Tires','Car Wash','Body Shops','Car Rental','Auto Detailing','Auto Loan Providers','Trailer Rental','Departments of Motor Vehicles','Motorcycle Rental','Mobile Dent Repair','Motorsport Vehicle Dealers','Bike tours']
test_sample_dropped_na['main_category'] = test_sample_dropped_na['main_category'].apply(lambda x: 'Automotive' if x in auto else x)
# Out:
# /var/folders/zp/sq6bzsp91fz1sl3107mgk5gc0000gn/T/ipykernel_5987/1553007118.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_sample_dropped_na['main_category'] = test_sample_dropped_na['main_category'].apply(lambda x: 'Automotive' if x in auto else x)

# %%
venues = ['Venues & Event Spaces','Party & Event Planning']
test_sample_dropped_na['main_category'] = test_sample_dropped_na['main_category'].apply(lambda x: 'Event Planning & Services' if x in venues else x)
# Out:
# /var/folders/zp/sq6bzsp91fz1sl3107mgk5gc0000gn/T/ipykernel_5987/739019121.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_sample_dropped_na['main_category'] = test_sample_dropped_na['main_category'].apply(lambda x: 'Event Planning & Services' if x in venues else x)

# %%
health = ['Fitness & Instruction','Gyms','Kickboxing','Aerial Fitness']
test_sample_dropped_na['main_category'] = test_sample_dropped_na['main_category'].apply(lambda x: 'Active Life' if x in health else x)
# Out:
# /var/folders/zp/sq6bzsp91fz1sl3107mgk5gc0000gn/T/ipykernel_5987/1231987046.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_sample_dropped_na['main_category'] = test_sample_dropped_na['main_category'].apply(lambda x: 'Active Life' if x in health else x)

# %%
entertainment = ['Cinema','Museums','Tours','Performing Arts','Arts & Crafts','Jazz & Blues','Landmarks & Historical Buildings','Golf','Art Galleries','Festivals','Stadiums & Arenas','Zoos','Hiking','Bike Rentals','Playgrounds','Professional Sports Teams','Recreation Centers','Art Tours','Country Clubs','Decks & Railing','Mountain Biking','Dinner Theater','Tabletop Games','Aerial Tours','Party Bike Rentals','Game Truck Rental','Psychic Mediums']
test_sample_dropped_na['main_category'] = test_sample_dropped_na['main_category'].apply(lambda x: 'Arts & Entertainment' if x in entertainment else x)
# Out:
# /var/folders/zp/sq6bzsp91fz1sl3107mgk5gc0000gn/T/ipykernel_5987/1837148663.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_sample_dropped_na['main_category'] = test_sample_dropped_na['main_category'].apply(lambda x: 'Arts & Entertainment' if x in entertainment else x)

# %%
medical = ['Doctors','Dentists','General Dentistry','Eyewear & Opticians','Medical Centers','Cosmetic Dentists','Chiropractors','Optometrists','Reflexology','Orthodontists','Periodontists','Medical Cannabis Referrals','Pain Management','Surgeons','Allergists','Anesthesiologists','Body Contouring','Dialysis Clinics','Reproductive Health Services','Memory Care','Preventive Medicine','Lice Services','Medical Transportation','Prosthodontists']
test_sample_dropped_na['main_category'] = test_sample_dropped_na['main_category'].apply(lambda x: 'Health & Medical' if x in medical else x)
# Out:
# /var/folders/zp/sq6bzsp91fz1sl3107mgk5gc0000gn/T/ipykernel_5987/2607808559.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_sample_dropped_na['main_category'] = test_sample_dropped_na['main_category'].apply(lambda x: 'Health & Medical' if x in medical else x)

# %%
nightlife = ['Dance Clubs']
test_sample_dropped_na['main_category'] = test_sample_dropped_na['main_category'].apply(lambda x: 'Nightlife' if x in nightlife else x)
# Out:
# /var/folders/zp/sq6bzsp91fz1sl3107mgk5gc0000gn/T/ipykernel_5987/3954106220.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_sample_dropped_na['main_category'] = test_sample_dropped_na['main_category'].apply(lambda x: 'Nightlife' if x in nightlife else x)

# %%
home_services = ['Movers','Apartments','Real Estate','Contractors','Heating & Air Conditioning/HVAC','Furniture Stores','Home Decor','Plumbing','Appliances & Repair','Mattresses','Sewing & Alterations','Home Cleaning','Appliances','Pest Control','Property Management','Landscaping','Kitchen & Bath','Real Estate Agents','Electricians','Carpeting','Packing Services','Commercial Real Estate','Decks & Railing','Chimney Sweeps','Countertop Installation','Home Network Installation','Roof Inspectors','Outdoor Power Equipment Services']
test_sample_dropped_na['main_category'] = test_sample_dropped_na['main_category'].apply(lambda x: 'Home Services' if x in home_services else x)
# Out:
# /var/folders/zp/sq6bzsp91fz1sl3107mgk5gc0000gn/T/ipykernel_5987/2517384766.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_sample_dropped_na['main_category'] = test_sample_dropped_na['main_category'].apply(lambda x: 'Home Services' if x in home_services else x)

# %%
shopping = ['Department Stores','Jewelry','Fashion','Sporting Goods',"Women's Clothing",'Drugstores','Convenience Stores','Accessories','Trainers','Health Markets','Shopping Centers','Shoe Stores','Thrift Stores',"Men's Clothing",'Piercing','Tobacco Shops','Hobby Shops','Shoe Repair','Screen Printing/T-Shirt Printing','Rugs','Hunting & Fishing Supplies','Wigs','Sunglasses','Hockey Equipment','Storefront Clinics','Snorkeling','Perfume','Local Fish Stores']
test_sample_dropped_na['main_category'] = test_sample_dropped_na['main_category'].apply(lambda x: 'Shopping' if x in shopping else x)
# Out:
# /var/folders/zp/sq6bzsp91fz1sl3107mgk5gc0000gn/T/ipykernel_5987/570973357.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_sample_dropped_na['main_category'] = test_sample_dropped_na['main_category'].apply(lambda x: 'Shopping' if x in shopping else x)

# %%
coffee_tea = ['Bubble Tea','Coffee Roasteries','Tea Rooms']
test_sample_dropped_na['main_category'] = test_sample_dropped_na['main_category'].apply(lambda x: 'Coffee & Tea' if x in coffee_tea else x)
# Out:
# /var/folders/zp/sq6bzsp91fz1sl3107mgk5gc0000gn/T/ipykernel_5987/3878969130.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_sample_dropped_na['main_category'] = test_sample_dropped_na['main_category'].apply(lambda x: 'Coffee & Tea' if x in coffee_tea else x)

# %%
pets = ['Pet Services','Veterinarians','Pet Stores','Pet Hospice']
test_sample_dropped_na['main_category'] = test_sample_dropped_na['main_category'].apply(lambda x: 'Pets' if x in pets else x)
# Out:
# /var/folders/zp/sq6bzsp91fz1sl3107mgk5gc0000gn/T/ipykernel_5987/2670156015.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_sample_dropped_na['main_category'] = test_sample_dropped_na['main_category'].apply(lambda x: 'Pets' if x in pets else x)

# %%
florist = ['Florists','Gift Shops']
test_sample_dropped_na['main_category'] = test_sample_dropped_na['main_category'].apply(lambda x: 'Flowers & Gifts' if x in florist else x)
# Out:
# /var/folders/zp/sq6bzsp91fz1sl3107mgk5gc0000gn/T/ipykernel_5987/890427474.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_sample_dropped_na['main_category'] = test_sample_dropped_na['main_category'].apply(lambda x: 'Flowers & Gifts' if x in florist else x)

# %%
groceries = ['Fruits & Veggies','Wholesale Stores','Wholesalers']
test_sample_dropped_na['main_category'] = test_sample_dropped_na['main_category'].apply(lambda x: 'Grocery' if x in groceries else x)
# Out:
# /var/folders/zp/sq6bzsp91fz1sl3107mgk5gc0000gn/T/ipykernel_5987/3784850926.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_sample_dropped_na['main_category'] = test_sample_dropped_na['main_category'].apply(lambda x: 'Grocery' if x in groceries else x)

# %%
test_sample_dropped_na
# Out:
#                        business_id                 user_id  \
# Unnamed: 0
# 0           4AxmAGObMPTDqbJK3EgNgQ  WDX_KkxwI8VYOF3RHpNLpA
# 2           ul0MGusQZBGo4CqiVh6VcA  vgiUst2zH7Zzs2FdISwQdQ
# 3           4vvu78FMlZyQwZf0bBUkLQ  ZzFwLI4AC9MyCBwY-kulEA
# 4           mRtGKvoxQLSh-tf2qBBoLg  6903ibtDSpwMDvD9Yp33wg
# 5           Sh4zraoihis9bFldbjDR6w  N5fd36xJuEEHAHLHFirVCg
# ...                            ...                     ...
# 327975      YNAFgpoVfg1LQmxKpOh8jQ  z7THtOjTBf2hFgUU46MGlw
# 327976      kGY6SZKnu9g-yWCpEGZs6w  QNvibXA1_DAqpxxQgRLpyQ
# 327977      duYoXnIsUygOWz8SjLThzA  INkmTXqkvsIldZ8wMeHzqA
# 327978      zQ-CO0jHvJEsr3HRWHnobw  tSXM662aLwGS_RsVzeINAA
# 327979      zQ-CO0jHvJEsr3HRWHnobw  lAW03ccfMEuRZiDqvVgc0w
#
#                                                          text  cool  stars  \
# Unnamed: 0
# 0           I discovered my new favorite food truck in the...     1    5.0
# 2           Super fun parade on the Sunday afternoon befor...     1    5.0
# 3           Horrible. I had read boisterous articles compa...     0    1.0
# 4           I ordered an Arnold Palmer over the sweltering...     0    2.0
# 5           I haven't been to Borden Park in a few years a...     3    5.0
# ...                                                       ...   ...    ...
# 327975      Good selections of on tap craft brews, good se...     0    2.0
# 327976      I recently moved to the area from California a...     1    5.0
# 327977      What can I say...\n\nWe went to the St Albert ...     1    1.0
# 327978      Nello's is one of my all time favorites. I alw...     0    5.0
# 327979      I've come here twice now for dinner.\n\nThe re...     2    4.0
#
#                                  date  funny               review_id  useful  \
# Unnamed: 0
# 0           2016-01-21 06:21:55+00:00      0  fVBt5kq8lyVSK2RcpY9XQA       2
# 2           2016-02-13 17:40:22+00:00      1  E5-7WlkTKnnC0XlsALwRfg       1
# 3           2019-05-26 18:45:25+00:00      1  JYGPNWLy8uxnxzjdNPWBQw       0
# 4           2013-09-05 23:17:55+00:00      0  EA0FGcHTsgBcGpa_e1g7GA       0
# 5           2015-06-22 13:52:58+00:00      1  8suVo8rQiU6hKR1hvkvGxg       3
# ...                               ...    ...                     ...     ...
# 327975      2018-04-23 19:41:56+00:00      0  vzRQ6fMxna6EJ_Q6Hkrs7A       0
# 327976      2015-03-11 08:43:57+00:00      1  E-12Xayd4_PrlBGNk_-kbQ       5
# 327977      2015-06-08 04:45:23+00:00      0  m2vkgIRl9dMIeibvF-G6MQ       0
# 327978      2019-06-10 01:51:46+00:00      0  u_pVvrejJC9a2vJ9rLca9g       0
# 327979      2017-03-02 21:50:46+00:00      1  Vw8p9ZhTiD5YZzjvXOBvUg       7
#
#             average_user_stars  ... submitted_reviews  \
# Unnamed: 0                      ...
# 0                         4.41  ...             374.0
# 2                         3.90  ...             270.0
# 3                         2.10  ...               9.0
# 4                         3.27  ...             215.0
# 5                         4.15  ...             177.0
# ...                        ...  ...               ...
# 327975                    4.05  ...              60.0
# 327976                    4.30  ...              15.0
# 327977                    2.00  ...               4.0
# 327978                    3.47  ...              47.0
# 327979                    4.03  ...            1578.0
#
#                                      name          city state  \
# Unnamed: 0
# 0              Schnitzel's Austrian Grill          Reno    NV
# 2                          Krewe of Thoth   New Orleans    LA
# 3                         Indy 500 Parade  Indianapolis    IN
# 4                            Milk & Honey  Philadelphia    PA
# 5                             Borden Park      Edmonton    AB
# ...                                   ...           ...   ...
# 327975                       Beer Factory  Saint Albert    AB
# 327976      Sturgeon Valley Athletic Club    St. Albert    AB
# 327977          Dairy Queen Grill & Chill    St. Albert    AB
# 327978                 Nello's Restaurant     St Albert    AB
# 327979                 Nello's Restaurant     St Albert    AB
#
#            average_business_stars  recieved_reviews  \
# Unnamed: 0
# 0                             4.5              11.0
# 2                             4.5               9.0
# 3                             3.5              11.0
# 4                             3.5              34.0
# 5                             4.0              12.0
# ...                           ...               ...
# 327975                        3.5              15.0
# 327976                        4.0               7.0
# 327977                        2.5              11.0
# 327978                        4.0              57.0
# 327979                        4.0              57.0
#
#                                                    categories  \
# Unnamed: 0
# 0                      Food, German, Food Trucks, Restaurants
# 2                                                Local Flavor
# 3               Arts & Entertainment, Festivals, Local Flavor
# 4                                Food, Bakeries, Coffee & Tea
# 5                          Parks, Active Life, Swimming Pools
# ...                                                       ...
# 327975      Bars, Restaurants, Food, Beer, Wine & Spirits,...
# 327976      Pilates, Health & Medical, Fitness & Instructi...
# 327977      Fast Food, Ice Cream & Frozen Yogurt, Restaura...
# 327978      Mediterranean, Restaurants, Gluten-Free, Itali...
# 327979      Mediterranean, Restaurants, Gluten-Free, Itali...
#
#                                                    attributes  \
# Unnamed: 0
# 0           {'BusinessAcceptsCreditCards': 'True', 'Alcoho...
# 2                                     {'GoodForKids': 'True'}
# 3                                     {'GoodForKids': 'True'}
# 4           {'RestaurantsPriceRange2': '2', 'BusinessParki...
# 5           {'GoodForKids': 'True', 'BikeParking': 'True',...
# ...                                                       ...
# 327975      {'RestaurantsReservations': 'True', 'Restauran...
# 327976      {'GoodForKids': 'True', 'ByAppointmentOnly': '...
# 327977      {'WiFi': "u'no'", 'NoiseLevel': "u'very_loud'"...
# 327978      {'OutdoorSeating': 'False', 'BikeParking': 'Fa...
# 327979      {'OutdoorSeating': 'False', 'BikeParking': 'Fa...
#
#                         category         main_category
# Unnamed: 0
# 0                           Food           Restaurants
# 2                   Local Flavor           Restaurants
# 3           Arts & Entertainment  Arts & Entertainment
# 4                           Food           Restaurants
# 5                          Parks                 Parks
# ...                          ...                   ...
# 327975                      Bars                  Bars
# 327976                   Pilates               Pilates
# 327977                 Fast Food           Restaurants
# 327978             Mediterranean           Restaurants
# 327979             Mediterranean           Restaurants
#
# [319603 rows x 21 columns]

# %%
category_counts = test_sample_dropped_na['main_category'].value_counts().head(10)
category_counts
# Out:
# main_category
# Restaurants                  191674
# Bars                          18456
# Beauty & Spas                 13690
# Nightlife                     11109
# Shopping                       9103
# Automotive                     7855
# Home Services                  6635
# Event Planning & Services      6091
# Arts & Entertainment           5984
# Hotels & Travel                5096
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 8))
category_counts.sort_values(ascending = False).plot(kind='bar')
plt.title('Top 10 Location Categories')
plt.xlabel('Number of Locations')
plt.ylabel('Category')
plt.show()

# %%
test_sample_dropped_na.head()
# Out:
#                        business_id                 user_id  \
# Unnamed: 0
# 0           4AxmAGObMPTDqbJK3EgNgQ  WDX_KkxwI8VYOF3RHpNLpA
# 2           ul0MGusQZBGo4CqiVh6VcA  vgiUst2zH7Zzs2FdISwQdQ
# 3           4vvu78FMlZyQwZf0bBUkLQ  ZzFwLI4AC9MyCBwY-kulEA
# 4           mRtGKvoxQLSh-tf2qBBoLg  6903ibtDSpwMDvD9Yp33wg
# 5           Sh4zraoihis9bFldbjDR6w  N5fd36xJuEEHAHLHFirVCg
#
#                                                          text  cool  stars  \
# Unnamed: 0
# 0           I discovered my new favorite food truck in the...     1    5.0
# 2           Super fun parade on the Sunday afternoon befor...     1    5.0
# 3           Horrible. I had read boisterous articles compa...     0    1.0
# 4           I ordered an Arnold Palmer over the sweltering...     0    2.0
# 5           I haven't been to Borden Park in a few years a...     3    5.0
#
#                                  date  funny               review_id  useful  \
# Unnamed: 0
# 0           2016-01-21 06:21:55+00:00      0  fVBt5kq8lyVSK2RcpY9XQA       2
# 2           2016-02-13 17:40:22+00:00      1  E5-7WlkTKnnC0XlsALwRfg       1
# 3           2019-05-26 18:45:25+00:00      1  JYGPNWLy8uxnxzjdNPWBQw       0
# 4           2013-09-05 23:17:55+00:00      0  EA0FGcHTsgBcGpa_e1g7GA       0
# 5           2015-06-22 13:52:58+00:00      1  8suVo8rQiU6hKR1hvkvGxg       3
#
#             average_user_stars  ... submitted_reviews  \
# Unnamed: 0                      ...
# 0                         4.41  ...             374.0
# 2                         3.90  ...             270.0
# 3                         2.10  ...               9.0
# 4                         3.27  ...             215.0
# 5                         4.15  ...             177.0
#
#                                   name          city state  \
# Unnamed: 0
# 0           Schnitzel's Austrian Grill          Reno    NV
# 2                       Krewe of Thoth   New Orleans    LA
# 3                      Indy 500 Parade  Indianapolis    IN
# 4                         Milk & Honey  Philadelphia    PA
# 5                          Borden Park      Edmonton    AB
#
#            average_business_stars  recieved_reviews  \
# Unnamed: 0
# 0                             4.5              11.0
# 2                             4.5               9.0
# 3                             3.5              11.0
# 4                             3.5              34.0
# 5                             4.0              12.0
#
#                                                categories  \
# Unnamed: 0
# 0                  Food, German, Food Trucks, Restaurants
# 2                                            Local Flavor
# 3           Arts & Entertainment, Festivals, Local Flavor
# 4                            Food, Bakeries, Coffee & Tea
# 5                      Parks, Active Life, Swimming Pools
#
#                                                    attributes  \
# Unnamed: 0
# 0           {'BusinessAcceptsCreditCards': 'True', 'Alcoho...
# 2                                     {'GoodForKids': 'True'}
# 3                                     {'GoodForKids': 'True'}
# 4           {'RestaurantsPriceRange2': '2', 'BusinessParki...
# 5           {'GoodForKids': 'True', 'BikeParking': 'True',...
#
#                         category         main_category
# Unnamed: 0
# 0                           Food           Restaurants
# 2                   Local Flavor           Restaurants
# 3           Arts & Entertainment  Arts & Entertainment
# 4                           Food           Restaurants
# 5                          Parks                 Parks
#
# [5 rows x 21 columns]

# %%
test_sample_dropped_na.drop(columns = ['categories'], inplace = True)
# Out:
# /var/folders/zp/sq6bzsp91fz1sl3107mgk5gc0000gn/T/ipykernel_5987/1791991364.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_sample_dropped_na.drop(columns = ['categories'], inplace = True)

# %%
test_sample_dropped_na
# Out:
#                        business_id                 user_id  \
# Unnamed: 0
# 0           4AxmAGObMPTDqbJK3EgNgQ  WDX_KkxwI8VYOF3RHpNLpA
# 2           ul0MGusQZBGo4CqiVh6VcA  vgiUst2zH7Zzs2FdISwQdQ
# 3           4vvu78FMlZyQwZf0bBUkLQ  ZzFwLI4AC9MyCBwY-kulEA
# 4           mRtGKvoxQLSh-tf2qBBoLg  6903ibtDSpwMDvD9Yp33wg
# 5           Sh4zraoihis9bFldbjDR6w  N5fd36xJuEEHAHLHFirVCg
# ...                            ...                     ...
# 327975      YNAFgpoVfg1LQmxKpOh8jQ  z7THtOjTBf2hFgUU46MGlw
# 327976      kGY6SZKnu9g-yWCpEGZs6w  QNvibXA1_DAqpxxQgRLpyQ
# 327977      duYoXnIsUygOWz8SjLThzA  INkmTXqkvsIldZ8wMeHzqA
# 327978      zQ-CO0jHvJEsr3HRWHnobw  tSXM662aLwGS_RsVzeINAA
# 327979      zQ-CO0jHvJEsr3HRWHnobw  lAW03ccfMEuRZiDqvVgc0w
#
#                                                          text  cool  stars  \
# Unnamed: 0
# 0           I discovered my new favorite food truck in the...     1    5.0
# 2           Super fun parade on the Sunday afternoon befor...     1    5.0
# 3           Horrible. I had read boisterous articles compa...     0    1.0
# 4           I ordered an Arnold Palmer over the sweltering...     0    2.0
# 5           I haven't been to Borden Park in a few years a...     3    5.0
# ...                                                       ...   ...    ...
# 327975      Good selections of on tap craft brews, good se...     0    2.0
# 327976      I recently moved to the area from California a...     1    5.0
# 327977      What can I say...\n\nWe went to the St Albert ...     1    1.0
# 327978      Nello's is one of my all time favorites. I alw...     0    5.0
# 327979      I've come here twice now for dinner.\n\nThe re...     2    4.0
#
#                                  date  funny               review_id  useful  \
# Unnamed: 0
# 0           2016-01-21 06:21:55+00:00      0  fVBt5kq8lyVSK2RcpY9XQA       2
# 2           2016-02-13 17:40:22+00:00      1  E5-7WlkTKnnC0XlsALwRfg       1
# 3           2019-05-26 18:45:25+00:00      1  JYGPNWLy8uxnxzjdNPWBQw       0
# 4           2013-09-05 23:17:55+00:00      0  EA0FGcHTsgBcGpa_e1g7GA       0
# 5           2015-06-22 13:52:58+00:00      1  8suVo8rQiU6hKR1hvkvGxg       3
# ...                               ...    ...                     ...     ...
# 327975      2018-04-23 19:41:56+00:00      0  vzRQ6fMxna6EJ_Q6Hkrs7A       0
# 327976      2015-03-11 08:43:57+00:00      1  E-12Xayd4_PrlBGNk_-kbQ       5
# 327977      2015-06-08 04:45:23+00:00      0  m2vkgIRl9dMIeibvF-G6MQ       0
# 327978      2019-06-10 01:51:46+00:00      0  u_pVvrejJC9a2vJ9rLca9g       0
# 327979      2017-03-02 21:50:46+00:00      1  Vw8p9ZhTiD5YZzjvXOBvUg       7
#
#             average_user_stars              yelping_since  submitted_reviews  \
# Unnamed: 0
# 0                         4.41  2011-04-19 03:15:49+00:00              374.0
# 2                         3.90  2013-02-12 18:10:40+00:00              270.0
# 3                         2.10  2018-05-07 20:37:46+00:00                9.0
# 4                         3.27  2008-07-10 04:59:17+00:00              215.0
# 5                         4.15  2014-08-02 19:03:27+00:00              177.0
# ...                        ...                        ...                ...
# 327975                    4.05  2011-01-27 19:27:07+00:00               60.0
# 327976                    4.30  2010-08-16 06:36:06+00:00               15.0
# 327977                    2.00  2015-04-29 23:20:59+00:00                4.0
# 327978                    3.47  2019-06-08 21:08:06+00:00               47.0
# 327979                    4.03  2011-06-03 03:06:54+00:00             1578.0
#
#                                      name          city state  \
# Unnamed: 0
# 0              Schnitzel's Austrian Grill          Reno    NV
# 2                          Krewe of Thoth   New Orleans    LA
# 3                         Indy 500 Parade  Indianapolis    IN
# 4                            Milk & Honey  Philadelphia    PA
# 5                             Borden Park      Edmonton    AB
# ...                                   ...           ...   ...
# 327975                       Beer Factory  Saint Albert    AB
# 327976      Sturgeon Valley Athletic Club    St. Albert    AB
# 327977          Dairy Queen Grill & Chill    St. Albert    AB
# 327978                 Nello's Restaurant     St Albert    AB
# 327979                 Nello's Restaurant     St Albert    AB
#
#             average_business_stars  recieved_reviews  \
# Unnamed: 0
# 0                              4.5              11.0
# 2                              4.5               9.0
# 3                              3.5              11.0
# 4                              3.5              34.0
# 5                              4.0              12.0
# ...                            ...               ...
# 327975                         3.5              15.0
# 327976                         4.0               7.0
# 327977                         2.5              11.0
# 327978                         4.0              57.0
# 327979                         4.0              57.0
#
#                                                    attributes  \
# Unnamed: 0
# 0           {'BusinessAcceptsCreditCards': 'True', 'Alcoho...
# 2                                     {'GoodForKids': 'True'}
# 3                                     {'GoodForKids': 'True'}
# 4           {'RestaurantsPriceRange2': '2', 'BusinessParki...
# 5           {'GoodForKids': 'True', 'BikeParking': 'True',...
# ...                                                       ...
# 327975      {'RestaurantsReservations': 'True', 'Restauran...
# 327976      {'GoodForKids': 'True', 'ByAppointmentOnly': '...
# 327977      {'WiFi': "u'no'", 'NoiseLevel': "u'very_loud'"...
# 327978      {'OutdoorSeating': 'False', 'BikeParking': 'Fa...
# 327979      {'OutdoorSeating': 'False', 'BikeParking': 'Fa...
#
#                         category         main_category
# Unnamed: 0
# 0                           Food           Restaurants
# 2                   Local Flavor           Restaurants
# 3           Arts & Entertainment  Arts & Entertainment
# 4                           Food           Restaurants
# 5                          Parks                 Parks
# ...                          ...                   ...
# 327975                      Bars                  Bars
# 327976                   Pilates               Pilates
# 327977                 Fast Food           Restaurants
# 327978             Mediterranean           Restaurants
# 327979             Mediterranean           Restaurants
#
# [319603 rows x 20 columns]

# %%
state_location_counts = test_sample_dropped_na['state'].value_counts().head(10)
plt.figure(figsize=(10, 8))
state_location_counts.sort_values(ascending = False).plot(kind='bar', color = 'Orange')
plt.title('Top 10 State Locations')
plt.xlabel('Number of Locations')
plt.ylabel('Category')
plt.show()
