# %%
import pandas as pd

test_sample = pd.read_csv('under-sample.csv')
# Out:
# /var/folders/zp/sq6bzsp91fz1sl3107mgk5gc0000gn/T/ipykernel_15847/2574737977.py:3: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   test_sample = pd.read_csv('under-sample.csv')

# %%
test_sample.head()
# Out:
#    Unnamed: 0             business_id                 user_id  \
# 0           0  4AxmAGObMPTDqbJK3EgNgQ  WDX_KkxwI8VYOF3RHpNLpA
# 1           1  II7CpZjGyx8aFTu3wJbQNw  pgh8UtO2K13GVMv4Ih-jEw
# 2           2  ul0MGusQZBGo4CqiVh6VcA  vgiUst2zH7Zzs2FdISwQdQ
# 3           3  4vvu78FMlZyQwZf0bBUkLQ  ZzFwLI4AC9MyCBwY-kulEA
# 4           4  mRtGKvoxQLSh-tf2qBBoLg  6903ibtDSpwMDvD9Yp33wg
#
#                                                 text  cool  stars  \
# 0  I discovered my new favorite food truck in the...     1    5.0
# 1  Sean Byrd was our guide on the City Tour. He w...     0    5.0
# 2  Super fun parade on the Sunday afternoon befor...     1    5.0
# 3  Horrible. I had read boisterous articles compa...     0    1.0
# 4  I ordered an Arnold Palmer over the sweltering...     0    2.0
#
#                         date  funny               review_id  useful  ...  \
# 0  2016-01-21 06:21:55+00:00      0  fVBt5kq8lyVSK2RcpY9XQA       2  ...
# 1  2021-01-24 21:04:52+00:00      0  3Sjk89h1OLVdEm9fqoggnQ       1  ...
# 2  2016-02-13 17:40:22+00:00      1  E5-7WlkTKnnC0XlsALwRfg       1  ...
# 3  2019-05-26 18:45:25+00:00      1  JYGPNWLy8uxnxzjdNPWBQw       0  ...
# 4  2013-09-05 23:17:55+00:00      0  EA0FGcHTsgBcGpa_e1g7GA       0  ...
#
#               address          city  state latitude   longitude  \
# 0                 NaN          Reno     NV      NaN -119.813803
# 1                 NaN   New Orleans     LA      NaN  -90.077750
# 2       St Charles Ae   New Orleans     LA      NaN  -90.080723
# 3     Pennsylvania St  Indianapolis     IN      NaN  -86.155944
# 4  18th St & Logan Sq  Philadelphia     PA      NaN  -75.168697
#
#   average_business_stars recieved_reviews  \
# 0                    4.5             11.0
# 1                    5.0              6.0
# 2                    4.5              9.0
# 3                    3.5             11.0
# 4                    3.5             34.0
#
#                                       categories  \
# 0         Food, German, Food Trucks, Restaurants
# 1              Hotels & Travel, Bus Tours, Tours
# 2                                   Local Flavor
# 3  Arts & Entertainment, Festivals, Local Flavor
# 4                   Food, Bakeries, Coffee & Tea
#
#                                           attributes  tip_review
# 0  {'BusinessAcceptsCreditCards': 'True', 'Alcoho...         NaN
# 1                                                NaN         NaN
# 2                            {'GoodForKids': 'True'}         NaN
# 3                            {'GoodForKids': 'True'}         NaN
# 4  {'RestaurantsPriceRange2': '2', 'BusinessParki...         NaN
#
# [5 rows x 24 columns]

# %%
test_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 327980 entries, 0 to 327979
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Unnamed: 0              327980 non-null  int64
#  1   business_id             327980 non-null  object
#  2   user_id                 327980 non-null  object
#  3   text                    327980 non-null  object
#  4   cool                    327980 non-null  int64
#  5   stars                   327980 non-null  float64
#  6   date                    327980 non-null  object
#  7   funny                   327980 non-null  int64
#  8   review_id               327980 non-null  object
#  9   useful                  327980 non-null  int64
#  10  average_user_stars      327979 non-null  float64
#  11  yelping_since           327979 non-null  object
#  12  submitted_reviews       327979 non-null  float64
#  13  name                    327979 non-null  object
#  14  address                 324081 non-null  object
#  15  city                    327979 non-null  object
#  16  state                   327979 non-null  object
#  17  latitude                327934 non-null  object
#  18  longitude               327979 non-null  float64
#  19  average_business_stars  327979 non-null  float64
#  20  recieved_reviews        327979 non-null  float64
#  21  categories              327948 non-null  object
#  22  attributes              319604 non-null  object
#  23  tip_review              20368 non-null   object
# dtypes: float64(6), int64(4), object(14)
# memory usage: 60.1+ MB

# %% [markdown]
# #### Understanding the Dataset

# %%
## Number of unique business ID
test_sample['business_id'].nunique()
# Out:
# 85740

# %%
test_sample['user_id'].nunique()
# Out:
# 231585

# %%
test_sample['cool'].unique()
# Out:
# array([  1,   0,   3,   2,   5,  20,  13,   4,  15,   8,  14,   7,  10,
#          6, 125,  17,   9,  16,  37,  11,  47,  19,  36,  38,  23,  31,
#         46,  32,  12,  53,  22, 101,  18,  56,  25,  24,  49,  41,  28,
#         27,  30,  33, 169, 138,  50,  76, 118,  69,  62,  43,  21,  86,
#         35,  44, 147, 135,  26, 108,  34,  29,  65, 150, 172,  55,  63,
#         48, 136,  88,  54,  57, 183,  45,  51,  42,  58,  97,  39,  87,
#        370,  64, 184,  79,  83,  89, 146,  73, 159,  75,  59, 109, 145,
#         98, 126,  94,  52, 115, 105,  74, 205])

# %%
test_sample['average_business_stars'].unique()
# Out:
# array([4.5, 5. , 3.5, 4. , 2. , 3. , 2.5, 1.5, 1. , nan])

# %%
test_sample['tip_review'].isna().sum()
# Out:
# 307612

# %%
test_sample['categories'].isna().sum()
# Out:
# 32

# %%
test_sample['attributes'].unique()
# Out:
# array(['{\'BusinessAcceptsCreditCards\': \'True\', \'Alcohol\': "\'none\'", \'BusinessParking\': "{\'garage\': False, \'street\': False, \'validated\': False, \'lot\': False, \'valet\': False}", \'Caters\': \'True\', \'GoodForMeal\': "{\'dessert\': False, \'latenight\': False, \'lunch\': False, \'dinner\': False, \'brunch\': False, \'breakfast\': False}", \'BikeParking\': \'False\', \'RestaurantsDelivery\': \'False\', \'RestaurantsPriceRange2\': \'1\', \'RestaurantsTakeOut\': \'True\'}',
#        nan, "{'GoodForKids': 'True'}", ...,
#        '{\'RestaurantsDelivery\': \'True\', \'BusinessParking\': "{\'garage\': False, \'street\': False, \'validated\': False, \'lot\': True, \'valet\': False}", \'BikeParking\': \'True\', \'RestaurantsPriceRange2\': \'4\', \'Caters\': \'True\'}',
#        '{\'RestaurantsReservations\': \'True\', \'RestaurantsPriceRange2\': \'2\', \'RestaurantsTakeOut\': \'True\', \'RestaurantsGoodForGroups\': \'True\', \'OutdoorSeating\': \'True\', \'GoodForDancing\': \'False\', \'HasTV\': \'True\', \'BikeParking\': \'True\', \'Ambience\': "{\'touristy\': False, \'hipster\': False, \'romantic\': False, \'intimate\': False, \'trendy\': False, \'upscale\': False, \'classy\': False, \'casual\': False}", \'BusinessParking\': "{\'garage\': False, \'street\': False, \'validated\': False, \'lot\': True, \'valet\': False}", \'WiFi\': "\'free\'"}',
#        '{\'WiFi\': "u\'no\'", \'NoiseLevel\': "u\'very_loud\'", \'RestaurantsAttire\': "\'casual\'", \'Alcohol\': "u\'none\'", \'RestaurantsReservations\': \'False\', \'RestaurantsGoodForGroups\': \'True\', \'RestaurantsTakeOut\': \'True\', \'RestaurantsPriceRange2\': \'2\', \'GoodForKids\': \'True\', \'OutdoorSeating\': \'True\', \'RestaurantsDelivery\': \'True\', \'DriveThru\': \'True\', \'HasTV\': \'True\'}'],
#       dtype=object)

# %% [markdown]
# #### Cleaning and transforming

# %%
test_sample.drop(columns = ['address', 'tip_review'], axis = 1, inplace = True)

# %%
test_sample.set_index('Unnamed: 0', inplace=True)

# %%
nans = test_sample.isna().sum()
nans
# Out:
# business_id                  0
# user_id                      0
# text                         0
# cool                         0
# stars                        0
# date                         0
# funny                        0
# review_id                    0
# useful                       0
# average_user_stars           1
# yelping_since                1
# submitted_reviews            1
# name                         1
# city                         1
# state                        1
# latitude                    46
# longitude                    1
# average_business_stars       1
# recieved_reviews             1
# categories                  32
# attributes                8376
# dtype: int64

# %%
test_sample_dropped_na = test_sample.dropna()

# %%
test_sample_dropped_na
# Out:
#                        business_id                 user_id  \
# Unnamed: 0
# 5           Sh4zraoihis9bFldbjDR6w  N5fd36xJuEEHAHLHFirVCg
# 6           WsFZqQ8X78nOVb9Lz4vcKA  UvJugVw9PIABzdnK-bR1GQ
# 7           u5U6aoqDJz_TwKNS6t4dIw  R6M5aafvjMWxOaIzhAd44w
# 8           BzRGo0xHpUp1lxKFYdw1-A  Wa-DgCDkaB3O0xP3cJimFQ
# 9           uk8ZJQONDqdQJoLo07BjHA  a0REzCBCztw5pS0_BOTa6A
# ...                            ...                     ...
# 327975      YNAFgpoVfg1LQmxKpOh8jQ  z7THtOjTBf2hFgUU46MGlw
# 327976      kGY6SZKnu9g-yWCpEGZs6w  QNvibXA1_DAqpxxQgRLpyQ
# 327977      duYoXnIsUygOWz8SjLThzA  INkmTXqkvsIldZ8wMeHzqA
# 327978      zQ-CO0jHvJEsr3HRWHnobw  tSXM662aLwGS_RsVzeINAA
# 327979      zQ-CO0jHvJEsr3HRWHnobw  lAW03ccfMEuRZiDqvVgc0w
#
#                                                          text  cool  stars  \
# Unnamed: 0
# 5           I haven't been to Borden Park in a few years a...     3    5.0
# 6           I went to launch event for this years festival...     0    5.0
# 7           This mall is just sad. The only reasons I ever...     0    2.0
# 8           Ernest's is a really great place to enjoy a fi...     0    5.0
# 9           Unfortunately my experience has been good but ...     0    3.0
# ...                                                       ...   ...    ...
# 327975      Good selections of on tap craft brews, good se...     0    2.0
# 327976      I recently moved to the area from California a...     1    5.0
# 327977      What can I say...\n\nWe went to the St Albert ...     1    1.0
# 327978      Nello's is one of my all time favorites. I alw...     0    5.0
# 327979      I've come here twice now for dinner.\n\nThe re...     2    4.0
#
#                                  date  funny               review_id  useful  \
# Unnamed: 0
# 5           2015-06-22 13:52:58+00:00      1  8suVo8rQiU6hKR1hvkvGxg       3
# 6           2017-06-05 13:28:02+00:00      0  GDHRtRWwSmqK8x_tYLpDvQ       1
# 7           2014-04-02 23:30:50+00:00      0  kt_txOBGmemW1zHMe9NPDw       2
# 8           2018-04-28 04:14:32+00:00      0  oc6Pc0d2XDlUUjAXfQbVmg       0
# 9           2014-03-20 02:46:48+00:00      0  dfEIDw7q267fhvbZexB6Lg       0
# ...                               ...    ...                     ...     ...
# 327975      2018-04-23 19:41:56+00:00      0  vzRQ6fMxna6EJ_Q6Hkrs7A       0
# 327976      2015-03-11 08:43:57+00:00      1  E-12Xayd4_PrlBGNk_-kbQ       5
# 327977      2015-06-08 04:45:23+00:00      0  m2vkgIRl9dMIeibvF-G6MQ       0
# 327978      2019-06-10 01:51:46+00:00      0  u_pVvrejJC9a2vJ9rLca9g       0
# 327979      2017-03-02 21:50:46+00:00      1  Vw8p9ZhTiD5YZzjvXOBvUg       7
#
#             average_user_stars  ... submitted_reviews  \
# Unnamed: 0                      ...
# 5                         4.15  ...             177.0
# 6                         4.15  ...              71.0
# 7                         3.69  ...             262.0
# 8                         4.51  ...              91.0
# 9                         3.56  ...             139.0
# ...                        ...  ...               ...
# 327975                    4.05  ...              60.0
# 327976                    4.30  ...              15.0
# 327977                    2.00  ...               4.0
# 327978                    3.47  ...              47.0
# 327979                    4.03  ...            1578.0
#
#                                      name          city state latitude  \
# Unnamed: 0
# 5                             Borden Park      Edmonton    AB      T5B
# 6            Edmonton Craft Beer Festival      Edmonton    AB      T5B
# 7                        Northgate Centre      Edmonton    AB      T5E
# 8                    Ernest's Dining Room      Edmonton    AB      T5G
# 9                                 Teavana      Edmonton    AB      T5G
# ...                                   ...           ...   ...      ...
# 327975                       Beer Factory  Saint Albert    AB  T8N 4B1
# 327976      Sturgeon Valley Athletic Club    St. Albert    AB  T8N 5B2
# 327977          Dairy Queen Grill & Chill    St. Albert    AB  T8N 5N6
# 327978                 Nello's Restaurant     St Albert    AB  T8N 5Z1
# 327979                 Nello's Restaurant     St Albert    AB  T8N 5Z1
#
#              longitude  average_business_stars  recieved_reviews  \
# Unnamed: 0
# 5          -113.452413                     4.0              12.0
# 6          -113.456865                     4.5              21.0
# 7          -113.487943                     2.0              14.0
# 8          -113.502944                     4.5              13.0
# 9          -113.506020                     3.0               9.0
# ...                ...                     ...               ...
# 327975     -113.642913                     3.5              15.0
# 327976     -113.576604                     4.0               7.0
# 327977     -113.626233                     2.5              11.0
# 327978     -113.629268                     4.0              57.0
# 327979     -113.629268                     4.0              57.0
#
#                                                    categories  \
# Unnamed: 0
# 5                          Parks, Active Life, Swimming Pools
# 6               Arts & Entertainment, Festivals, Local Flavor
# 7                                  Shopping, Shopping Centers
# 8                                 Canadian (New), Restaurants
# 9                                             Tea Rooms, Food
# ...                                                       ...
# 327975      Bars, Restaurants, Food, Beer, Wine & Spirits,...
# 327976      Pilates, Health & Medical, Fitness & Instructi...
# 327977      Fast Food, Ice Cream & Frozen Yogurt, Restaura...
# 327978      Mediterranean, Restaurants, Gluten-Free, Itali...
# 327979      Mediterranean, Restaurants, Gluten-Free, Itali...
#
#                                                    attributes
# Unnamed: 0
# 5           {'GoodForKids': 'True', 'BikeParking': 'True',...
# 6                                    {'GoodForKids': 'False'}
# 7           {'BikeParking': 'True', 'BusinessParking': "{'...
# 8           {'HasTV': 'True', 'Ambience': "{'touristy': Fa...
# 9           {'RestaurantsPriceRange2': '2', 'WiFi': "u'no'...
# ...                                                       ...
# 327975      {'RestaurantsReservations': 'True', 'Restauran...
# 327976      {'GoodForKids': 'True', 'ByAppointmentOnly': '...
# 327977      {'WiFi': "u'no'", 'NoiseLevel': "u'very_loud'"...
# 327978      {'OutdoorSeating': 'False', 'BikeParking': 'Fa...
# 327979      {'OutdoorSeating': 'False', 'BikeParking': 'Fa...
#
# [319562 rows x 21 columns]

# %%
test_sample_dropped_na['category'] = test_sample_dropped_na['categories'].str.split(',').str[0].str.strip()
# Out:
# /var/folders/zp/sq6bzsp91fz1sl3107mgk5gc0000gn/T/ipykernel_15847/1567978691.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_sample_dropped_na['category'] = test_sample_dropped_na['categories'].str.split(',').str[0].str.strip()

# %%
test_sample_dropped_na
# Out:
#                        business_id                 user_id  \
# Unnamed: 0
# 5           Sh4zraoihis9bFldbjDR6w  N5fd36xJuEEHAHLHFirVCg
# 6           WsFZqQ8X78nOVb9Lz4vcKA  UvJugVw9PIABzdnK-bR1GQ
# 7           u5U6aoqDJz_TwKNS6t4dIw  R6M5aafvjMWxOaIzhAd44w
# 8           BzRGo0xHpUp1lxKFYdw1-A  Wa-DgCDkaB3O0xP3cJimFQ
# 9           uk8ZJQONDqdQJoLo07BjHA  a0REzCBCztw5pS0_BOTa6A
# ...                            ...                     ...
# 327975      YNAFgpoVfg1LQmxKpOh8jQ  z7THtOjTBf2hFgUU46MGlw
# 327976      kGY6SZKnu9g-yWCpEGZs6w  QNvibXA1_DAqpxxQgRLpyQ
# 327977      duYoXnIsUygOWz8SjLThzA  INkmTXqkvsIldZ8wMeHzqA
# 327978      zQ-CO0jHvJEsr3HRWHnobw  tSXM662aLwGS_RsVzeINAA
# 327979      zQ-CO0jHvJEsr3HRWHnobw  lAW03ccfMEuRZiDqvVgc0w
#
#                                                          text  cool  stars  \
# Unnamed: 0
# 5           I haven't been to Borden Park in a few years a...     3    5.0
# 6           I went to launch event for this years festival...     0    5.0
# 7           This mall is just sad. The only reasons I ever...     0    2.0
# 8           Ernest's is a really great place to enjoy a fi...     0    5.0
# 9           Unfortunately my experience has been good but ...     0    3.0
# ...                                                       ...   ...    ...
# 327975      Good selections of on tap craft brews, good se...     0    2.0
# 327976      I recently moved to the area from California a...     1    5.0
# 327977      What can I say...\n\nWe went to the St Albert ...     1    1.0
# 327978      Nello's is one of my all time favorites. I alw...     0    5.0
# 327979      I've come here twice now for dinner.\n\nThe re...     2    4.0
#
#                                  date  funny               review_id  useful  \
# Unnamed: 0
# 5           2015-06-22 13:52:58+00:00      1  8suVo8rQiU6hKR1hvkvGxg       3
# 6           2017-06-05 13:28:02+00:00      0  GDHRtRWwSmqK8x_tYLpDvQ       1
# 7           2014-04-02 23:30:50+00:00      0  kt_txOBGmemW1zHMe9NPDw       2
# 8           2018-04-28 04:14:32+00:00      0  oc6Pc0d2XDlUUjAXfQbVmg       0
# 9           2014-03-20 02:46:48+00:00      0  dfEIDw7q267fhvbZexB6Lg       0
# ...                               ...    ...                     ...     ...
# 327975      2018-04-23 19:41:56+00:00      0  vzRQ6fMxna6EJ_Q6Hkrs7A       0
# 327976      2015-03-11 08:43:57+00:00      1  E-12Xayd4_PrlBGNk_-kbQ       5
# 327977      2015-06-08 04:45:23+00:00      0  m2vkgIRl9dMIeibvF-G6MQ       0
# 327978      2019-06-10 01:51:46+00:00      0  u_pVvrejJC9a2vJ9rLca9g       0
# 327979      2017-03-02 21:50:46+00:00      1  Vw8p9ZhTiD5YZzjvXOBvUg       7
#
#             average_user_stars  ...                           name  \
# Unnamed: 0                      ...
# 5                         4.15  ...                    Borden Park
# 6                         4.15  ...   Edmonton Craft Beer Festival
# 7                         3.69  ...               Northgate Centre
# 8                         4.51  ...           Ernest's Dining Room
# 9                         3.56  ...                        Teavana
# ...                        ...  ...                            ...
# 327975                    4.05  ...                   Beer Factory
# 327976                    4.30  ...  Sturgeon Valley Athletic Club
# 327977                    2.00  ...      Dairy Queen Grill & Chill
# 327978                    3.47  ...             Nello's Restaurant
# 327979                    4.03  ...             Nello's Restaurant
#
#                     city state latitude   longitude average_business_stars  \
# Unnamed: 0
# 5               Edmonton    AB      T5B -113.452413                    4.0
# 6               Edmonton    AB      T5B -113.456865                    4.5
# 7               Edmonton    AB      T5E -113.487943                    2.0
# 8               Edmonton    AB      T5G -113.502944                    4.5
# 9               Edmonton    AB      T5G -113.506020                    3.0
# ...                  ...   ...      ...         ...                    ...
# 327975      Saint Albert    AB  T8N 4B1 -113.642913                    3.5
# 327976        St. Albert    AB  T8N 5B2 -113.576604                    4.0
# 327977        St. Albert    AB  T8N 5N6 -113.626233                    2.5
# 327978         St Albert    AB  T8N 5Z1 -113.629268                    4.0
# 327979         St Albert    AB  T8N 5Z1 -113.629268                    4.0
#
#             recieved_reviews  \
# Unnamed: 0
# 5                       12.0
# 6                       21.0
# 7                       14.0
# 8                       13.0
# 9                        9.0
# ...                      ...
# 327975                  15.0
# 327976                   7.0
# 327977                  11.0
# 327978                  57.0
# 327979                  57.0
#
#                                                    categories  \
# Unnamed: 0
# 5                          Parks, Active Life, Swimming Pools
# 6               Arts & Entertainment, Festivals, Local Flavor
# 7                                  Shopping, Shopping Centers
# 8                                 Canadian (New), Restaurants
# 9                                             Tea Rooms, Food
# ...                                                       ...
# 327975      Bars, Restaurants, Food, Beer, Wine & Spirits,...
# 327976      Pilates, Health & Medical, Fitness & Instructi...
# 327977      Fast Food, Ice Cream & Frozen Yogurt, Restaura...
# 327978      Mediterranean, Restaurants, Gluten-Free, Itali...
# 327979      Mediterranean, Restaurants, Gluten-Free, Itali...
#
#                                                    attributes  \
# Unnamed: 0
# 5           {'GoodForKids': 'True', 'BikeParking': 'True',...
# 6                                    {'GoodForKids': 'False'}
# 7           {'BikeParking': 'True', 'BusinessParking': "{'...
# 8           {'HasTV': 'True', 'Ambience': "{'touristy': Fa...
# 9           {'RestaurantsPriceRange2': '2', 'WiFi': "u'no'...
# ...                                                       ...
# 327975      {'RestaurantsReservations': 'True', 'Restauran...
# 327976      {'GoodForKids': 'True', 'ByAppointmentOnly': '...
# 327977      {'WiFi': "u'no'", 'NoiseLevel': "u'very_loud'"...
# 327978      {'OutdoorSeating': 'False', 'BikeParking': 'Fa...
# 327979      {'OutdoorSeating': 'False', 'BikeParking': 'Fa...
#
#                         category
# Unnamed: 0
# 5                          Parks
# 6           Arts & Entertainment
# 7                       Shopping
# 8                 Canadian (New)
# 9                      Tea Rooms
# ...                          ...
# 327975                      Bars
# 327976                   Pilates
# 327977                 Fast Food
# 327978             Mediterranean
# 327979             Mediterranean
#
# [319562 rows x 22 columns]

# %%
test_sample_dropped_na['category'].nunique()
# Out:
# 1017

# %%
categories = test_sample_dropped_na['category'].value_counts()
selected_categories = categories[categories > 50].index.tolist()
filtered_dataset = test_sample_dropped_na[test_sample_dropped_na['category'].isin(selected_categories)]

# %%
filtered_dataset
# Out:
#                        business_id                 user_id  \
# Unnamed: 0
# 5           Sh4zraoihis9bFldbjDR6w  N5fd36xJuEEHAHLHFirVCg
# 6           WsFZqQ8X78nOVb9Lz4vcKA  UvJugVw9PIABzdnK-bR1GQ
# 7           u5U6aoqDJz_TwKNS6t4dIw  R6M5aafvjMWxOaIzhAd44w
# 8           BzRGo0xHpUp1lxKFYdw1-A  Wa-DgCDkaB3O0xP3cJimFQ
# 9           uk8ZJQONDqdQJoLo07BjHA  a0REzCBCztw5pS0_BOTa6A
# ...                            ...                     ...
# 327974      IG1MLst7GcptliBDES8ycw  Pn84Dl915kwIFIyfty5_cA
# 327975      YNAFgpoVfg1LQmxKpOh8jQ  z7THtOjTBf2hFgUU46MGlw
# 327977      duYoXnIsUygOWz8SjLThzA  INkmTXqkvsIldZ8wMeHzqA
# 327978      zQ-CO0jHvJEsr3HRWHnobw  tSXM662aLwGS_RsVzeINAA
# 327979      zQ-CO0jHvJEsr3HRWHnobw  lAW03ccfMEuRZiDqvVgc0w
#
#                                                          text  cool  stars  \
# Unnamed: 0
# 5           I haven't been to Borden Park in a few years a...     3    5.0
# 6           I went to launch event for this years festival...     0    5.0
# 7           This mall is just sad. The only reasons I ever...     0    2.0
# 8           Ernest's is a really great place to enjoy a fi...     0    5.0
# 9           Unfortunately my experience has been good but ...     0    3.0
# ...                                                       ...   ...    ...
# 327974      Wild Earth Cafe has always been one of my favo...     1    5.0
# 327975      Good selections of on tap craft brews, good se...     0    2.0
# 327977      What can I say...\n\nWe went to the St Albert ...     1    1.0
# 327978      Nello's is one of my all time favorites. I alw...     0    5.0
# 327979      I've come here twice now for dinner.\n\nThe re...     2    4.0
#
#                                  date  funny               review_id  useful  \
# Unnamed: 0
# 5           2015-06-22 13:52:58+00:00      1  8suVo8rQiU6hKR1hvkvGxg       3
# 6           2017-06-05 13:28:02+00:00      0  GDHRtRWwSmqK8x_tYLpDvQ       1
# 7           2014-04-02 23:30:50+00:00      0  kt_txOBGmemW1zHMe9NPDw       2
# 8           2018-04-28 04:14:32+00:00      0  oc6Pc0d2XDlUUjAXfQbVmg       0
# 9           2014-03-20 02:46:48+00:00      0  dfEIDw7q267fhvbZexB6Lg       0
# ...                               ...    ...                     ...     ...
# 327974      2012-06-19 23:39:45+00:00      1  155UOEf9_ixtaqMRbaG5QQ       1
# 327975      2018-04-23 19:41:56+00:00      0  vzRQ6fMxna6EJ_Q6Hkrs7A       0
# 327977      2015-06-08 04:45:23+00:00      0  m2vkgIRl9dMIeibvF-G6MQ       0
# 327978      2019-06-10 01:51:46+00:00      0  u_pVvrejJC9a2vJ9rLca9g       0
# 327979      2017-03-02 21:50:46+00:00      1  Vw8p9ZhTiD5YZzjvXOBvUg       7
#
#             average_user_stars  ...                          name  \
# Unnamed: 0                      ...
# 5                         4.15  ...                   Borden Park
# 6                         4.15  ...  Edmonton Craft Beer Festival
# 7                         3.69  ...              Northgate Centre
# 8                         4.51  ...          Ernest's Dining Room
# 9                         3.56  ...                       Teavana
# ...                        ...  ...                           ...
# 327974                    4.40  ...      Wild Earth Bakery & Café
# 327975                    4.05  ...                  Beer Factory
# 327977                    2.00  ...     Dairy Queen Grill & Chill
# 327978                    3.47  ...            Nello's Restaurant
# 327979                    4.03  ...            Nello's Restaurant
#
#                     city state latitude   longitude average_business_stars  \
# Unnamed: 0
# 5               Edmonton    AB      T5B -113.452413                    4.0
# 6               Edmonton    AB      T5B -113.456865                    4.5
# 7               Edmonton    AB      T5E -113.487943                    2.0
# 8               Edmonton    AB      T5G -113.502944                    4.5
# 9               Edmonton    AB      T5G -113.506020                    3.0
# ...                  ...   ...      ...         ...                    ...
# 327974         St Albert    AB  T8N 3X4 -113.647753                    3.5
# 327975      Saint Albert    AB  T8N 4B1 -113.642913                    3.5
# 327977        St. Albert    AB  T8N 5N6 -113.626233                    2.5
# 327978         St Albert    AB  T8N 5Z1 -113.629268                    4.0
# 327979         St Albert    AB  T8N 5Z1 -113.629268                    4.0
#
#             recieved_reviews  \
# Unnamed: 0
# 5                       12.0
# 6                       21.0
# 7                       14.0
# 8                       13.0
# 9                        9.0
# ...                      ...
# 327974                  77.0
# 327975                  15.0
# 327977                  11.0
# 327978                  57.0
# 327979                  57.0
#
#                                                    categories  \
# Unnamed: 0
# 5                          Parks, Active Life, Swimming Pools
# 6               Arts & Entertainment, Festivals, Local Flavor
# 7                                  Shopping, Shopping Centers
# 8                                 Canadian (New), Restaurants
# 9                                             Tea Rooms, Food
# ...                                                       ...
# 327974       Bakeries, Coffee & Tea, Restaurants, Food, Cafes
# 327975      Bars, Restaurants, Food, Beer, Wine & Spirits,...
# 327977      Fast Food, Ice Cream & Frozen Yogurt, Restaura...
# 327978      Mediterranean, Restaurants, Gluten-Free, Itali...
# 327979      Mediterranean, Restaurants, Gluten-Free, Itali...
#
#                                                    attributes  \
# Unnamed: 0
# 5           {'GoodForKids': 'True', 'BikeParking': 'True',...
# 6                                    {'GoodForKids': 'False'}
# 7           {'BikeParking': 'True', 'BusinessParking': "{'...
# 8           {'HasTV': 'True', 'Ambience': "{'touristy': Fa...
# 9           {'RestaurantsPriceRange2': '2', 'WiFi': "u'no'...
# ...                                                       ...
# 327974      {'RestaurantsAttire': "'casual'", 'Restaurants...
# 327975      {'RestaurantsReservations': 'True', 'Restauran...
# 327977      {'WiFi': "u'no'", 'NoiseLevel': "u'very_loud'"...
# 327978      {'OutdoorSeating': 'False', 'BikeParking': 'Fa...
# 327979      {'OutdoorSeating': 'False', 'BikeParking': 'Fa...
#
#                         category
# Unnamed: 0
# 5                          Parks
# 6           Arts & Entertainment
# 7                       Shopping
# 8                 Canadian (New)
# 9                      Tea Rooms
# ...                          ...
# 327974                  Bakeries
# 327975                      Bars
# 327977                 Fast Food
# 327978             Mediterranean
# 327979             Mediterranean
#
# [310913 rows x 22 columns]

# %%
# generalizations
restaurant_categories = ['Food Stands','Brasseries','Cheese Shops','Fish & Chips','Szechuan','African','Malaysian','Acai Bowls','Waffles','Food', 'Local Flavor', 'Canadian (New)', 'Vietnamese', 'Italian', 'Buffets', 'Burgers', 'American (Traditional)', 'American (New)', 'Breakfast & Brunch', 'Sandwiches', 'Seafood', 'Mexican', 'Pizza', 'Cajun/Creole', 'Sushi Bars', 'Chinese', 'Japanese', 'Steakhouses', 'Cafes', 'Salad', 'Fast Food', 'Bakeries', 'Ice Cream & Frozen Yogurt', 'Desserts', 'Barbeque', 'Thai', 'Specialty Food', 'Asian Fusion', 'Southern', 'Diners', 'Mediterranean', 'Delis', 'Caterers', 'Chicken Wings', 'Vegetarian', 'Indian', 'Comfort Food', 'Latin American', 'French', 'Vegan', 'Greek', 'Gluten-Free', 'Tex-Mex', 'Korean', 'Soup', 'Donuts', 'Live/Raw Food', 'Tacos', 'Tapas/Small Plates', 'Gastropubs', 'Food Delivery Services', 'Pakistani', 'Tapas Bars', 'Cheesesteaks', 'Soul Food', 'Ethnic Food', 'Middle Eastern', 'German', 'Bagels', 'Food Trucks', 'Hot Dogs', 'Noodles', 'Creperies', 'Spanish', 'Caribbean', 'Chicken Shop', 'Ramen', 'Cuban', 'Irish', 'Basque', 'Halal', 'Dim Sum', 'New Mexican Cuisine', 'Poke', 'Seafood Markets', 'British', 'Gelato', 'Cupcakes', 'Ethiopian', 'Peruvian', 'Falafel', 'Custom Cakes', 'Pasta Shops', 'Kebab', 'Hot Pot', 'Puerto Rican', 'Dominican', 'Salvadoran', 'Cafeteria', 'Pancakes', 'Senegalese', 'Sri Lankan', 'Parent Cafes','Food Banks','Food Banks','Afghan','Izakaya','Indonesian','Imported Food','Venezuelan','Pretzels','Smokehouse','Shanghainese','Patisserie/Cake Shop','Kosher','Shaved Ice','Filipino','Personal Chefs','Chocolatiers & Shops','Irish Pub','Bed & Breakfast','Taiwanese','Brazilian','Modern European','Wraps','Cantonese','Hawaiian','Candy Stores']
beauty = ["Men's Hair Salons",'Nail Technicians','Beauty & Spas', 'Nail Salons', 'Cosmetics & Beauty Supply', 'Hair Salons', 'Massage', 'Skin Care', 'Waxing', 'Eyelash Service', 'Barbers', 'Tanning', 'Threading Services', 'Day Spas', 'Piercing', 'Blow Dry/Out Services', 'Makeup Artists', 'Hair Removal', 'Eyebrow Services', 'Hair Stylists', 'Tattoo', 'Laser Hair Removal', 'Massage Therapy', 'Pedicures', 'Medical Spas', 'Hair Extensions', 'Reflexology', 'Hair Loss Centers', 'Acupuncture', 'Pole Dancing Classes', 'Float Spa', 'Cryotherapy', 'Sugaring', 'Permanent Makeup', 'Saunas','Massage Schools']
bars = ['Beer Gardens','Wineries','Bars', 'Nightlife', 'Beer', 'Wine Bars', 'Cocktail Bars', 'Sports Bars', 'Pubs', 'Breweries', 'Gastropubs', 'Beer Bar', 'Wine Tasting Room', 'Dive Bars', 'Karaoke', 'Speakeasies', 'Gay Bars', 'Juice Bars & Smoothies', 'Hookah Bars', 'Brewpubs', 'Cigar Bars', 'Champagne Bars', 'Tiki Bars','Meaderies','Distilleries','Whiskey Bars']
hotels = ['Hotels','Resorts']
auto = ['Gas Stations','Used','Auto Repair','Car Dealers','Oil Change Stations','Auto Parts & Supplies','Tires','Car Wash','Body Shops','Car Rental','Auto Detailing','Auto Loan Providers','Trailer Rental','Departments of Motor Vehicles','Motorcycle Rental','Mobile Dent Repair','Motorsport Vehicle Dealers','Bike tours','Crane Services','Auto Insurance','Car Share Services','Motorsport Vehicle Repairs','Wheel & Rim Repair','Transmission Repair','Windshield Installation & Repair','Auto Glass Services','Used Car Dealers']
venues = ['Wedding Planning','Venues & Event Spaces','Party & Event Planning','Music Venues']
fitness = ['Fitness & Instruction','Gyms','Kickboxing','Aerial Fitness','Yoga']
entertainment = ['Cinema','Museums','Tours','Performing Arts','Arts & Crafts','Jazz & Blues','Landmarks & Historical Buildings','Golf','Art Galleries','Festivals','Stadiums & Arenas','Zoos','Hiking','Bike Rentals','Playgrounds','Professional Sports Teams','Recreation Centers','Art Tours','Country Clubs','Decks & Railing','Mountain Biking','Dinner Theater','Tabletop Games','Aerial Tours','Party Bike Rentals','Game Truck Rental','Psychic Mediums', "Walking Tours", "Boat Tours", "Brewery Tours", "Wine Tours", "Air Tours", "Hot Air Balloons",  "Aerial Tours",'Buses','Firearm Training','Disc Golf','High Fidelity Audio Equipment','Vacation Rental Agents','Matchmakers','Free Diving','Ranches','Bicycles','Farm Equipment Repair','Golf Lessons','Racing Experience','Face Painting','Botanical Gardens','Comedy Clubs','Sports Clubs','Gun/Rifle Ranges','Amusement Parks','Photographers','Cards & Stationery','Fishing','Boat Charters','Bowling','Arcades','Airports','Escape Games','Boating','Casinos','Beaches','Art Museums']
medical = ['Hospitals','Urgent Care','Doctors','Dentists','General Dentistry','Eyewear & Opticians','Medical Centers','Cosmetic Dentists','Chiropractors','Optometrists','Reflexology','Orthodontists','Periodontists','Medical Cannabis Referrals','Pain Management','Surgeons','Allergists','Anesthesiologists','Body Contouring','Dialysis Clinics','Reproductive Health Services','Memory Care','Preventive Medicine','Lice Services','Medical Transportation','Prosthodontists','CPR Classes','Retina Specialists','Nephrologists','Sex Therapists','Ophthalmologists','Obstetricians & Gynecologists','Dermatologists','Physical Therapy','Oral Surgeons','Pharmacy','Pediatric Dentists','Family Practice','Diagnostic Services']
nightlife = ['Dance Clubs','Strip Clubs','Adult Entertainment','Dance Clubs']
home_services = ['Garage Door Services','Laundry Services','Nurseries & Gardening','Home & Garden','Building Supplies','Movers','Apartments','Real Estate','Contractors','Heating & Air Conditioning/HVAC','Furniture Stores','Home Decor','Plumbing','Appliances & Repair','Mattresses','Sewing & Alterations','Home Cleaning','Appliances','Pest Control','Property Management','Landscaping','Kitchen & Bath','Real Estate Agents','Electricians','Carpeting','Packing Services','Commercial Real Estate','Decks & Railing','Chimney Sweeps','Countertop Installation','Home Network Installation','Roof Inspectors','Outdoor Power Equipment Services','Home & Rental Insurance','House Sitters','Assisted Living Facilities','Bounce House Rentals','Awnings','Safety Equipment','Internet Service Providers','Windows Installation','Roofing','Carpet Cleaning','Flooring','Security Systems','Keys & Locksmiths','Tree Services','Water Heater Installation/Repair']
shopping = ['Electronics','Mobile Phones','Bridal','Discount Store','Hardware Stores','Antiques','Department Stores','Jewelry','Fashion','Sporting Goods',"Women's Clothing",'Drugstores','Convenience Stores','Accessories','Trainers','Health Markets','Shopping Centers','Shoe Stores','Thrift Stores',"Men's Clothing",'Piercing','Tobacco Shops','Hobby Shops','Shoe Repair','Screen Printing/T-Shirt Printing','Rugs','Hunting & Fishing Supplies','Wigs','Sunglasses','Hockey Equipment','Storefront Clinics','Snorkeling','Perfume','Local Fish Stores','Concept Shops','Jewelry Repair','Bike Repair/Maintenance','Watches','Guns & Ammo','Vape Shops',"Children's Clothing",'Mobile Phone Repair','Spray Tanning','Electronics Repair','Computers','Sports Wear','Bikes','Toy Stores','Printing Services','Music & DVDs','Bookstores','Outdoor Gear','IT Services & Computer Repair','Street Vendors']
coffee_tea = ['Bubble Tea','Coffee Roasteries','Tea Rooms','Internet Cafes']
pets = ['Pet Services','Veterinarians','Pet Stores','Pet Hospice','Pet Insurance','Pet Photography','Pet Groomers','Pets']
groceries = ['Fruits & Veggies','Wholesale Stores','Wholesalers','Organic Stores','Farmers Market','Meat Shops']
legal = ['Public Services & Government','Shipping Centers','Self Storage','Legal Services','Divorce & Family Law','Billing Services','Land Surveying','Fingerprinting','Traffic Ticketing Law','Investing','Excavation Services','Aestheticians','Environmental Abatement','Junk Removal & Hauling','Legal Services','Home Inspectors','Towing','Couriers & Delivery Services','Financial Services','Notaries','Real Estate Services','Transportation']
florist = ['Florists','Gift Shops']
education = ['Books','Bookbinding','Career Counseling','Tutoring Centers','Parenting Classes','Buddhist Temples','Architects','Religious Schools','Vocal Coach','Self-defense Classes','Bail Bondsmen','Day Camps','Smog Check Stations','Bookbinding','Religious Organizations','Community Service/Non-Profit','Specialty Schools','Education']

# %%
import numpy as np

# %%
filtered_dataset['Main_Category'] = np.select(
    [
        filtered_dataset['category'].isin(restaurant_categories),
        filtered_dataset['category'].isin(beauty),
        filtered_dataset['category'].isin(bars),
        filtered_dataset['category'].isin(hotels),
        filtered_dataset['category'].isin(auto),
        filtered_dataset['category'].isin(venues),
        filtered_dataset['category'].isin(fitness),
        filtered_dataset['category'].isin(entertainment),
        filtered_dataset['category'].isin(medical),
        filtered_dataset['category'].isin(nightlife),
        filtered_dataset['category'].isin(home_services),
        filtered_dataset['category'].isin(shopping),
        filtered_dataset['category'].isin(coffee_tea),
        filtered_dataset['category'].isin(pets),
        filtered_dataset['category'].isin(groceries),
        filtered_dataset['category'].isin(legal),
        filtered_dataset['category'].isin(florist),
        filtered_dataset['category'].isin(education)
    ],
    [
        'Restaurant',
        'Beauty',
        'Bars',
        'Hotels',
        'Auto',
        'Venues',
        'Fitness',
        'Entertainment',
        'Medical',
        'Nightlife',
        'Home_Services',
        'Shopping',
        'Coffee_Tea',
        'Pets',
        'Groceries',
        'Legal',
        'Florist',
        'Education'
    ],
    default='Other'
)
# Out:
# /var/folders/zp/sq6bzsp91fz1sl3107mgk5gc0000gn/T/ipykernel_15847/1485385008.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dataset['Main_Category'] = np.select(

# %%
filtered_dataset
# Out:
#                        business_id                 user_id  \
# Unnamed: 0
# 5           Sh4zraoihis9bFldbjDR6w  N5fd36xJuEEHAHLHFirVCg
# 6           WsFZqQ8X78nOVb9Lz4vcKA  UvJugVw9PIABzdnK-bR1GQ
# 7           u5U6aoqDJz_TwKNS6t4dIw  R6M5aafvjMWxOaIzhAd44w
# 8           BzRGo0xHpUp1lxKFYdw1-A  Wa-DgCDkaB3O0xP3cJimFQ
# 9           uk8ZJQONDqdQJoLo07BjHA  a0REzCBCztw5pS0_BOTa6A
# ...                            ...                     ...
# 327974      IG1MLst7GcptliBDES8ycw  Pn84Dl915kwIFIyfty5_cA
# 327975      YNAFgpoVfg1LQmxKpOh8jQ  z7THtOjTBf2hFgUU46MGlw
# 327977      duYoXnIsUygOWz8SjLThzA  INkmTXqkvsIldZ8wMeHzqA
# 327978      zQ-CO0jHvJEsr3HRWHnobw  tSXM662aLwGS_RsVzeINAA
# 327979      zQ-CO0jHvJEsr3HRWHnobw  lAW03ccfMEuRZiDqvVgc0w
#
#                                                          text  cool  stars  \
# Unnamed: 0
# 5           I haven't been to Borden Park in a few years a...     3    5.0
# 6           I went to launch event for this years festival...     0    5.0
# 7           This mall is just sad. The only reasons I ever...     0    2.0
# 8           Ernest's is a really great place to enjoy a fi...     0    5.0
# 9           Unfortunately my experience has been good but ...     0    3.0
# ...                                                       ...   ...    ...
# 327974      Wild Earth Cafe has always been one of my favo...     1    5.0
# 327975      Good selections of on tap craft brews, good se...     0    2.0
# 327977      What can I say...\n\nWe went to the St Albert ...     1    1.0
# 327978      Nello's is one of my all time favorites. I alw...     0    5.0
# 327979      I've come here twice now for dinner.\n\nThe re...     2    4.0
#
#                                  date  funny               review_id  useful  \
# Unnamed: 0
# 5           2015-06-22 13:52:58+00:00      1  8suVo8rQiU6hKR1hvkvGxg       3
# 6           2017-06-05 13:28:02+00:00      0  GDHRtRWwSmqK8x_tYLpDvQ       1
# 7           2014-04-02 23:30:50+00:00      0  kt_txOBGmemW1zHMe9NPDw       2
# 8           2018-04-28 04:14:32+00:00      0  oc6Pc0d2XDlUUjAXfQbVmg       0
# 9           2014-03-20 02:46:48+00:00      0  dfEIDw7q267fhvbZexB6Lg       0
# ...                               ...    ...                     ...     ...
# 327974      2012-06-19 23:39:45+00:00      1  155UOEf9_ixtaqMRbaG5QQ       1
# 327975      2018-04-23 19:41:56+00:00      0  vzRQ6fMxna6EJ_Q6Hkrs7A       0
# 327977      2015-06-08 04:45:23+00:00      0  m2vkgIRl9dMIeibvF-G6MQ       0
# 327978      2019-06-10 01:51:46+00:00      0  u_pVvrejJC9a2vJ9rLca9g       0
# 327979      2017-03-02 21:50:46+00:00      1  Vw8p9ZhTiD5YZzjvXOBvUg       7
#
#             average_user_stars  ...          city  state latitude   longitude  \
# Unnamed: 0                      ...
# 5                         4.15  ...      Edmonton     AB      T5B -113.452413
# 6                         4.15  ...      Edmonton     AB      T5B -113.456865
# 7                         3.69  ...      Edmonton     AB      T5E -113.487943
# 8                         4.51  ...      Edmonton     AB      T5G -113.502944
# 9                         3.56  ...      Edmonton     AB      T5G -113.506020
# ...                        ...  ...           ...    ...      ...         ...
# 327974                    4.40  ...     St Albert     AB  T8N 3X4 -113.647753
# 327975                    4.05  ...  Saint Albert     AB  T8N 4B1 -113.642913
# 327977                    2.00  ...    St. Albert     AB  T8N 5N6 -113.626233
# 327978                    3.47  ...     St Albert     AB  T8N 5Z1 -113.629268
# 327979                    4.03  ...     St Albert     AB  T8N 5Z1 -113.629268
#
#            average_business_stars recieved_reviews  \
# Unnamed: 0
# 5                             4.0             12.0
# 6                             4.5             21.0
# 7                             2.0             14.0
# 8                             4.5             13.0
# 9                             3.0              9.0
# ...                           ...              ...
# 327974                        3.5             77.0
# 327975                        3.5             15.0
# 327977                        2.5             11.0
# 327978                        4.0             57.0
# 327979                        4.0             57.0
#
#                                                    categories  \
# Unnamed: 0
# 5                          Parks, Active Life, Swimming Pools
# 6               Arts & Entertainment, Festivals, Local Flavor
# 7                                  Shopping, Shopping Centers
# 8                                 Canadian (New), Restaurants
# 9                                             Tea Rooms, Food
# ...                                                       ...
# 327974       Bakeries, Coffee & Tea, Restaurants, Food, Cafes
# 327975      Bars, Restaurants, Food, Beer, Wine & Spirits,...
# 327977      Fast Food, Ice Cream & Frozen Yogurt, Restaura...
# 327978      Mediterranean, Restaurants, Gluten-Free, Itali...
# 327979      Mediterranean, Restaurants, Gluten-Free, Itali...
#
#                                                    attributes  \
# Unnamed: 0
# 5           {'GoodForKids': 'True', 'BikeParking': 'True',...
# 6                                    {'GoodForKids': 'False'}
# 7           {'BikeParking': 'True', 'BusinessParking': "{'...
# 8           {'HasTV': 'True', 'Ambience': "{'touristy': Fa...
# 9           {'RestaurantsPriceRange2': '2', 'WiFi': "u'no'...
# ...                                                       ...
# 327974      {'RestaurantsAttire': "'casual'", 'Restaurants...
# 327975      {'RestaurantsReservations': 'True', 'Restauran...
# 327977      {'WiFi': "u'no'", 'NoiseLevel': "u'very_loud'"...
# 327978      {'OutdoorSeating': 'False', 'BikeParking': 'Fa...
# 327979      {'OutdoorSeating': 'False', 'BikeParking': 'Fa...
#
#                         category Main_Category
# Unnamed: 0
# 5                          Parks         Other
# 6           Arts & Entertainment         Other
# 7                       Shopping         Other
# 8                 Canadian (New)    Restaurant
# 9                      Tea Rooms    Coffee_Tea
# ...                          ...           ...
# 327974                  Bakeries    Restaurant
# 327975                      Bars          Bars
# 327977                 Fast Food    Restaurant
# 327978             Mediterranean    Restaurant
# 327979             Mediterranean    Restaurant
#
# [310913 rows x 23 columns]

# %%
filtered_dataset['Main_Category'].value_counts()
# Out:
# Main_Category
# Restaurant       138338
# Other             91704
# Bars              30901
# Beauty            14731
# Shopping           6631
# Home_Services      6270
# Auto               5629
# Entertainment      4058
# Medical            2962
# Hotels             2088
# Venues             1863
# Legal              1294
# Fitness            1074
# Pets                834
# Education           731
# Coffee_Tea          624
# Groceries           531
# Nightlife           374
# Florist             276
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
top_10_categories = filtered_dataset['Main_Category'].value_counts().sort_values(ascending=False).head(10)
plt.figure(figsize=(10, 8))
top_10_categories.plot(kind='bar')
plt.title('Top 10 Location Categories')
plt.xlabel('Category')
plt.ylabel('Number of Locations')
plt.show()

# %%
filtered_dataset.drop(columns=['categories'], inplace = True)
# Out:
# /var/folders/zp/sq6bzsp91fz1sl3107mgk5gc0000gn/T/ipykernel_15847/3992612959.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dataset.drop(columns=['categories'], inplace = True)

# %%
filtered_dataset
# Out:
#                        business_id                 user_id  \
# Unnamed: 0
# 5           Sh4zraoihis9bFldbjDR6w  N5fd36xJuEEHAHLHFirVCg
# 6           WsFZqQ8X78nOVb9Lz4vcKA  UvJugVw9PIABzdnK-bR1GQ
# 7           u5U6aoqDJz_TwKNS6t4dIw  R6M5aafvjMWxOaIzhAd44w
# 8           BzRGo0xHpUp1lxKFYdw1-A  Wa-DgCDkaB3O0xP3cJimFQ
# 9           uk8ZJQONDqdQJoLo07BjHA  a0REzCBCztw5pS0_BOTa6A
# ...                            ...                     ...
# 327974      IG1MLst7GcptliBDES8ycw  Pn84Dl915kwIFIyfty5_cA
# 327975      YNAFgpoVfg1LQmxKpOh8jQ  z7THtOjTBf2hFgUU46MGlw
# 327977      duYoXnIsUygOWz8SjLThzA  INkmTXqkvsIldZ8wMeHzqA
# 327978      zQ-CO0jHvJEsr3HRWHnobw  tSXM662aLwGS_RsVzeINAA
# 327979      zQ-CO0jHvJEsr3HRWHnobw  lAW03ccfMEuRZiDqvVgc0w
#
#                                                          text  cool  stars  \
# Unnamed: 0
# 5           I haven't been to Borden Park in a few years a...     3    5.0
# 6           I went to launch event for this years festival...     0    5.0
# 7           This mall is just sad. The only reasons I ever...     0    2.0
# 8           Ernest's is a really great place to enjoy a fi...     0    5.0
# 9           Unfortunately my experience has been good but ...     0    3.0
# ...                                                       ...   ...    ...
# 327974      Wild Earth Cafe has always been one of my favo...     1    5.0
# 327975      Good selections of on tap craft brews, good se...     0    2.0
# 327977      What can I say...\n\nWe went to the St Albert ...     1    1.0
# 327978      Nello's is one of my all time favorites. I alw...     0    5.0
# 327979      I've come here twice now for dinner.\n\nThe re...     2    4.0
#
#                                  date  funny               review_id  useful  \
# Unnamed: 0
# 5           2015-06-22 13:52:58+00:00      1  8suVo8rQiU6hKR1hvkvGxg       3
# 6           2017-06-05 13:28:02+00:00      0  GDHRtRWwSmqK8x_tYLpDvQ       1
# 7           2014-04-02 23:30:50+00:00      0  kt_txOBGmemW1zHMe9NPDw       2
# 8           2018-04-28 04:14:32+00:00      0  oc6Pc0d2XDlUUjAXfQbVmg       0
# 9           2014-03-20 02:46:48+00:00      0  dfEIDw7q267fhvbZexB6Lg       0
# ...                               ...    ...                     ...     ...
# 327974      2012-06-19 23:39:45+00:00      1  155UOEf9_ixtaqMRbaG5QQ       1
# 327975      2018-04-23 19:41:56+00:00      0  vzRQ6fMxna6EJ_Q6Hkrs7A       0
# 327977      2015-06-08 04:45:23+00:00      0  m2vkgIRl9dMIeibvF-G6MQ       0
# 327978      2019-06-10 01:51:46+00:00      0  u_pVvrejJC9a2vJ9rLca9g       0
# 327979      2017-03-02 21:50:46+00:00      1  Vw8p9ZhTiD5YZzjvXOBvUg       7
#
#             average_user_stars  ...                          name  \
# Unnamed: 0                      ...
# 5                         4.15  ...                   Borden Park
# 6                         4.15  ...  Edmonton Craft Beer Festival
# 7                         3.69  ...              Northgate Centre
# 8                         4.51  ...          Ernest's Dining Room
# 9                         3.56  ...                       Teavana
# ...                        ...  ...                           ...
# 327974                    4.40  ...      Wild Earth Bakery & Café
# 327975                    4.05  ...                  Beer Factory
# 327977                    2.00  ...     Dairy Queen Grill & Chill
# 327978                    3.47  ...            Nello's Restaurant
# 327979                    4.03  ...            Nello's Restaurant
#
#                     city state latitude   longitude average_business_stars  \
# Unnamed: 0
# 5               Edmonton    AB      T5B -113.452413                    4.0
# 6               Edmonton    AB      T5B -113.456865                    4.5
# 7               Edmonton    AB      T5E -113.487943                    2.0
# 8               Edmonton    AB      T5G -113.502944                    4.5
# 9               Edmonton    AB      T5G -113.506020                    3.0
# ...                  ...   ...      ...         ...                    ...
# 327974         St Albert    AB  T8N 3X4 -113.647753                    3.5
# 327975      Saint Albert    AB  T8N 4B1 -113.642913                    3.5
# 327977        St. Albert    AB  T8N 5N6 -113.626233                    2.5
# 327978         St Albert    AB  T8N 5Z1 -113.629268                    4.0
# 327979         St Albert    AB  T8N 5Z1 -113.629268                    4.0
#
#             recieved_reviews  \
# Unnamed: 0
# 5                       12.0
# 6                       21.0
# 7                       14.0
# 8                       13.0
# 9                        9.0
# ...                      ...
# 327974                  77.0
# 327975                  15.0
# 327977                  11.0
# 327978                  57.0
# 327979                  57.0
#
#                                                    attributes  \
# Unnamed: 0
# 5           {'GoodForKids': 'True', 'BikeParking': 'True',...
# 6                                    {'GoodForKids': 'False'}
# 7           {'BikeParking': 'True', 'BusinessParking': "{'...
# 8           {'HasTV': 'True', 'Ambience': "{'touristy': Fa...
# 9           {'RestaurantsPriceRange2': '2', 'WiFi': "u'no'...
# ...                                                       ...
# 327974      {'RestaurantsAttire': "'casual'", 'Restaurants...
# 327975      {'RestaurantsReservations': 'True', 'Restauran...
# 327977      {'WiFi': "u'no'", 'NoiseLevel': "u'very_loud'"...
# 327978      {'OutdoorSeating': 'False', 'BikeParking': 'Fa...
# 327979      {'OutdoorSeating': 'False', 'BikeParking': 'Fa...
#
#                         category Main_Category
# Unnamed: 0
# 5                          Parks         Other
# 6           Arts & Entertainment         Other
# 7                       Shopping         Other
# 8                 Canadian (New)    Restaurant
# 9                      Tea Rooms    Coffee_Tea
# ...                          ...           ...
# 327974                  Bakeries    Restaurant
# 327975                      Bars          Bars
# 327977                 Fast Food    Restaurant
# 327978             Mediterranean    Restaurant
# 327979             Mediterranean    Restaurant
#
# [310913 rows x 22 columns]

# %%
state_location_counts = filtered_dataset['state'].value_counts().head(10)
plt.figure(figsize=(10, 8))
state_location_counts.sort_values(ascending = False).plot(kind='bar', color = 'Orange')
plt.title('Top 10 State Locations')
plt.xlabel('Number of Locations')
plt.ylabel('Category')
plt.show()
